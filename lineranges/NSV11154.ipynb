# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *

import scienceplots
plt.style.use('science')
plt.style.use('notebook')
import ipyparallel as ipp

# %%
observed_path = "/media/advait/DATA/research/rcb-project/TSFitPy/input_files/observed_spectra"
star = "NSV11154"
observed_file = f"{observed_path}/{star}_clean.txt"
observed_data = np.loadtxt(observed_file, unpack=True)
obs_wave, obs_flux, obs_err = observed_data[0], observed_data[1], observed_data[2]

wavecorr = obs_wave*1e-4
fluxcorr = obs_flux

# %%
lists = {}
basepath = "../input_files/linelists/individual/"
lists['CN'] = basepath + "CN_new"
lists['12C16O'] = basepath + "12C16O"
lists['12C18O'] = basepath + "12C18O"
lists['C2'] = basepath + "C2"

lists['atoms'] = basepath + "atoms_5500K_newCI"

lines = pd.read_csv("/media/advait/DATA/research/rcb-project/code/lineranges/atomic.csv")
lines['wav'] = lines['wav']*1e-4

# %%
# from scipy import signal
# fs = 100000
# fc = 13000  # Cut-off frequency of the filter
# w = fc / (fs / 2) # Normalize the frequency
# b, a = signal.butter(5, w, 'low')
# fluxcorr = signal.filtfilt(b, a, fluxcorr)
# errcorr = signal.filtfilt(b, a, obs_err)
# observed_file = f"{observed_path}/{star}_clean.txt"
# obs_wave += +2e-5 * 1e4
# np.savetxt(observed_file, np.array([obs_wave, fluxcorr, errcorr]).T , fmt = '%.4f %.4f %.4f', delimiter = ' ')

# %%
turbospectrum_paths = {"turbospec_path": "../turbospectrum/exec-ifx/",  # change to /exec-gf/ if gnu compiler
                       "interpol_path": "../scripts/model_interpolators/",
                       "model_atom_path": "../input_files/nlte_data/model_atoms/",
                       "departure_file_path": "../input_files/nlte_data/",
                    #    "model_atmosphere_grid_path": "../input_files/test_model_atmospheres/",
                        "model_atmosphere_grid_path": "../input_files/hdc_model_atmospheres/",
                       "line_list_path": ""}

teff = 5250
logg = 1.0
met = 0.0
vmic = 6.5
lmin = np.min(obs_wave).round(2)
lmax = 2.5e4
# lmax = 22700
ldelta = 0.1
atmosphere_type = "1D"   # "1D" or "3D"
nlte_flag = False
elements_in_nlte = ["Fe", "Mg"]  # can choose several elements, used ONLY if nlte_flag = True

nguess = 7.848
oguess = 7.365
element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 8.65-8.56, "N" : nguess-7.98, "O" : oguess-8.77, "Mg":-1, "Ca":-1, "Fe":-0.8, "Si":-0.5, "S":-1, "Na": -1}
                    #  "Fe" : -1.0, "Mg" : -1, "S" : -1, "Si": -1, "Na":-1, "Ca":-1, "Co":-1} 
rat = 7.18
vmac = 8.0
free_isotopes = {"8.016" : rat/(1+rat), "8.017": 0.0, "8.018": 1/(1+rat)}
include_molecules = True

# %%
lmin = 22800
lmax = 22910
# element_abundances['S'] = -1
# element_abundances['C'] = 9.75
turbospectrum_paths["line_list_path"] = "../input_files/linelists/linelist_5500K/"
wavelength, flux = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules, free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = basepath + "C2"
wavelength, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = basepath + "CN"
wavelength, syntflux_CN = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['atoms'] 
wavelength4, syntflux_atoms = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)


plt.figure(figsize=(15, 5))
# plt.axvline(22949.5, color='r', linestyle='--')
# plt.plot(wavelength, flux_c2, 'xkcd:green', lw = 2, alpha = 0.6)
plt.plot(wavelength, flux, 'xkcd:blue', lw = 3,  label="Synthetic")
plt.plot(wavelength, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
plt.plot(wavelength, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = r"CN")
plt.plot(wavelength, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = r"atoms")
# plt.errorbar(obs_wave, obs_flux, yerr=obs_err, fmt="none", ecolor="gray", alpha=0.5)
plt.plot(wavecorr*1e4, fluxcorr, "k.-", alpha=0.75, lw =1.5 ,  label="Observed")
plt.xlim(lmin, lmax)
plt.ylim(0.7, 1.1)
# Out:
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# (0.7, 1.1)

# %%
lmin = 22860
lmax = 22930
# element_abundances['S'] = -1
# element_abundances['C'] = 9.75
turbospectrum_paths["line_list_path"] = "../input_files/linelists/linelist_5500K/"
wavelength, flux = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules, free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = basepath + "C2"
wavelength, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = basepath + "CN"
wavelength, syntflux_CN = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['atoms'] 
wavelength4, syntflux_atoms = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)


plt.figure(figsize=(15, 5))
# plt.axvline(22949.5, color='r', linestyle='--')
# plt.plot(wavelength, flux_c2, 'xkcd:green', lw = 2, alpha = 0.6)
plt.plot(wavelength, flux, 'xkcd:blue', lw = 3,  label="Synthetic")
plt.plot(wavelength, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
plt.plot(wavelength, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = r"CN")
plt.plot(wavelength, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = r"atoms")
# plt.errorbar(obs_wave, obs_flux, yerr=obs_err, fmt="none", ecolor="gray", alpha=0.5)
# plt.plot(obs_wave, obs_flux, "k.-", alpha=0.75, lw =1.5 ,  label="Observed")
plt.plot(wavecorr*1e4, fluxcorr, "k.-", alpha=0.75, lw =1.5 ,  label="Observed")
plt.xlim(lmin, lmax)
plt.ylim(0.6, 1.1)
# Out:
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# (0.6, 1.1)

# %%
lmin = 23280
lmax = 23340
# element_abundances['S'] = -1
# element_abundances['C'] = 9.75
turbospectrum_paths["line_list_path"] = "../input_files/linelists/linelist_5500K/"
wavelength, flux = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules, free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = basepath + "C2"
wavelength, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)



plt.figure(figsize=(10, 5))
# plt.axvline(22949.5, color='r', linestyle='--')
# plt.plot(wavelength, flux_c2, 'xkcd:green', lw = 2, alpha = 0.6)
plt.plot(wavelength, flux, 'xkcd:blue', lw = 3,  label="Synthetic")
plt.plot(wavelength, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
# plt.errorbar(obs_wave, obs_flux, yerr=obs_err, fmt="none", ecolor="gray", alpha=0.5)
plt.plot(wavecorr*1e4, fluxcorr, "k.-", alpha=0.75, lw =1.5 ,  label="Observed")
plt.xlim(lmin, lmax)
plt.ylim(0.5, 1.1)
# Out:
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# (0.5, 1.1)

# %%
# lmin = 23760
# lmax = 23840
lmin = 24040
lmax = 24120
# element_abundances['S'] = -1
# element_abundances['C'] = 9.75
turbospectrum_paths["line_list_path"] = "../input_files/linelists/linelist_5500K/"
wavelength, flux = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules, free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = lists['12C16O'] 
wavelength, syntflux_CO16 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = lists['12C18O']
wavelength, syntflux_CO18 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)



plt.figure(figsize=(10, 5))
# plt.axvline(22949.5, color='r', linestyle='--')
# plt.plot(wavelength, flux_c2, 'xkcd:green', lw = 2, alpha = 0.6)
plt.plot(wavelength, flux, 'xkcd:blue', lw = 3,  label="Synthetic")
# plt.plot(wavelength, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
plt.plot(wavelength, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}C^{16}O$")
plt.plot(wavelength, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}C^{18}O$")
# plt.errorbar(obs_wave, obs_flux, yerr=obs_err, fmt="none", ecolor="gray", alpha=0.5)
plt.plot(wavecorr*1e4, fluxcorr, "k.-", alpha=0.75, lw =1.5 ,  label="Observed")
plt.xlim(lmin, lmax)
plt.ylim(0.5, 1.1)
# Out:
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# (0.5, 1.1)

# %%
# turbospectrum_paths = {"turbospec_path": "../turbospectrum/exec-ifx/",  # change to /exec-gf/ if gnu compiler
#                        "interpol_path": "../scripts/model_interpolators/",
#                        "model_atom_path": "../input_files/nlte_data/model_atoms/",
#                        "departure_file_path": "../input_files/nlte_data/",
#                     #    "model_atmosphere_grid_path": "../input_files/test_model_atmospheres/",
#                         "model_atmosphere_grid_path": "../input_files/hdc_model_atmospheres/",
#                        "line_list_path": ""}

# teff = 4500
# logg = 1.0
# met = 0.0
# vmic = 7.5
# lmin = np.min(obs_wave).round(2)
# lmax = 2.5e4
# # lmax = 22700
# ldelta = 0.1
# atmosphere_type = "1D"   # "1D" or "3D"
# nlte_flag = False
# elements_in_nlte = ["Fe", "Mg"]  # can choose several elements, used ONLY if nlte_flag = True

# nguess = 7.0
# oguess = 7.5
# element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 8.4-8.56, "N" : nguess-7.98, "O" : oguess-8.77, "Fe" : -1.0, "Mg" : -1, "S" : -1, "Si": -1, "Na":-1, "Ca":-1, "Co":-1, "Ti":-1} 
# rat = 60
# vmac = 4.0
# free_isotopes = {"8.016" : rat/(1+rat), "8.017": 0.0, "8.018": 1/(1+rat)}
# include_molecules = True  
lmin = np.min(obs_wave).round(2)
lmax = 2.5e4

# %%
turbospectrum_paths = {"turbospec_path": "../turbospectrum/exec-ifx/",  # change to /exec-gf/ if gnu compiler
                       "interpol_path": "../scripts/model_interpolators/",
                       "model_atom_path": "../input_files/nlte_data/model_atoms/",
                       "departure_file_path": "../input_files/nlte_data/",
                    #    "model_atmosphere_grid_path": "../input_files/test_model_atmospheres/",
                        "model_atmosphere_grid_path": "../input_files/hdc_model_atmospheres/",
                       "line_list_path": ""}

teff = 5250
logg = 1.0
met = 0.0
vmic = 6.
lmin = 2.25e4
lmax = 2.5e4
# lmax = 22700
ldelta = 0.5
atmosphere_type = "1D"   # "1D" or "3D"
nlte_flag = False
elements_in_nlte = ["Fe", "Mg"]  # can choose several elements, used ONLY if nlte_flag = True

nguess = 7.848
oguess = 7.365
element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 8.65-8.56, "N" : nguess-7.98, "O" : oguess-8.77, "Mg":-1, "Ca":-1, "Fe":-0.9, "Si":-1, "S":-0.12, "Na": -0.8, "Ti":-1, "Co":-1, "Ni":-1}
                    #  "Fe" : -1.0, "Mg" : -1, "S" : -1, "Si": -1, "Na":-1, "Ca":-1, "Co":-1} 
rat = 7.18
vmac = 8.0
free_isotopes = {"8.016" : rat/(1+rat), "8.017": 0.0, "8.018": 1/(1+rat)}
include_molecules = True

# %%
abundname = ""
abundval = ""
for element in element_abundances.keys():
    print(f"{element} : {element_abundances[element] + solar_abundances[element]}")
    abundname += f"A({element})" + "  "
    abundval += f"{element_abundances[element] + solar_abundances[element]:.{-1+len(f"A({element}")}f}" + "  "
print(abundname)
print(abundval)
# Out:
# H : 7.5
# He : 11.5
# C : 8.65
# N : 7.848
# O : 7.365
# Mg : 6.55
# Ca : 5.37
# Fe : 6.6
# Si : 6.59
# S : 7.04
# Na : 5.49
# Ti : 3.9400000000000004
# Co : 3.95
# Ni : 5.24
# A(H)  A(He)  A(C)  A(N)  A(O)  A(Mg)  A(Ca)  A(Fe)  A(Si)  A(S)  A(Na)  A(Ti)  A(Co)  A(Ni)
# 7.50  11.500  8.65  7.85  7.37  6.550  5.370  6.600  6.590  7.04  5.490  3.940  3.950  5.240

# %%
solar_abundances['Ti']
# Out:
# 4.94

# %%
turbospectrum_paths['line_list_path'] = lists['CN'] 
wavelength, syntflux_CN = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False, verbose = True)

turbospectrum_paths['line_list_path'] = lists['12C16O'] 
wavelength1, syntflux_CO16 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['12C18O'] 
wavelength2, syntflux_CO18 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['C2'] 
wavelength3, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
# Out:
# Trimming
# LINELIST WARNING! File /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../input_files/linelists/individual/CN_new/12C14N_TriHy2.plez.bz2 is not a valid linelist file
# Trimming done
# Running TS
#  *****************************
#  * begining of interpolation *
#  *****************************
#  Interpolation between :
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 1  Teff=   5250.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 2  Teff=   5250.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 3  Teff=   5250.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 4  Teff=   5250.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 5  Teff=   5250.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 6  Teff=   5250.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 7  Teff=   5250.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5250g1.0z+0.00m1.0t05ptin80
# model 8  Teff=   5250.  logg= 1.00  z=  0.00
# Interpolation point : Teff=   5250.  logg= 1.00  z=  0.00
#  optimized interpolation applied for standard composition models
#  now calculate rhox
#  now calculate error
#     estimated max error on T =  0.0 %
#    estimated max error on Pe =  0.0 %
#    estimated max error on Pg =  0.0 %
# estimated max error on kappa =  0.0 %
#  now write result
#  spherical models
#  interpolation done
#
#  ***********************
#  * BABSMA version 20.1 *
#  ***********************
#
#  Babsma.f HI k,edge(k)           2   3647.00082065685
#  Babsma.f HI k,edge(k)           3   8207.00355450638
#  Babsma.f HI k,edge(k)           4   14588.0028345939
#  Babsma.f HI k,edge(k)           5   22794.0000477878
#  Babsma.f HI k,edge(k)           6   32915.0027675573
#  PURE-LTE  :.true.
#  LAMBDA_MIN:22497.000
#  LAMBDA_MAX:25003.000
#  LAMBDA_STEP:0.500
#  MODELINPUT:
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-14-2024-13-59-14__0.7730402610538085/marcs_tef5250.0_g1.00_z0.
#  00_tur2.00.interpol
#  MARCS-FILE:.false.
#  MODELOPAC:
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-14-2024-13-59-14__0.7730402610538085/model_opacity_00000000.op
#  ac
#  METALLICITY:0.00
#  ALPHA/Fe   :0.00
#  HELIUM     :0.00
#  R-PROCESS  :0.00
#  S-PROCESS  :0.00
#  INDIVIDUAL ABUNDANCES:92
#            1   7.500000
#            2   11.50000
#            3   1.050000
#            4   1.380000
#            5   2.700000
#            6   8.650000
#            7   7.848000
#            8   7.365000
#            9   4.400000
#           10   8.160000
#           11   5.490000
#           12   6.550000
#           13   6.430000
#           14   6.590000
#           15   5.410000
#           16   7.040000
#           17   5.250000
#           18   6.400000
#           19   5.140000
#           20   5.370000
#           21   3.070000
#           22   3.940000
#           23   3.890000
#           24   5.740000
#           25   5.520000
#           26   6.600000
#           27   3.950000
#           28   5.240000
#           29   4.190000
#           30   4.560000
#           31   3.040000
#           32   3.650000
#           33   2.290000
#           34   3.330000
#           35   2.560000
#           36   3.250000
#           37   2.520000
#           38   2.870000
#           39   2.210000
#           40   2.580000
#           41   1.460000
#           42   1.880000
#           43  -99.00000
#           44   1.750000
#           45  0.9100000
#           46   1.570000
#           47  0.9400000
#           48   1.770000
#           49  0.8000000
#           50   2.040000
#           51   1.000000
#           52   2.190000
#           53   1.510000
#           54   2.240000
#           55   1.070000
#           56   2.180000
#           57   1.100000
#           58   1.580000
#           59  0.7200000
#           60   1.420000
#           61  -99.00000
#           62  0.9600000
#           63  0.5200000
#           64   1.070000
#           65  0.3000000
#           66   1.100000
#           67  0.4800000
#           68  0.9200000
#           69  0.1000000
#           70  0.8400000
#           71  0.1000000
#           72  0.8500000
#           73 -0.1700000
#           74  0.8500000
#           75  0.2300000
#           76   1.400000
#           77   1.380000
#           78   1.640000
#           79  0.9200000
#           80   1.130000
#           81  0.9000000
#           82   1.750000
#           83  0.6500000
#           84  -99.00000
#           85  -99.00000
#           86  -99.00000
#           87  -99.00000
#           88  -99.00000
#           89  -99.00000
#           90  2.0000000E-02
#           91  -99.00000
#           92 -0.5200000
#  XIFIX:T
#  Following atomic species included in molecular equilibrium:
#  H  He Li Be B  C  N  O  F  Ne
#  Na Mg Al Si P  S  Cl Ar K  Ca
#  Sc Ti V  Cr Mn Fe Co Ni Cu Zn
#  Ga Ge As Se Br Kr Rb Sr Y  Zr
#  Nb Mo Tc Ru Rh Pd Ag Cd In Sn
#  Sb Te I  Xe Cs Ba La Ce Pr Nd
#  Pm Sm Eu Gd Tb Dy Ho Er Tm Yb
#  Lu Hf Ta W  Re Os Ir Pt Au Hg
#  Tl Pb Bi Po At Rn Fr Ra Ac Th
#  Pa U
#  Found edge:    22794.0000477878        22793.5000477878
#    22794.0000477878        22794.5000477878
#         2607  wavelengths for continuum between:    22497.00      and
#    25103.00
#  ab. changed: elt            1   7.500000
#  ab. changed: elt            2   11.50000
#  ab. changed: elt            3   1.050000
#  ab. changed: elt            4   1.380000
#  ab. changed: elt            5   2.700000
#  ab. changed: elt            6   8.650000
#  ab. changed: elt            7   7.848000
#  ab. changed: elt            8   7.365000
#  ab. changed: elt            9   4.400000
#  ab. changed: elt           10   8.160000
#  ab. changed: elt           11   5.490000
#  ab. changed: elt           12   6.550000
#  ab. changed: elt           13   6.430000
#  ab. changed: elt           14   6.590000
#  ab. changed: elt           15   5.410000
#  ab. changed: elt           16   7.040000
#  ab. changed: elt           17   5.250000
#  ab. changed: elt           18   6.400000
#  ab. changed: elt           19   5.140000
#  ab. changed: elt           20   5.370000
#  ab. changed: elt           21   3.070000
#  ab. changed: elt           22   3.940000
#  ab. changed: elt           23   3.890000
#  ab. changed: elt           24   5.740000
#  ab. changed: elt           25   5.520000
#  ab. changed: elt           26   6.600000
#  ab. changed: elt           27   3.950000
#  ab. changed: elt           28   5.240000
#  ab. changed: elt           29   4.190000
#  ab. changed: elt           30   4.560000
#  ab. changed: elt           31   3.040000
#  ab. changed: elt           32   3.650000
#  ab. changed: elt           33   2.290000
#  ab. changed: elt           34   3.330000
#  ab. changed: elt           35   2.560000
#  ab. changed: elt           36   3.250000
#  ab. changed: elt           37   2.520000
#  ab. changed: elt           38   2.870000
#  ab. changed: elt           39   2.210000
#  ab. changed: elt           40   2.580000
#  ab. changed: elt           41   1.460000
#  ab. changed: elt           42   1.880000
#  ab. changed: elt           44   1.750000
#  ab. changed: elt           45  0.9100000
#  ab. changed: elt           46   1.570000
#  ab. changed: elt           47  0.9400000
#  ab. changed: elt           48   1.770000
#  ab. changed: elt           49  0.8000000
#  ab. changed: elt           50   2.040000
#  ab. changed: elt           51   1.000000
#  ab. changed: elt           52   2.190000
#  ab. changed: elt           53   1.510000
#  ab. changed: elt           54   2.240000
#  ab. changed: elt           55   1.070000
#  ab. changed: elt           56   2.180000
#  ab. changed: elt           57   1.100000
#  ab. changed: elt           58   1.580000
#  ab. changed: elt           59  0.7200000
#  ab. changed: elt           60   1.420000
#  ab. changed: elt           62  0.9600000
#  ab. changed: elt           63  0.5200000
#  ab. changed: elt           64   1.070000
#  ab. changed: elt           65  0.3000000
#  ab. changed: elt           66   1.100000
#  ab. changed: elt           67  0.4800000
#  ab. changed: elt           68  0.9200000
#  ab. changed: elt           69  0.1000000
#  ab. changed: elt           70  0.8400000
#  ab. changed: elt           71  0.1000000
#  ab. changed: elt           72  0.8500000
#  ab. changed: elt           73 -0.1700000
#  ab. changed: elt           74  0.8500000
#  ab. changed: elt           75  0.2300000
#  ab. changed: elt           76   1.400000
#  ab. changed: elt           77   1.380000
#  ab. changed: elt           78   1.640000
#  ab. changed: elt           79  0.9200000
#  ab. changed: elt           80   1.130000
#  ab. changed: elt           81  0.9000000
#  ab. changed: elt           82   1.750000
#  ab. changed: elt           83  0.6500000
#  ab. changed: elt           90  2.0000000E-02
#  ab. changed: elt           92 -0.5200000
#  babsma callinbg makeabudasp2007
#  Abundance is scaled from Asplund et al. 2007
#  metallicity changed by   0.0000000E+00  dex
#   This is an ascii model
#  sphINTERPOL                                                 56   5000.000
#    1.000000               0  0.0000000E+00
#  injon; after inquire, model format (marcsformat) is:
#  FORMATTED
#  UTPUT:          11           7
#  WARNING! we do not use the model abundances!!!
#  adopted abundances:
#    12.00000       16.00000       13.15000       12.34800       11.86500
#    12.66000       9.990000       11.05000       10.93000       11.09000
#    11.54000       9.639999       9.870000       10.24000       11.10000
#    9.740000
#  inabs done
#  ELEMENT  ATOMIC NUMBER   LOG(ABUNDANCE)
#      H             1       12.000
#      He            2       16.000
#      Li            3        5.550
#      Be            4        5.880
#      B             5        7.200
#      C             6       13.150
#      N             7       12.348
#      O             8       11.865
#      F             9        8.900
#      Ne           10       12.660
#      Na           11        9.990
#      Mg           12       11.050
#      Al           13       10.930
#      Si           14       11.090
#      P            15        9.910
#      S            16       11.540
#      Cl           17        9.750
#      Ar           18       10.900
#      K            19        9.640
#      Ca           20        9.870
#      Sc           21        7.570
#      Ti           22        8.440
#      V            23        8.390
#      Cr           24       10.240
#      Mn           25       10.020
#      Fe           26       11.100
#      Co           27        8.450
#      Ni           28        9.740
#      Cu           29        8.690
#      Zn           30        9.060
#      Ga           31        7.540
#      Ge           32        8.150
#      As           33        6.790
#      Se           34        7.830
#      Br           35        7.060
#      Kr           36        7.750
#      Rb           37        7.020
#      Sr           38        7.370
#      Y            39        6.710
#      Zr           40        7.080
#      Nb           41        5.960
#      Mo           42        6.380
#      Tc           43      -24.500
#      Ru           44        6.250
#      Rh           45        5.410
#      Pd           46        6.070
#      Ag           47        5.440
#      Cd           48        6.270
#      In           49        5.300
#      Sn           50        6.540
#      Sb           51        5.500
#      Te           52        6.690
#      I            53        6.010
#      Xe           54        6.740
#      Cs           55        5.570
#      Ba           56        6.680
#      La           57        5.600
#      Ce           58        6.080
#      Pr           59        5.220
#      Nd           60        5.920
#      Pm           61      -24.500
#      Sm           62        5.460
#      Eu           63        5.020
#      Gd           64        5.570
#      Tb           65        4.800
#      Dy           66        5.600
#      Ho           67        4.980
#      Er           68        5.420
#      Tm           69        4.600
#      Yb           70        5.340
#      Lu           71        4.600
#      Hf           72        5.350
#      Ta           73        4.330
#      W            74        5.350
#      Re           75        4.730
#      Os           76        5.900
#      Ir           77        5.880
#      Pt           78        6.140
#      Au           79        5.420
#      Hg           80        5.630
#      Tl           81        5.400
#      Pb           82        6.250
#      Bi           83        5.150
#      Po           84      -24.500
#      At           85      -24.500
#      Rn           86      -24.500
#      Fr           87      -24.500
#      Ra           88      -24.500
#      Ac           89      -24.500
#      Th           90        4.520
#      Pa           91      -24.500
#      U            92        3.980
#  MOLECPARTF. suppressing:         206  LaH                 (unknown D00)
#  MOLECPARTF. suppressing:         209  LuH                 (unknown D00)
#  MOLECPARTF. suppressing:         212  NbN                 (unknown D00)
#  MOLECPARTF. suppressing:         231  SbH                 (unknown D00)
#  MOLECPARTF. suppressing:         252  TeCl                (unknown D00)
#  MOLECPARTF. suppressing:         267  Al+ H               (unknown D00)
#  MOLECPARTF. suppressing:         267  As+ O               (unknown D00)
#  MOLECPARTF. suppressing:         269  B + O               (unknown D00)
#  H- electron affinity will be changed by -2dxi
#   data may be added in IRWIN_molecule file
#   to update older data from Tsuji
#  using Tsuji's old data for C C C H
#  using Tsuji's old data for C C N
#  using Tsuji's old data for B B O
#  using Tsuji's old data for C -
#  using Tsuji's old data for C H -
#  using Tsuji's old data for N O O -
#  using Tsuji's old data for N H H -
#  using Tsuji's old data for N N H H
#  using Tsuji's old data for N N H H H H
#  using Tsuji's old data for C N N
#  using Tsuji's old data for N C N
#  using Tsuji's old data for C C C C N N
#  using Tsuji's old data for N O O
#  using Tsuji's old data for N O O O
#  using Tsuji's old data for N N O
#  using Tsuji's old data for N N O O O O
#  using Tsuji's old data for H N O
#  using Tsuji's old data for H N O O
#  using Tsuji's old data for H N O O O
#  using Tsuji's old data for H C N O
#  using Tsuji's old data for O -
#  using Tsuji's old data for O O -
#  using Tsuji's old data for H C H O
#  using Tsuji's old data for AlO O
#  using Tsuji's old data for Si-
#  using Tsuji's old data for SiH H
#  using Tsuji's old data for SiH H H
#  using Tsuji's old data for SiSiC C
#  using Tsuji's old data for SiF F
#  using Tsuji's old data for SiClCl
#  using Tsuji's old data for P F F
#  using Tsuji's old data for S S O
#  using Tsuji's old data for S O O O
#  using Tsuji's old data for C ClCl
#  using Tsuji's old data for C ClClCl
#  using Tsuji's old data for C ClClClCl
#  using Tsuji's old data for ClO O
#  using Tsuji's old data for ClClO
#  using Tsuji's old data for S Cl
#  using Tsuji's old data for S ClCl
#  using Tsuji's old data for H ClO
#  using Tsuji's old data for C ClO
#  using Tsuji's old data for ScSc
#  using Tsuji's old data for ScN
#  using Tsuji's old data for ScO O
#  using Tsuji's old data for ScScO
#  using Tsuji's old data for TiC C
#  using Tsuji's old data for TiF
#  using Tsuji's old data for TiCl
#  using Tsuji's old data for V C C
#  using Tsuji's old data for V N
#  using Tsuji's old data for V F F
#  using Tsuji's old data for V ClCl
#  using Tsuji's old data for CrN
#  using Tsuji's old data for CrF
#  using Tsuji's old data for CrF F
#  using Tsuji's old data for CrCl
#  using Tsuji's old data for CrClCl
#  using Tsuji's old data for MnO O
#  using Tsuji's old data for MnS S
#  using Tsuji's old data for MnF F
#  using Tsuji's old data for MnClCl
#  using Tsuji's old data for FeS
#  using Tsuji's old data for FeF F
#  using Tsuji's old data for SrSrO
#  using Tsuji's old data for Y C C
#  using Tsuji's old data for Y C C C C
#  using Tsuji's old data for Y O O
#  using Tsuji's old data for Y Y O
#  using Tsuji's old data for Y F F
#  using Tsuji's old data for ZrH
#  using Tsuji's old data for ZrC C
#  using Tsuji's old data for ZrS
#  using Tsuji's old data for ZrF
#  using Tsuji's old data for ZrCl
#  using Tsuji's old data for BaBaO
#  using Tsuji's old data for LaC C
#  using Tsuji's old data for LaN
#  using Tsuji's old data for LaO O
#  using Tsuji's old data for LaLaO
#  using Tsuji's old data for LaLaO O
#  using Tsuji's old data for LaF F
#  using Tsuji's old data for CeC C
#  using Tsuji's old data for CeO O
#  using Tsuji's old data for CeS
#  using Tsuji's old data for CeF
#  using Tsuji's old data for NdC C
#  using Tsuji's old data for NdO
#  using Tsuji's old data for NdO O
#  using Tsuji's old data for NdF
#  using Tsuji's old data for NdF F
#  using Tsuji's old data for N N N H
#  using Tsuji's old data for C C H H H H H H
#  using Tsuji's old data for H C C C N
#  using Tsuji's old data for C C C C C H
#  using Tsuji's old data for C C H H H
#  using Tsuji's old data for C C C C H H H
#  using Tsuji's old data for C C C C H H H H
#  using Tsuji's old data for C C C C H
#  using Tsuji's old data for C C C C H H
#  using Tsuji's old data for C C C H H H
#  using Tsuji's old data for C C C H H
#  using Tsuji's old data for C C C C N
#  using Tsuji's old data for C H H H C N
#  using Tsuji's old data for C C C H H H H
#  using Tsuji's old data for C C C N
#  Atomic partition function data read
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  1.

#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-14-2024-13-59-14__0.7730402610538085/model_opacity_00000000.op
#  ac
#  RESULTFILE :
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-14-2024-13-59-14__0.7730402610538085//spectrum_00000000.spec
#  METALLICITY:0.00
#  ALPHA/Fe   :0.00
#  HELIUM     :0.00
#  R-PROCESS  :0.00
#  S-PROCESS  :0.00
#  INDIVIDUAL ABUNDANCES:92
#            1   7.500000
#            2   11.50000
#            3   1.050000
#            4   1.380000
#            5   2.700000
#            6   8.650000
#            7   7.848000
#            8   7.365000
#            9   4.400000
#           10   8.160000
#           11   5.490000
#           12   6.550000
#           13   6.430000
#           14   6.590000
#           15   5.410000
#           16   7.040000
#           17   5.250000
#           18   6.400000
#           19   5.140000
#           20   5.370000
#           21   3.070000
#           22   3.940000
#           23   3.890000
#           24   5.740000
#           25   5.520000
#           26   6.600000
#           27   3.950000
#           28   5.240000
#           29   4.190000
#           30   4.560000
#           31   3.040000
#           32   3.650000
#           33   2.290000
#           34   3.330000
#           35   2.560000
#           36   3.250000
#           37   2.520000
#           38   2.870000
#           39   2.210000
#           40   2.580000
#           41   1.460000
#           42   1.880000
#           43  -99.00000
#           44   1.750000
#           45  0.9100000
#           46   1.570000
#           47  0.9400000
#           48   1.770000
#           49  0.8000000
#           50   2.040000
#           51   1.000000
#           52   2.190000
#           53   1.510000
#           54   2.240000
#           55   1.070000
#           56   2.180000
#           57   1.100000
#           58   1.580000
#           59  0.7200000
#           60   1.420000
#           61  -99.00000
#           62  0.9600000
#           63  0.5200000
#           64   1.070000
#           65  0.3000000
#           66   1.100000
#           67  0.4800000
#           68  0.9200000
#           69  0.1000000
#           70  0.8400000
#           71  0.1000000
#           72  0.8500000
#           73 -0.1700000
#           74  0.8500000
#           75  0.2300000
#           76   1.400000
#           77   1.380000
#           78   1.640000
#           79  0.9200000
#           80   1.130000
#           81  0.9000000
#           82   1.750000
#           83  0.6500000
#           84  -99.00000
#           85  -99.00000
#           86  -99.00000
#           87  -99.00000
#           88  -99.00000
#           89  -99.00000
#           90  2.0000000E-02
#           91  -99.00000
#           92 -0.5200000
#  ISOTOPES :156
#  NFILES   :1
#  SPHERICAL:T
#  Following atomic species included in molecular equilibrium:
#  H  He Li Be B  C  N  O  F  Ne
#  Na Mg Al Si P  S  Cl Ar K  Ca
#  Sc Ti V  Cr Mn Fe Co Ni Cu Zn
#  Ga Ge As Se Br Kr Rb Sr Y  Zr
#  Nb Mo Tc Ru Rh Pd Ag Cd In Sn
#  Sb Te I  Xe Cs Ba La Ce Pr Nd
#  Pm Sm Eu Gd Tb Dy Ho Er Tm Yb
#  Lu Hf Ta W  Re Os Ir Pt Au Hg
#  Tl Pb Bi Po At Rn Fr Ra Ac Th
#  Pa U
#  hydrovelo, computeIplus : F F
#  T  DATA/LISTE_molecules_all_v19.1.dat
#            1  line lists:
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-14-2024-13-59-14__0.7730402610538085/linelist_for_fitting_trim
#  med/all/Nov-14-2024-13-59-15_0.45532065480297534/0/linelist-1.bsyn
#  T          30   300.0000              15   1.300000
#  dummy-output.dat
#
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-14-2024-13-59-14__0.7730402610538085/model_opacity_00000000.op
#  ac
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-14-2024-13-59-14__0.7730402610538085//spectrum_00000000.spec
#  ab. changed: elt            1   7.500000
#  ab. changed: elt            2   11.50000
#  ab. changed: elt            3   1.050000
#  ab. changed: elt            4   1.380000
#  ab. changed: elt            5   2.700000
#  ab. changed: elt            6   8.650000
#  ab. changed: elt            7   7.848000
#  ab. changed: elt            8   7.365000
#  ab. changed: elt            9   4.400000
#  ab. changed: elt           10   8.160000
#  ab. changed: elt           11   5.490000
#  ab. changed: elt           12   6.550000
#  ab. changed: elt           13   6.430000
#  ab. changed: elt           14   6.590000
#  ab. changed: elt           15   5.410000
#  ab. changed: elt           16   7.040000
#  ab. changed: elt           17   5.250000
#  ab. changed: elt           18   6.400000
#  ab. changed: elt           19   5.140000
#  ab. changed: elt           20   5.370000
#  ab. changed: elt           21   3.070000
#  ab. changed: elt           22   3.940000
#  ab. changed: elt           23   3.890000
#  ab. changed: elt           24   5.740000
#  ab. changed: elt           25   5.520000
#  ab. changed: elt           26   6.600000
#  ab. changed: elt           27   3.950000
#  ab. changed: elt           28   5.240000
#  ab. changed: elt           29   4.190000
#  ab. changed: elt           30   4.560000
#  ab. changed: elt           31   3.040000
#  ab. changed: elt           32   3.650000
#  ab. changed: elt           33   2.290000
#  ab. changed: elt           34   3.330000
#  ab. changed: elt           35   2.560000
#  ab. changed: elt           36   3.250000
#  ab. changed: elt           37   2.520000
#  ab. changed: elt           38   2.870000
#  ab. changed: elt           39   2.210000
#  ab. changed: elt           40   2.580000
#  ab. changed: elt           41   1.460000
#  ab. changed: elt           42   1.880000
#  ab. changed: elt           44   1.750000
#  ab. changed: elt           45  0.9100000
#  ab. changed: elt           46   1.570000
#  ab. changed: elt           47  0.9400000
#  ab. changed: elt           48   1.770000
#  ab. changed: elt           49  0.8000000
#  ab. changed: elt           50   2.040000
#  ab. changed: elt           51   1.000000
#  ab. changed: elt           52   2.190000
#  ab. changed: elt           53   1.510000
#  ab. changed: elt           54   2.240000
#  ab. changed: elt           55   1.070000
#  ab. changed: elt           56   2.180000
#  ab. changed: elt           57   1.100000
#  ab. changed: elt           58   1.580000
#  ab. changed: elt           59  0.7200000
#  ab. changed: elt           60   1.420000
#  ab. changed: elt           62  0.9600000
#  ab. changed: elt           63  0.5200000
#  ab. changed: elt           64   1.070000
#  ab. changed: elt           65  0.3000000
#  ab. changed: elt           66   1.100000
#  ab. changed: elt           67  0.4800000
#  ab. changed: elt           68  0.9200000
#  ab. changed: elt           69  0.1000000
#  ab. changed: elt           70  0.8400000
#  ab. changed: elt           71  0.1000000
#  ab. changed: elt           72  0.8500000
#  ab. changed: elt           73 -0.1700000
#  ab. changed: elt           74  0.8500000
#  ab. changed: elt           75  0.2300000
#  ab. changed: elt           76   1.400000
#  ab. changed: elt           77   1.380000
#  ab. changed: elt           78   1.640000
#  ab. changed: elt           79  0.9200000
#  ab. changed: elt           80   1.130000
#  ab. changed: elt           81  0.9000000
#  ab. changed: elt           82   1.750000
#  ab. changed: elt           83  0.6500000
#  ab. changed: elt           90  2.0000000E-02
#  ab. changed: elt           92 -0.5200000
#     Full molecular equilibrium, using:
#
#       DATA/LISTE_molecules_all_v19.1.dat
#
#   Transfer treated in the spherical scheme
#
#  Abundance is scaled from Asplund et al. 2007
#  metallicity changed by   0.0000000E+00  dex
#   3.006
#  ISOTOPIC fraction changed from   7.5000003E-02
#  to   7.5900003E-02  for element            3
#   3.007
#  ISOTOPIC fraction changed from   0.9250000
#  to   0.9241000      for element            3
#   5.010
#  ISOTOPIC fraction changed from   0.1990000
#  to   0.1990000      for element            5
#   5.011
#  ISOTOPIC fraction changed from   0.8010000
#  to   0.8010000      for element            5
#   6.012
#  ISOTOPIC fraction changed from   0.9890000
#  to   0.9889380      for element            6
#   6.013
#  ISOTOPIC fraction changed from   1.1000000E-02
#  to   1.1062000E-02  for element            6
#   7.014
#  ISOTOPIC fraction changed from   0.9963400
#  to   0.9977100      for element            7
#   7.015
#  ISOTOPIC fraction changed from   3.6599999E-03
#  to   2.2900000E-03  for element            7
#   8.016
#  ISOTOPIC fraction changed from   0.9976200
#  to   0.8777510      for element            8
#   8.017
#  ISOTOPIC fraction changed from   3.8000001E-04
#  to   0.0000000E+00  for element            8
#   8.018
#  ISOTOPIC fraction changed from   2.0000001E-03
#  to   0.1222490      for element            8
#  10.020
#  ISOTOPIC fraction changed from   0.9299000
#  to   0.9294310      for element           10
#  10.021
#  ISOTOPIC fraction changed from   2.2600000E-03
#  to   2.2280000E-03  for element           10
#  10.022
#  ISOTOPIC fraction changed from   6.7900002E-02
#  to   6.8341002E-02  for element           10
#  12.024
#  ISOTOPIC fraction changed from   0.7899000
#  to   0.7899000      for element           12
#  12.025
#  ISOTOPIC fraction changed from   0.1000000
#  to   0.1000000      for element           12
#  12.026
#  ISOTOPIC fraction changed from   0.1101000
#  to   0.1101000      for element           12
#  14.028
#  ISOTOPIC fraction changed from   0.9223000
#  to   0.9222970      for element           14
#  14.029
#  ISOTOPIC fraction changed from   4.6700001E-02
#  to   4.6831999E-02  for element           14
#  14.030
#  ISOTOPIC fraction changed from   3.0999999E-02
#  to   3.0872000E-02  for element           14
#  16.032
#  ISOTOPIC fraction changed from   0.9502000
#  to   0.9493000      for element           16
#  16.033
#  ISOTOPIC fraction changed from   7.4999998E-03
#  to   7.6000001E-03  for element           16
#  16.034
#  ISOTOPIC fraction changed from   4.2100001E-02
#  to   4.2900000E-02  for element           16
#  16.036
#  ISOTOPIC fraction changed from   1.9999999E-04
# ...
#  44.104
#  ISOTOPIC fraction changed from   0.1870000
#  to   0.1862000      for element           44
#  46.102
#  ISOTOPIC fraction changed from   1.0200000E-02
#  to   1.0200000E-02  for element           46
#  46.104
#  ISOTOPIC fraction changed from   0.1114000
#  to   0.1114000      for element           46
#  46.105
#  ISOTOPIC fraction changed from   0.2233000
#  to   0.2233000      for element           46
#  46.106
#  ISOTOPIC fraction changed from   0.2733000
#  to   0.2733000      for element           46
#  46.108
#  ISOTOPIC fraction changed from   0.2646000
#  to   0.2646000      for element           46
#  46.110
#  ISOTOPIC fraction changed from   0.1172000
#  ISOTOPIC fraction changed from   2.4170000E-02
#  to   2.4170000E-02  for element           56
#  56.135
#  ISOTOPIC fraction changed from   6.5920003E-02
#  to   6.5920003E-02  for element           56
#  56.136
#  ISOTOPIC fraction changed from   7.8539997E-02
#  to   7.8539997E-02  for element           56
#  56.137
#  ISOTOPIC fraction changed from   0.1123000
#  to   0.1123200      for element           56
#  56.138
#  ISOTOPIC fraction changed from   0.7170000
#  to   0.7169800      for element           56
#  63.151
#  ISOTOPIC fraction changed from   0.4780000
#  to   0.4781000      for element           63
#  63.153
#  ISOTOPIC fraction changed from   0.5220000
#  to   0.5219000      for element           63
#  old abundh:  2.4972502E-05
#  MODEL IDENTIFICATION=sphINTERPOL; MAIN PROGRAMME BSYN
#  Bsyn; k, pgmod, pg_calc, romod, ro_calc
#  ELEMENT  ATOMIC NUMBER   LOG(ABUNDANCE)
#      H             1       12.000
#      He            2       16.000
#      Li            3        5.550
#      Be            4        5.880
#      B             5        7.200
#      C             6       13.150
#      N             7       12.348
#      O             8       11.865
#      F             9        8.900
#      Ne           10       12.660
#      Na           11        9.990
#      Mg           12       11.050
#      Al           13       10.930
#      Si           14       11.090
#      P            15        9.910
#      S            16       11.540
#      Cl           17        9.750
#      Ar           18       10.900
#      K            19        9.640
#      Ca           20        9.870
#      Sc           21        7.570
#      Ti           22        8.440
#      V            23        8.390
#      Cr           24       10.240
#      Mn           25       10.020
#      Fe           26       11.100
#      Co           27        8.450
#      Ni           28        9.740
#      Cu           29        8.690
#      Zn           30        9.060
#      Ga           31        7.540
#      Ge           32        8.150
#      As           33        6.790
#      Se           34        7.830
#      Br           35        7.060
#      Kr           36        7.750
#      Rb           37        7.020
#      Sr           38        7.370
#      Y            39        6.710
#      Zr           40        7.080
#      Nb           41        5.960
#      Mo           42        6.380
#      Tc           43      -24.500
#      Ru           44        6.250
#      Rh           45        5.410
#      Pd           46        6.070
#      Ag           47        5.440
#      Cd           48        6.270
#      In           49        5.300
#      Sn           50        6.540
#      Sb           51        5.500
#      Te           52        6.690
#      I            53        6.010
#      Xe           54        6.740
#      Cs           55        5.570
#      Ba           56        6.680
#      La           57        5.600
#      Ce           58        6.080
#      Pr           59        5.220
#      Nd           60        5.920
#      Pm           61      -24.500
#      Sm           62        5.460
#      Eu           63        5.020
#      Gd           64        5.570
#      Tb           65        4.800
#      Dy           66        5.600
#      Ho           67        4.980
#      Er           68        5.420
#      Tm           69        4.600
#      Yb           70        5.340
#      Lu           71        4.600
#      Hf           72        5.350
#      Ta           73        4.330
#      W            74        5.350
#      Re           75        4.730
#      Os           76        5.900
#      Ir           77        5.880
#      Pt           78        6.140
#      Au           79        5.420
#      Hg           80        5.630
#      Tl           81        5.400
#      Pb           82        6.250
#      Bi           83        5.150
#      Po           84      -24.500
#      At           85      -24.500
#      Rn           86      -24.500
#      Fr           87      -24.500
#      Ra           88      -24.500
#      Ac           89      -24.500
#      Th           90        4.520
#      Pa           91      -24.500
#      U            92        3.980
#  MOLECPARTF. suppressing:         206  LaH                 (unknown D00)
#  MOLECPARTF. suppressing:         209  LuH                 (unknown D00)
#  MOLECPARTF. suppressing:         212  NbN                 (unknown D00)
#  MOLECPARTF. suppressing:         231  SbH                 (unknown D00)
#  MOLECPARTF. suppressing:         252  TeCl                (unknown D00)
#  MOLECPARTF. suppressing:         267  Al+ H               (unknown D00)
#  MOLECPARTF. suppressing:         267  As+ O               (unknown D00)
#  MOLECPARTF. suppressing:         269  B + O               (unknown D00)
#  H- electron affinity will be changed by -2dxi
#   data may be added in IRWIN_molecule file
#   to update older data from Tsuji
#  using Tsuji's old data for C C C H
#  using Tsuji's old data for C C N
#  using Tsuji's old data for B B O
#  using Tsuji's old data for C -
#  using Tsuji's old data for C H -
#  using Tsuji's old data for N O O -
#  using Tsuji's old data for N H H -
#  using Tsuji's old data for N N H H
#  using Tsuji's old data for N N H H H H
#  using Tsuji's old data for C N N
#  using Tsuji's old data for N C N
#  using Tsuji's old data for C C C C N N
#  using Tsuji's old data for N O O
#  using Tsuji's old data for N O O O
#  using Tsuji's old data for N N O
#  using Tsuji's old data for N N O O O O
#  using Tsuji's old data for H N O
#  using Tsuji's old data for H N O O
#  using Tsuji's old data for H N O O O
#  using Tsuji's old data for H C N O
#  using Tsuji's old data for O -
#  using Tsuji's old data for O O -
#  using Tsuji's old data for H C H O
#  using Tsuji's old data for AlO O
#  using Tsuji's old data for Si-
#  using Tsuji's old data for SiH H
#  using Tsuji's old data for SiH H H
#  using Tsuji's old data for SiSiC C
#  using Tsuji's old data for SiF F
#  using Tsuji's old data for SiClCl
#  using Tsuji's old data for P F F
#  using Tsuji's old data for S S O
#  using Tsuji's old data for S O O O
#  using Tsuji's old data for C ClCl
#  using Tsuji's old data for C ClClCl
#  using Tsuji's old data for C ClClClCl
#  using Tsuji's old data for ClO O
#  using Tsuji's old data for ClClO
#  using Tsuji's old data for S Cl
#  using Tsuji's old data for S ClCl
#  using Tsuji's old data for H ClO
#  using Tsuji's old data for C ClO
#  using Tsuji's old data for ScSc
#  using Tsuji's old data for ScN
#  using Tsuji's old data for ScO O
#  using Tsuji's old data for ScScO
#  using Tsuji's old data for TiC C
#  using Tsuji's old data for TiF
#  using Tsuji's old data for TiCl
#  using Tsuji's old data for V C C
#  using Tsuji's old data for V N
#  using Tsuji's old data for V F F
#  using Tsuji's old data for V ClCl
#  using Tsuji's old data for CrN
#  using Tsuji's old data for CrF
#  using Tsuji's old data for CrF F
#  using Tsuji's old data for CrCl
#  using Tsuji's old data for CrClCl
#  using Tsuji's old data for MnO O
#  using Tsuji's old data for MnS S
#  using Tsuji's old data for MnF F
#  using Tsuji's old data for MnClCl
#  using Tsuji's old data for FeS
#  using Tsuji's old data for FeF F
#  using Tsuji's old data for SrSrO
#  using Tsuji's old data for Y C C
#  using Tsuji's old data for Y C C C C
#  using Tsuji's old data for Y O O
#  using Tsuji's old data for Y Y O
#  using Tsuji's old data for Y F F
#  using Tsuji's old data for ZrH
#  using Tsuji's old data for ZrC C
#  using Tsuji's old data for ZrS
#  using Tsuji's old data for ZrF
#  using Tsuji's old data for ZrCl
#  using Tsuji's old data for BaBaO
#  using Tsuji's old data for LaC C
#  using Tsuji's old data for LaN
#  using Tsuji's old data for LaO O
#  using Tsuji's old data for LaLaO
#  using Tsuji's old data for LaLaO O
#  using Tsuji's old data for LaF F
#  using Tsuji's old data for CeC C
#  using Tsuji's old data for CeO O
#  using Tsuji's old data for CeS
#  using Tsuji's old data for CeF
#  using Tsuji's old data for NdC C
#  using Tsuji's old data for NdO
#  using Tsuji's old data for NdO O
#  using Tsuji's old data for NdF
#  using Tsuji's old data for NdF F
#  using Tsuji's old data for N N N H
#  using Tsuji's old data for C C H H H H H H
#  using Tsuji's old data for H C C C N
#  using Tsuji's old data for C C C C C H
#  using Tsuji's old data for C C H H H
#  using Tsuji's old data for C C C C H H H
#  using Tsuji's old data for C C C C H H H H
#  using Tsuji's old data for C C C C H
#  using Tsuji's old data for C C C C H H
#  using Tsuji's old data for C C C H H H
#  using Tsuji's old data for C C C H H
#  using Tsuji's old data for C C C C N
#  using Tsuji's old data for C H H H C N
#  using Tsuji's old data for C C C H H H H
#  using Tsuji's old data for C C C N
#  Atomic partition function data read
#  new abundh:  2.4969961E-05
#   starting scan of linelist
#  0607.012014
#  getlele C N
#  after getlele:          607 C N
#  Mass used for lines of          607 C N                  is    26.00307
# species: 0607.012014       C N                  iel:      607 ion:  1 isotopes:  12 14
#  nlines        11077
#  exomol_12C14N
#
#
#
#        11077  considered for element          607           1
#            0  lines rejected because of negative c6
#         0 LINES WERE REJECTED, ONLY LINES BETWEEN 22495.000 AND 25005.000 A CONSIDERED
#   CENTRAL WAVELENGTH= 23750.000 A
#  now solve
#        11077  lines in the interval
#  FLUX SPECTRUM BETWEEN 22497.000 A AND  25003.000 A WITH STEP 0.500 A
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed

# %%
turbospectrum_paths['line_list_path'] = lists['atoms'] 
wavelength4, syntflux_atoms = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
# Out:
# Trimming
# Trimming done
# Running TS
# TS completed

# %%
turbospectrum_paths['line_list_path'] = "../input_files/linelists/linelist_5500K/"
wavelength, syntflux_all = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)

# turbospectrum_paths['line_list_path'] = lists['C2'] 
# element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 9.5-8.56 + 0.7, "N" : nguess-7.98, "O" : 8.8-8.77, "Na" : 6.9-6.29}  # elemental abundances [X/Fe]; if not written solar scaled ones are used
# wavelength3, syntflux_C2_high = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
# Out:
# Trimming
# Trimming done
# Running TS
# TS completed

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

# for i in range(n):
    # i = 2
fig, (axs, ax2) = plt.subplots(2, 1, figsize=(15, 8))
plt.subplots_adjust(wspace=0, hspace=0)

# wav_range = [2.29, 2.30]
i = 4
buffer = 0.0005
wav_range = (wavmin + i/n*wavspan - buffer, wavmin + (i+1)/n*wavspan + buffer)

mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])
axs.set_xlim(wav_range)
ax2.set_xlim(wav_range)
axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
axs.set_ylim(0.4, 1.15)
ax2.set_ylim(0.4, 1.15)
axs.legend(fontsize=5, loc = 'upper right')
axs.set_xticklabels([])
prev_wav = 0
prev_name = ''
for idx, row in lines.iterrows():
    near = False
    same = False

    if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
        linewav = row['wav']
        # find nearest syntwave index to linewav
        idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
        thresh = 0.95
        wav_gap_thresh = 1e-4
        if syntflux_atoms[idx] < thresh:
            near = abs(prev_wav - linewav) < wav_gap_thresh
            # print(abs(prev_wav - linewav))
            # print(near)
            same = prev_name == row['name']
            if (not near) :
                axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                prev_wav, prev_name = row['wav'], row['name']
            else:
                print("too near")
ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
# offset = -5e-4
ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
# 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
ax2.legend(fontsize=5, loc = 'upper right')

# %%
# create a directory for the star name in this folder if it doesnt exist
if not os.path.exists(f"./{star}"):
    os.makedirs(f"./{star}")

# %%
for element in element_abundances.keys():
    print(f"{element} : {element_abundances[element] + solar_abundances[element]}")
# Out:
# H : 7.5
# He : 11.5
# C : 8.65
# N : 7.848
# O : 7.365
# Mg : 6.55
# Ca : 5.37
# Fe : 6.6
# Si : 6.59
# S : 7.04
# Na : 5.49
# Ti : 3.9400000000000004
# Co : 3.95
# Ni : 5.24

# %%
element_abundances
# Out:
# {'H': -4.5,
#  'He': 0.5700000000000003,
#  'C': 0.08999999999999986,
#  'N': -0.13200000000000056,
#  'O': -1.4049999999999994,
#  'Mg': -1.0,
#  'Ca': -1.0,
#  'Fe': -0.9,
#  'Si': -1.0,
#  'S': -0.12,
#  'Na': -0.8,
#  'Ti': -1.0,
#  'Co': -1.0,
#  'Ni': -1.0}

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

for i in range(n):
    # i = 2
    fig, (axs, ax2) = plt.subplots(2, 1, figsize=(15, 8))
    plt.subplots_adjust(wspace=0, hspace=0)
    buffer = 0.0005
    wav_range = (wavmin + i/n*wavspan - buffer, wavmin + (i+1)/n*wavspan + buffer)
    mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])
    axs.set_xlim(wav_range)
    ax2.set_xlim(wav_range)
    axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    # axs.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    # axs.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    # axs.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
    # axs.plot(wavelength*1e-4, syntflux_C2_high, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$+ 0.7")
    # axs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    axs.set_ylim(0.4, 1.15)
    ax2.set_ylim(0.4, 1.15)
    axs.legend(fontsize=5, loc = 'upper right')
    axs.set_xticklabels([])
    # axs.grid(which='both', linestyle='--', alpha = 0.5)

    

    # find the lines in the range
    prev_wav = 0
    prev_name = ''
    for idx, row in lines.iterrows():
        near = False
        same = False

        if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
            linewav = row['wav']
            # find nearest syntwave index to linewav
            idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
            thresh = 0.95
            wav_gap_thresh = 1e-4
            if syntflux_atoms[idx] < thresh:
                near = abs(prev_wav - linewav) < wav_gap_thresh
                same = prev_name == row['name']
                if (not near) :
                    axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    prev_wav, prev_name = row['wav'], row['name']
                else:
                    print("too near")
    ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
    # 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    ax2.legend(fontsize=5, loc = 'upper right')

    

    # save the plot
    plt.savefig(f'./{star}/atom_{i}.png', dpi=300)
    # break
    plt.close()
    # axs.close()
    # axs[i].axhline(1.0, color = 'black', lw = 0.5)
# Out:
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near

# %%
lmask_path = "/media/advait/DATA/research/rcb-project/TSFitPy/input_files/linemask_files/O/ocomb-rcb.txt"
lmask = np.loadtxt(lmask_path, unpack=True, comments=";", usecols=(0, 1, 2))
mid, left, right = lmask[0], lmask[1], lmask[2]

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

for i in range(n):

    # i = 4
    fig, (axs, ax2) = plt.subplots(2, 1, figsize=(15, 8))
    plt.subplots_adjust(wspace=0, hspace=0)
    buffer = 0.0005
    wav_range = (wavmin + i/n*wavspan - buffer, wavmin + (i+1)/n*wavspan + buffer)
    mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])

    axs.set_xlim(wav_range)
    ax2.set_xlim(wav_range)
    for line in mid:
        axs.axvline(line*1e-4, color = 'xkcd:blue', lw = 1)
        if line*1e-4 > wav_range[0] and line*1e-4 < wav_range[1]:
            axs.text(line*1e-4+0.00005, 1.02, str(line), rotation = 90, fontsize = 10, fontname = 'serif')
        # axs.text(line*1e-4, 1.05, str(line), rotation = 90, fontsize = 10, fontname = 'serif')
        ax2.axvline(line*1e-4, color = 'xkcd:blue', lw = 1)
    for line in left:
        axs.axvline(line*1e-4, color = 'xkcd:red', lw = 1)
        ax2.axvline(line*1e-4, color = 'xkcd:red', lw = 1)
    for line in right:
        axs.axvline(line*1e-4, color = 'xkcd:red', lw = 1)
        ax2.axvline(line*1e-4, color = 'xkcd:red', lw = 1)
    axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    # axs.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    # axs.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    # axs.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
    # axs.plot(wavelength*1e-4, syntflux_C2_high, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$+ 0.7")
    # axs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    axs.set_ylim(0.4, 1.15)
    ax2.set_ylim(0.4, 1.15)
    axs.legend(fontsize=5, loc = 'upper right')
    axs.set_xticklabels([])
    # axs.grid(which='both', linestyle='--', alpha = 0.5)



    

    # find the lines in the range
    prev_wav = 0
    prev_name = ''
    for idx, row in lines.iterrows():
        near = False
        same = False

        if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
            linewav = row['wav']
            # find nearest syntwave index to linewav
            idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
            thresh = 0.95
            wav_gap_thresh = 1e-4
            if syntflux_atoms[idx] < thresh:
                near = abs(prev_wav - linewav) < wav_gap_thresh
                same = prev_name == row['name']
                if (not near) :
                    axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    prev_wav, prev_name = row['wav'], row['name']
                else:
                    print("too near")
    ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
    # 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    ax2.legend(fontsize=5, loc = 'upper right')

    

    # save the plot
    plt.savefig(f'./{star}/masks/CO_{i}.png', dpi=300)
    # break
    plt.close()
    # axs.close()
    # axs[i].axhline(1.0, color = 'black', lw = 0.5)
# Out:
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

# for i in range(n):
    # i = 2
fig, (axs, ax2) = plt.subplots(2, 1, figsize=(5, 8))
plt.subplots_adjust(wspace=0, hspace=0)

# wav_range = [2.4688, 2.4702]
# l,r = wav_range

l, r = 23334.0,  23339.70 
l, r = l*1e-4, r*1e-4
wav_range = [l, r]

mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])
axs.set_xlim(wav_range)
ax2.set_xlim(wav_range)
axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
axs.set_ylim(0.4, 1.15)
ax2.set_ylim(0.4, 1.15)
axs.legend(fontsize=5, loc = 'upper right')
axs.set_xticklabels([])
prev_wav = 0
prev_name = ''
for idx, row in lines.iterrows():
    near = False
    same = False

    if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
        linewav = row['wav']
        # find nearest syntwave index to linewav
        idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
        thresh = 0.95
        wav_gap_thresh = 1e-4
        if syntflux_atoms[idx] < thresh:
            near = abs(prev_wav - linewav) < wav_gap_thresh
            same = prev_name == row['name']
            if (not near) :
                axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                prev_wav, prev_name = row['wav'], row['name']
            else:
                print("too near")
ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
# 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
ax2.legend(fontsize=5, loc = 'upper right')
print(f"{(0.5*(l+r)*1e4):.2f}  {l*1e4:.2f}  {r*1e4:.2f}")
# Out:
# 23336.85  23334.00  23339.70
