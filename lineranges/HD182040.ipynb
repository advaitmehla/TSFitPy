# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *

import scienceplots
plt.style.use('science')
plt.style.use('notebook')
import ipyparallel as ipp

# %%
observed_path = "/media/advait/DATA/research/rcb-project/TSFitPy/input_files/observed_spectra"
star = "HD182040"
observed_file = f"{observed_path}/{star}.txt"
observed_data = np.loadtxt(observed_file, unpack=True)
obs_wave, obs_flux, obs_err = observed_data[0], observed_data[1], observed_data[2]

# %%
wavecorr = obs_wave*1e-4 # + 1e-5
fluxcorr = obs_flux

# %%
from scipy import signal
fs = 100000
fc = 14000  # Cut-off frequency of the filter
w = fc / (fs / 2) # Normalize the frequency
b, a = signal.butter(5, w, 'low')
fluxcorr = signal.filtfilt(b, a, fluxcorr)
observed_file = f"{observed_path}/{star}_clean.txt"
np.savetxt(observed_file, np.array([obs_wave, obs_flux, obs_err]).T , fmt = '%.4f %.4f %.4f', delimiter = ' ')

# %%
lists = {}
basepath = "../input_files/linelists/individual/"
lists['CN'] = basepath + "CN_new"
lists['12C16O'] = basepath + "12C16O"
lists['12C18O'] = basepath + "12C18O"
lists['C2'] = basepath + "C2"
lists['atoms'] = basepath + "atoms_6000K"

# %%
lines = pd.read_csv("/media/advait/DATA/research/rcb-project/code/lineranges/atomic_6000.csv")
lines['wav'] = lines['wav']*1e-4

# %%
# obs_wave += 0.1
# # save the corrected observed spectrum
# observed_file = f"{observed_path}/{star}.txt"
# np.savetxt(observed_file, np.array([obs_wave, fluxcorr, obs_err]).T , fmt = '%.4f %.4f %.4f', delimiter = ' ')

# %%
turbospectrum_paths = {"turbospec_path": "../turbospectrum/exec-ifx/",  # change to /exec-gf/ if gnu compiler
                       "interpol_path": "../scripts/model_interpolators/",
                       "model_atom_path": "../input_files/nlte_data/model_atoms/",
                       "departure_file_path": "../input_files/nlte_data/",
                    #    "model_atmosphere_grid_path": "../input_files/test_model_atmospheres/",
                        "model_atmosphere_grid_path": "../input_files/hdc_model_atmospheres/",
                       "line_list_path": ""}

teff = 5750
logg = 1.0
met = 0.0
vmic = 6
lmin = 2.25e4
lmax = 2.5e4
# lmax = 22700
ldelta = 0.1
atmosphere_type = "1D"   # "1D" or "3D"
nlte_flag = False
elements_in_nlte = ["Fe", "Mg"]  # can choose several elements, used ONLY if nlte_flag = True

nguess =  9.084
oguess = 7.993
rat = 0.58
# element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 9.52-8.56, "N" : nguess-7.98, "O" : oguess-8.77, "Fe" : 0.0, "Mg" : -1, "S" : -1, "Si": -1, "Na":-1} 
# nguess = 
element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 9.895-8.56, "N" : nguess-7.98, "O" : oguess-8.77, "Fe":-0.45, "Mg":+0.17, "Ca":-0.51, "S":-0.15, "Si":-0.21} 

vmac = 0
free_isotopes = {"8.016" : rat/(1+rat), "8.017": 0.0, "8.018": 1/(1+rat)}
include_molecules = True

# %%
lmin = 22690
lmax = 22790
# element_abundances['S'] = -1
# element_abundances['C'] = 9.75
turbospectrum_paths["line_list_path"] = "../input_files/linelists/linelist_6000K/"
wavelength, flux = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules, free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = basepath + "C2_air"
wavelength, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)
turbospectrum_paths["line_list_path"] = basepath + "CN"
wavelength, syntflux_CN = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['atoms'] 
wavelength4, syntflux_atoms = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)


plt.figure(figsize=(15, 5))
# plt.axvline(22949.5, color='r', linestyle='--')
# plt.plot(wavelength, flux_c2, 'xkcd:green', lw = 2, alpha = 0.6)
plt.plot(wavelength, flux, 'xkcd:blue', lw = 3,  label="Synthetic")
plt.plot(wavelength, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
plt.plot(wavelength, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = r"CN")
plt.plot(wavelength, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = r"atoms")
# plt.errorbar(obs_wave, obs_flux, yerr=obs_err, fmt="none", ecolor="gray", alpha=0.5)
plt.plot(wavecorr*1e4, fluxcorr, "k.-", alpha=0.75, lw =1.5 ,  label="Observed")
plt.xlim(lmin, lmax)
plt.ylim(0.5, 1.1)
# Out:
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# (0.5, 1.1)

# %%
turbospectrum_paths = {"turbospec_path": "../turbospectrum/exec-ifx/",  # change to /exec-gf/ if gnu compiler
                       "interpol_path": "../scripts/model_interpolators/",
                       "model_atom_path": "../input_files/nlte_data/model_atoms/",
                       "departure_file_path": "../input_files/nlte_data/",
                    #    "model_atmosphere_grid_path": "../input_files/test_model_atmospheres/",
                        "model_atmosphere_grid_path": "../input_files/hdc_model_atmospheres/",
                       "line_list_path": ""}

teff = 5750
logg = 1.0
met = 0.0
vmic = 6
lmin = 2.25e4
lmax = 2.5e4
# lmax = 22700
ldelta = 0.1
atmosphere_type = "1D"   # "1D" or "3D"
nlte_flag = False
elements_in_nlte = ["Fe", "Mg"]  # can choose several elements, used ONLY if nlte_flag = True

nguess =  9.084
oguess = 7.993
rat = 0.58
# element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 9.52-8.56, "N" : nguess-7.98, "O" : oguess-8.77, "Fe" : 0.0, "Mg" : -1, "S" : -1, "Si": -1, "Na":-1} 
# nguess = 
element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 9.895-8.56, "N" : nguess-7.98, "O" : oguess-8.77, "Fe":-0.45, "Mg":+0.17, "Ca":-0.51, "S":-0.15, "Si":-0.21} 

vmac = 0
free_isotopes = {"8.016" : rat/(1+rat), "8.017": 0.0, "8.018": 1/(1+rat)}
# # free_isotopes = {"8.016" : 0.4, "8.017": 0.6, "8.018": 0.}
# free_isotopes = {"6.012" : 0.5, "6.013": 0.5, "6.014": 0.0}
include_molecules = True

# %%
free_isotopes
# Out:
# {'8.016': 0.36708860759493667, '8.017': 0.0, '8.018': 0.6329113924050632}

# %%
lmin = 23140
lmax = 23160
plt.figure(figsize=(15, 5))

turbospectrum_paths['line_list_path'] = lists['CN'] 
wavelength, syntflux_CN = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['12C16O'] 
wavelength1, syntflux_CO16 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

# turbospectrum_paths['line_list_path'] = "/home/advait/Desktop/research/rcb-project/TSFitPy/input_files/linelists/individual/12C17O"
# wavelength2, syntflux_CO18 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['C2'] 
wavelength3, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths["line_list_path"] = "../input_files/linelists/individual/atoms_6000K"
wavelength4, syntflux_atoms = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths["line_list_path"] = "../input_files/linelists/linelist_6000K/"
wavelength, flux = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules, free_isotopes, resolution=75000, macro=vmac, rotation=0, do_matplotlib_plot=False)

plt.plot(wavelength, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = r"CN")
plt.plot(wavelength1, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}C^{16}O$")
plt.plot(wavelength2, syntflux_CO18, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"$^{12}C^{18}O$")
plt.plot(wavelength3, syntflux_C2, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = r"C$_2$")
plt.plot(wavelength, flux, 'xkcd:blue', lw = 3,  label="Synthetic")
plt.plot(wavelength4, syntflux_atoms, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"atoms")
plt.plot(wavecorr*1e4, fluxcorr, "k.-", alpha=0.75, lw =1.5 ,  label="Observed")
plt.xlim(lmin, lmax)
# Out:
# Trimming
# LINELIST WARNING! File /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../input_files/linelists/individual/CN_new/12C14N_TriHy2.plez.bz2 is not a valid linelist file
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# (23140.0, 23160.0)

# %%
element_abundances
# Out:
# {'H': -4.5,
#  'He': 0.5700000000000003,
#  'C': 1.2400000000000002,
#  'N': 1.1679999999999993,
#  'O': -0.7649999999999988,
#  'Fe': -0.45,
#  'Mg': 0.17,
#  'Ca': -0.51,
#  'S': -0.15,
#  'Si': -0.21}

# %%
for element in element_abundances.keys():
    print(f"{element} : {element_abundances[element] + solar_abundances[element]}")
# Out:
# H : 7.5
# He : 11.5
# C : 9.8
# N : 9.148
# O : 8.005
# Fe : 7.05
# Mg : 7.72
# Ca : 5.86
# S : 7.01
# Si : 7.38

# %%
turbospectrum_paths['line_list_path'] = lists['CN'] 
wavelength, syntflux_CN = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['12C16O'] 
wavelength1, syntflux_CO16 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['12C18O'] 
wavelength2, syntflux_CO18 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['C2'] 
wavelength3, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)

turbospectrum_paths['line_list_path'] = lists['atoms'] 
wavelength4, syntflux_atoms = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)
# Out:
# Trimming
# LINELIST WARNING! File /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../input_files/linelists/individual/CN_new/12C14N_TriHy2.plez.bz2 is not a valid linelist file
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# Trimming done
# Running TS
# TS completed
# Trimming
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 14
#      11 wavelength3, syntflux_C2 = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)
#      13 turbospectrum_paths['line_list_path'] = lists['atoms']
# ---> 14 wavelength4, syntflux_atoms = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)
#
# File /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/scripts_for_plotting.py:480, in plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules, free_isotopes, resolution, macro, rotation, verbose, return_unnorm_flux, do_matplotlib_plot)
#     477 line_list_path_trimmed = os.path.join(line_list_path_trimmed, "all", today, '')
#     479 print("Trimming")
# --> 480 create_window_linelist([lmin - 4], [lmax + 4], turbospectrum_paths["line_list_path"], line_list_path_trimmed, include_molecules, False)
#     481 print("Trimming done")
#     483 line_list_path_trimmed = os.path.join(line_list_path_trimmed, "0", "")
#
# File /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../scripts/create_window_linelist_function.py:133, in create_window_linelist(seg_begins, seg_ends, old_path_name, new_path_name, molecules_flag, lbl, do_hydrogen)
#     130 element_wavelength_dictionary = {}
#     132 # wavelength minimum and maximum for the element (assume sorted)
# --> 133 wavelength_minimum_element: float = get_wavelength_from_array(lines_file, element_wavelength_dictionary, 0, line_number_read_file)
#     134 wavelength_maximum_element: float = get_wavelength_from_array(lines_file, element_wavelength_dictionary, number_of_lines_element - 1, line_number_read_file)
#     136 # check that ANY wavelengths are within the range at all
#
# File /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../scripts/create_window_linelist_function.py:218, in get_wavelength_from_array(array_to_search, dict_array_values, index_to_search, offset_idx)
#     208 """
#     209 Get the wavelength from the array. If it is not in the dictionary, then add it to the dictionary.
#     210 That is done because converting the string to float is expensive, so we do it only once.
#    (...)
#     215 :return: Wavelength from the array
#     216 """
#     217 if index_to_search not in dict_array_values:
# --> 218     dict_array_values[index_to_search] = float(array_to_search[index_to_search + offset_idx].strip().split()[0])
#     219 return dict_array_values[index_to_search]
#
# ValueError: could not convert string to float: "'C"

# %%
turbospectrum_paths['line_list_path'] = "../input_files/linelists/linelist_5500K/"
wavelength, syntflux_all = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False, verbose=True)

# turbospectrum_paths['line_list_path'] = lists['C2'] 
# element_abundances ={"H" : 7.5-12, "He" : 11.5-10.93, "C" : 9.5-8.56 + 0.7, "N" : nguess-7.98, "O" : 8.8-8.77, "Na" : 6.9-6.29}  # elemental abundances [X/Fe]; if not written solar scaled ones are used
# wavelength3, syntflux_C2_high = plot_synthetic_data(turbospectrum_paths, teff, logg, met, vmic, lmin, lmax, ldelta, atmosphere_type, nlte_flag, elements_in_nlte, element_abundances, include_molecules,free_isotopes, resolution=75000, macro=0, rotation=0, do_matplotlib_plot=False)
# Out:
# Trimming
# Trimming done
# Running TS
#  *****************************
#  * begining of interpolation *
#  *****************************
#  Interpolation between :
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 1  Teff=   5750.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 2  Teff=   5750.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 3  Teff=   5750.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 4  Teff=   5750.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 5  Teff=   5750.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 6  Teff=   5750.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 7  Teff=   5750.  logg= 1.00  z=  0.00
#   this model is SPHERICALLY SYMMETRIC
#  AAAA
#  s5750g1.0z+0.00m1.0t05ptiply
# model 8  Teff=   5750.  logg= 1.00  z=  0.00
# Interpolation point : Teff=   5750.  logg= 1.00  z=  0.00
#  optimized interpolation applied for standard composition models
#  now calculate rhox
#  now calculate error
#     estimated max error on T =  0.0 %
#    estimated max error on Pe =  0.0 %
#    estimated max error on Pg =  0.0 %
# estimated max error on kappa =  0.0 %
#  now write result
#  spherical models
#  interpolation done
#
#  ***********************
#  * BABSMA version 20.1 *
#  ***********************
#
#  Babsma.f HI k,edge(k)           2   3647.00082065685
#  Babsma.f HI k,edge(k)           3   8207.00355450638
#  Babsma.f HI k,edge(k)           4   14588.0028345939
#  Babsma.f HI k,edge(k)           5   22794.0000477878
#  Babsma.f HI k,edge(k)           6   32915.0027675573
#  PURE-LTE  :.true.
#  LAMBDA_MIN:22497.000
#  LAMBDA_MAX:25003.000
#  LAMBDA_STEP:0.100
#  MODELINPUT:
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/marcs_tef5750.0_g1.00_z0.0
#  0_tur2.00.interpol
#  MARCS-FILE:.false.
#  MODELOPAC:
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/model_opacity_00000000.opa
#  c
#  METALLICITY:0.00
#  ALPHA/Fe   :0.00
#  HELIUM     :0.00
#  R-PROCESS  :0.00
#  S-PROCESS  :0.00
#  INDIVIDUAL ABUNDANCES:92
#            1   7.500000
#            2   11.50000
#            3   1.050000
#            4   1.380000
#            5   2.700000
#            6   9.895000
#            7   9.084000
#            8   7.993000
#            9   4.400000
#           10   8.160000
#           11   6.290000
#           12   7.720000
#           13   6.430000
#           14   7.380000
#           15   5.410000
#           16   7.010000
#           17   5.250000
#           18   6.400000
#           19   5.140000
#           20   5.860000
#           21   3.070000
#           22   4.940000
#           23   3.890000
#           24   5.740000
#           25   5.520000
#           26   7.050000
#           27   4.950000
#           28   6.240000
#           29   4.190000
#           30   4.560000
#           31   3.040000
#           32   3.650000
#           33   2.290000
#           34   3.330000
#           35   2.560000
#           36   3.250000
#           37   2.520000
#           38   2.870000
#           39   2.210000
#           40   2.580000
#           41   1.460000
#           42   1.880000
#           43  -99.00000
#           44   1.750000
#           45  0.9100000
#           46   1.570000
#           47  0.9400000
#           48   1.770000
#           49  0.8000000
#           50   2.040000
#           51   1.000000
#           52   2.190000
#           53   1.510000
#           54   2.240000
#           55   1.070000
#           56   2.180000
#           57   1.100000
#           58   1.580000
#           59  0.7200000
#           60   1.420000
#           61  -99.00000
#           62  0.9600000
#           63  0.5200000
#           64   1.070000
#           65  0.3000000
#           66   1.100000
#           67  0.4800000
#           68  0.9200000
#           69  0.1000000
#           70  0.8400000
#           71  0.1000000
#           72  0.8500000
#           73 -0.1700000
#           74  0.8500000
#           75  0.2300000
#           76   1.400000
#           77   1.380000
#           78   1.640000
#           79  0.9200000
#           80   1.130000
#           81  0.9000000
#           82   1.750000
#           83  0.6500000
#           84  -99.00000
#           85  -99.00000
#           86  -99.00000
#           87  -99.00000
#           88  -99.00000
#           89  -99.00000
#           90  2.0000000E-02
#           91  -99.00000
#           92 -0.5200000
#  XIFIX:T
#  Following atomic species included in molecular equilibrium:
#  H  He Li Be B  C  N  O  F  Ne
#  Na Mg Al Si P  S  Cl Ar K  Ca
#  Sc Ti V  Cr Mn Fe Co Ni Cu Zn
#  Ga Ge As Se Br Kr Rb Sr Y  Zr
#  Nb Mo Tc Ru Rh Pd Ag Cd In Sn
#  Sb Te I  Xe Cs Ba La Ce Pr Nd
#  Pm Sm Eu Gd Tb Dy Ho Er Tm Yb
#  Lu Hf Ta W  Re Os Ir Pt Au Hg
#  Tl Pb Bi Po At Rn Fr Ra Ac Th
#  Pa U
#  Found edge:    22794.0000477878        22793.9000477878
#    22794.0000477878        22794.1000477878
#         2607  wavelengths for continuum between:    22497.00      and
#    25103.00
#  ab. changed: elt            1   7.500000
#  ab. changed: elt            2   11.50000
#  ab. changed: elt            3   1.050000
#  ab. changed: elt            4   1.380000
#  ab. changed: elt            5   2.700000
#  ab. changed: elt            6   9.895000
#  ab. changed: elt            7   9.084000
#  ab. changed: elt            8   7.993000
#  ab. changed: elt            9   4.400000
#  ab. changed: elt           10   8.160000
#  ab. changed: elt           11   6.290000
#  ab. changed: elt           12   7.720000
#  ab. changed: elt           13   6.430000
#  ab. changed: elt           14   7.380000
#  ab. changed: elt           15   5.410000
#  ab. changed: elt           16   7.010000
#  ab. changed: elt           17   5.250000
#  ab. changed: elt           18   6.400000
#  ab. changed: elt           19   5.140000
#  ab. changed: elt           20   5.860000
#  ab. changed: elt           21   3.070000
#  ab. changed: elt           22   4.940000
#  ab. changed: elt           23   3.890000
#  ab. changed: elt           24   5.740000
#  ab. changed: elt           25   5.520000
#  ab. changed: elt           26   7.050000
#  ab. changed: elt           27   4.950000
#  ab. changed: elt           28   6.240000
#  ab. changed: elt           29   4.190000
#  ab. changed: elt           30   4.560000
#  ab. changed: elt           31   3.040000
#  ab. changed: elt           32   3.650000
#  ab. changed: elt           33   2.290000
#  ab. changed: elt           34   3.330000
#  ab. changed: elt           35   2.560000
#  ab. changed: elt           36   3.250000
#  ab. changed: elt           37   2.520000
#  ab. changed: elt           38   2.870000
#  ab. changed: elt           39   2.210000
#  ab. changed: elt           40   2.580000
#  ab. changed: elt           41   1.460000
#  ab. changed: elt           42   1.880000
#  ab. changed: elt           44   1.750000
#  ab. changed: elt           45  0.9100000
#  ab. changed: elt           46   1.570000
#  ab. changed: elt           47  0.9400000
#  ab. changed: elt           48   1.770000
#  ab. changed: elt           49  0.8000000
#  ab. changed: elt           50   2.040000
#  ab. changed: elt           51   1.000000
#  ab. changed: elt           52   2.190000
#  ab. changed: elt           53   1.510000
#  ab. changed: elt           54   2.240000
#  ab. changed: elt           55   1.070000
#  ab. changed: elt           56   2.180000
#  ab. changed: elt           57   1.100000
#  ab. changed: elt           58   1.580000
#  ab. changed: elt           59  0.7200000
#  ab. changed: elt           60   1.420000
#  ab. changed: elt           62  0.9600000
#  ab. changed: elt           63  0.5200000
#  ab. changed: elt           64   1.070000
#  ab. changed: elt           65  0.3000000
#  ab. changed: elt           66   1.100000
#  ab. changed: elt           67  0.4800000
#  ab. changed: elt           68  0.9200000
#  ab. changed: elt           69  0.1000000
#  ab. changed: elt           70  0.8400000
#  ab. changed: elt           71  0.1000000
#  ab. changed: elt           72  0.8500000
#  ab. changed: elt           73 -0.1700000
#  ab. changed: elt           74  0.8500000
#  ab. changed: elt           75  0.2300000
#  ab. changed: elt           76   1.400000
#  ab. changed: elt           77   1.380000
#  ab. changed: elt           78   1.640000
#  ab. changed: elt           79  0.9200000
#  ab. changed: elt           80   1.130000
#  ab. changed: elt           81  0.9000000
#  ab. changed: elt           82   1.750000
#  ab. changed: elt           83  0.6500000
#  ab. changed: elt           90  2.0000000E-02
#  ab. changed: elt           92 -0.5200000
#  babsma callinbg makeabudasp2007
#  Abundance is scaled from Asplund et al. 2007
#  metallicity changed by   0.0000000E+00  dex
#   This is an ascii model
#  sphINTERPOL                                                 56   5000.000
#    1.000000               0  0.0000000E+00
#  injon; after inquire, model format (marcsformat) is:
#  FORMATTED
#  UTPUT:          11           7
#  WARNING! we do not use the model abundances!!!
#  adopted abundances:
#    12.00000       16.00000       14.39500       13.58400       12.49300
#    12.66000       10.79000       12.22000       10.93000       11.88000
#    11.51000       9.639999       10.36000       10.24000       11.55000
#    10.74000
#  inabs done
#  ELEMENT  ATOMIC NUMBER   LOG(ABUNDANCE)
#      H             1       12.000
#      He            2       16.000
#      Li            3        5.550
#      Be            4        5.880
#      B             5        7.200
#      C             6       14.395
#      N             7       13.584
#      O             8       12.493
#      F             9        8.900
#      Ne           10       12.660
#      Na           11       10.790
#      Mg           12       12.220
#      Al           13       10.930
#      Si           14       11.880
#      P            15        9.910
#      S            16       11.510
#      Cl           17        9.750
#      Ar           18       10.900
#      K            19        9.640
#      Ca           20       10.360
#      Sc           21        7.570
#      Ti           22        9.440
#      V            23        8.390
#      Cr           24       10.240
#      Mn           25       10.020
#      Fe           26       11.550
#      Co           27        9.450
#      Ni           28       10.740
#      Cu           29        8.690
#      Zn           30        9.060
#      Ga           31        7.540
#      Ge           32        8.150
#      As           33        6.790
#      Se           34        7.830
#      Br           35        7.060
#      Kr           36        7.750
#      Rb           37        7.020
#      Sr           38        7.370
#      Y            39        6.710
#      Zr           40        7.080
#      Nb           41        5.960
#      Mo           42        6.380
#      Tc           43      -24.500
#      Ru           44        6.250
#      Rh           45        5.410
#      Pd           46        6.070
#      Ag           47        5.440
#      Cd           48        6.270
#      In           49        5.300
#      Sn           50        6.540
#      Sb           51        5.500
#      Te           52        6.690
#      I            53        6.010
#      Xe           54        6.740
#      Cs           55        5.570
#      Ba           56        6.680
#      La           57        5.600
#      Ce           58        6.080
#      Pr           59        5.220
#      Nd           60        5.920
#      Pm           61      -24.500
#      Sm           62        5.460
#      Eu           63        5.020
#      Gd           64        5.570
#      Tb           65        4.800
#      Dy           66        5.600
#      Ho           67        4.980
#      Er           68        5.420
#      Tm           69        4.600
#      Yb           70        5.340
#      Lu           71        4.600
#      Hf           72        5.350
#      Ta           73        4.330
#      W            74        5.350
#      Re           75        4.730
#      Os           76        5.900
#      Ir           77        5.880
#      Pt           78        6.140
#      Au           79        5.420
#      Hg           80        5.630
#      Tl           81        5.400
#      Pb           82        6.250
#      Bi           83        5.150
#      Po           84      -24.500
#      At           85      -24.500
#      Rn           86      -24.500
#      Fr           87      -24.500
#      Ra           88      -24.500
#      Ac           89      -24.500
#      Th           90        4.520
#      Pa           91      -24.500
#      U            92        3.980
#  MOLECPARTF. suppressing:         206  LaH                 (unknown D00)
#  MOLECPARTF. suppressing:         209  LuH                 (unknown D00)
#  MOLECPARTF. suppressing:         212  NbN                 (unknown D00)
#  MOLECPARTF. suppressing:         231  SbH                 (unknown D00)
#  MOLECPARTF. suppressing:         252  TeCl                (unknown D00)
#  MOLECPARTF. suppressing:         267  Al+ H               (unknown D00)
#  MOLECPARTF. suppressing:         267  As+ O               (unknown D00)
#  MOLECPARTF. suppressing:         269  B + O               (unknown D00)
#  H- electron affinity will be changed by -2dxi
#   data may be added in IRWIN_molecule file
#   to update older data from Tsuji
#  using Tsuji's old data for C C C H
#  using Tsuji's old data for C C N
#  using Tsuji's old data for B B O
#  using Tsuji's old data for C -
#  using Tsuji's old data for C H -
#  using Tsuji's old data for N O O -
#  using Tsuji's old data for N H H -
#  using Tsuji's old data for N N H H
#  using Tsuji's old data for N N H H H H
#  using Tsuji's old data for C N N
#  using Tsuji's old data for N C N
#  using Tsuji's old data for C C C C N N
#  using Tsuji's old data for N O O
#  using Tsuji's old data for N O O O
#  using Tsuji's old data for N N O
#  using Tsuji's old data for N N O O O O
#  using Tsuji's old data for H N O
#  using Tsuji's old data for H N O O
#  using Tsuji's old data for H N O O O
#  using Tsuji's old data for H C N O
#  using Tsuji's old data for O -
#  using Tsuji's old data for O O -
#  using Tsuji's old data for H C H O
#  using Tsuji's old data for AlO O
#  using Tsuji's old data for Si-
#  using Tsuji's old data for SiH H
#  using Tsuji's old data for SiH H H
#  using Tsuji's old data for SiSiC C
#  using Tsuji's old data for SiF F
#  using Tsuji's old data for SiClCl
#  using Tsuji's old data for P F F
#  using Tsuji's old data for S S O
#  using Tsuji's old data for S O O O
#  using Tsuji's old data for C ClCl
#  using Tsuji's old data for C ClClCl
#  using Tsuji's old data for C ClClClCl
#  using Tsuji's old data for ClO O
#  using Tsuji's old data for ClClO
#  using Tsuji's old data for S Cl
#  using Tsuji's old data for S ClCl
#  using Tsuji's old data for H ClO
#  using Tsuji's old data for C ClO
#  using Tsuji's old data for ScSc
#  using Tsuji's old data for ScN
#  using Tsuji's old data for ScO O
#  using Tsuji's old data for ScScO
#  using Tsuji's old data for TiC C
#  using Tsuji's old data for TiF
#  using Tsuji's old data for TiCl
#  using Tsuji's old data for V C C
#  using Tsuji's old data for V N
#  using Tsuji's old data for V F F
#  using Tsuji's old data for V ClCl
#  using Tsuji's old data for CrN
#  using Tsuji's old data for CrF
#  using Tsuji's old data for CrF F
#  using Tsuji's old data for CrCl
#  using Tsuji's old data for CrClCl
#  using Tsuji's old data for MnO O
#  using Tsuji's old data for MnS S
#  using Tsuji's old data for MnF F
#  using Tsuji's old data for MnClCl
#  using Tsuji's old data for FeS
#  using Tsuji's old data for FeF F
#  using Tsuji's old data for SrSrO
#  using Tsuji's old data for Y C C
#  using Tsuji's old data for Y C C C C
#  using Tsuji's old data for Y O O
#  using Tsuji's old data for Y Y O
#  using Tsuji's old data for Y F F
#  using Tsuji's old data for ZrH
#  using Tsuji's old data for ZrC C
#  using Tsuji's old data for ZrS
#  using Tsuji's old data for ZrF
#  using Tsuji's old data for ZrCl
#  using Tsuji's old data for BaBaO
#  using Tsuji's old data for LaC C
#  using Tsuji's old data for LaN
#  using Tsuji's old data for LaO O
#  using Tsuji's old data for LaLaO
#  using Tsuji's old data for LaLaO O
#  using Tsuji's old data for LaF F
#  using Tsuji's old data for CeC C
#  using Tsuji's old data for CeO O
#  using Tsuji's old data for CeS
#  using Tsuji's old data for CeF
#  using Tsuji's old data for NdC C
#  using Tsuji's old data for NdO
#  using Tsuji's old data for NdO O
#  using Tsuji's old data for NdF
#  using Tsuji's old data for NdF F
#  using Tsuji's old data for N N N H
#  using Tsuji's old data for C C H H H H H H
#  using Tsuji's old data for H C C C N
#  using Tsuji's old data for C C C C C H
#  using Tsuji's old data for C C H H H
#  using Tsuji's old data for C C C C H H H
#  using Tsuji's old data for C C C C H H H H
#  using Tsuji's old data for C C C C H
#  using Tsuji's old data for C C C C H H
#  using Tsuji's old data for C C C H H H
#  using Tsuji's old data for C C C H H
#  using Tsuji's old data for C C C C N
#  using Tsuji's old data for C H H H C N
#  using Tsuji's old data for C C C H H H H
#  using Tsuji's old data for C C C N
#  Atomic partition function data read
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  2.0662293E-12  pgcalc=  0.1373292      pgmod=  0.1476726
#  H-
#   H
#  FeI
#  (H+H)
#  H2+
#  H2-
#  HeI
#  HeIff  P
#  He-
#  C_I
#  C_II
#  C_Iff
#  CIIff  P
#  C-
#  N_I
#  N_II
#  N-
#  O_I
#  O_II
#  O-
#  CO-
#  H2O-
#  MgI    P
#  MgII   O
#  AlI    O
#  AlII   O
#  SiI    P
#  SiII   O
#  CaI   bf
#  CaII   O
#  FeII
#  CHcont
#  OHcont
#  MgIff  P
#  SiIff  P
#  MeIff  O
#  H2+H2
#  He+H2
#  H2+H
#  He+H
#  e-sc
#  H-sc
#  H2sc
#  He-sc
# DATA/NHcont_Stancil_2019.dat
# tau,T,Pe,Pg,ro,P6   1  6.378E-07   3426.3  3.967E-05  1.373E-01  2.066E-12  5.602E-02
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  2.8045296E-12  pgcalc=  0.1887796      pgmod=  0.2030486
# tau,T,Pe,Pg,ro,P6   2  1.002E-06   3470.0  5.483E-05  1.888E-01  2.805E-12  7.701E-02
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  3.8788339E-12  pgcalc=  0.2646342      pgmod=  0.2849706
# tau,T,Pe,Pg,ro,P6   3  1.549E-06   3517.0  7.732E-05  2.646E-01  3.879E-12  1.079E-01
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  5.4517445E-12  pgcalc=  0.3769005      pgmod=  0.4065369
# tau,T,Pe,Pg,ro,P6   4  2.365E-06   3563.8  1.107E-04  3.769E-01  5.452E-12  1.537E-01
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  7.7261053E-12  pgcalc=  0.5411563      pgmod=  0.5849248
# tau,T,Pe,Pg,ro,P6   5  3.569E-06   3610.6  1.597E-04  5.412E-01  7.726E-12  2.207E-01
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  1.0981949E-11  pgcalc=  0.7794169      pgmod=  0.8448896
# tau,T,Pe,Pg,ro,P6   6  5.335E-06   3658.5  2.311E-04  7.794E-01  1.098E-11  3.179E-01
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  1.5631184E-11  pgcalc=   1.124621      pgmod=   1.222362
# tau,T,Pe,Pg,ro,P6   7  7.920E-06   3708.7  3.355E-04  1.125E+00  1.563E-11  4.587E-01
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  2.2246744E-11  pgcalc=   1.623965      pgmod=   1.772148
# tau,T,Pe,Pg,ro,P6   8  1.172E-05   3762.8  4.887E-04  1.624E+00  2.225E-11  6.624E-01
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  3.1686157E-11  pgcalc=   2.349460      pgmod=   2.576321
# tau,T,Pe,Pg,ro,P6   9  1.737E-05   3822.0  7.156E-04  2.349E+00  3.169E-11  9.583E-01
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  4.5163845E-11  pgcalc=   3.406013      pgmod=   3.760105
# tau,T,Pe,Pg,ro,P6  10  2.583E-05   3887.2  1.056E-03  3.406E+00  4.516E-11  1.389E+00
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  6.4377385E-11  pgcalc=   4.944197      pgmod=   5.511883
# tau,T,Pe,Pg,ro,P6  11  3.867E-05   3958.5  1.569E-03  4.944E+00  6.438E-11  2.017E+00
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=  7.6841464E-11  pgcalc=   5.960441      pgmod=   6.689598
# tau,T,Pe,Pg,ro,P6  12  4.747E-05   3998.0  1.923E-03  5.960E+00  7.684E-11  2.431E+00
#  WARNING ! calculated gas pressure difference > 3%
#  model rocalc=

#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/SPECIES_LTE_NLTE_00000000.
#  dat
#  LAMBDA_MIN:22497.000
#  LAMBDA_MAX:25003.000
#  LAMBDA_STEP:0.100
#  INTENSITY/FLUX:Flux
#  COS(THETA)    :1.00
#  ABFIND        :.false.
#  MODELOPAC:
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/model_opacity_00000000.opa
#  c
#  RESULTFILE :
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434//spectrum_00000000.spec
#  METALLICITY:0.00
#  ALPHA/Fe   :0.00
#  HELIUM     :0.00
#  R-PROCESS  :0.00
#  S-PROCESS  :0.00
#  INDIVIDUAL ABUNDANCES:92
#            1   7.500000
#            2   11.50000
#            3   1.050000
#            4   1.380000
#            5   2.700000
#            6   9.895000
#            7   9.084000
#            8   7.993000
#            9   4.400000
#           10   8.160000
#           11   6.290000
#           12   7.720000
#           13   6.430000
#           14   7.380000
#           15   5.410000
#           16   7.010000
#           17   5.250000
#           18   6.400000
#           19   5.140000
#           20   5.860000
#           21   3.070000
#           22   4.940000
#           23   3.890000
#           24   5.740000
#           25   5.520000
#           26   7.050000
#           27   4.950000
#           28   6.240000
#           29   4.190000
#           30   4.560000
#           31   3.040000
#           32   3.650000
#           33   2.290000
#           34   3.330000
#           35   2.560000
#           36   3.250000
#           37   2.520000
#           38   2.870000
#           39   2.210000
#           40   2.580000
#           41   1.460000
#           42   1.880000
#           43  -99.00000
#           44   1.750000
#           45  0.9100000
#           46   1.570000
#           47  0.9400000
#           48   1.770000
#           49  0.8000000
#           50   2.040000
#           51   1.000000
#           52   2.190000
#           53   1.510000
#           54   2.240000
#           55   1.070000
#           56   2.180000
#           57   1.100000
#           58   1.580000
#           59  0.7200000
#           60   1.420000
#           61  -99.00000
#           62  0.9600000
#           63  0.5200000
#           64   1.070000
#           65  0.3000000
#           66   1.100000
#           67  0.4800000
#           68  0.9200000
#           69  0.1000000
#           70  0.8400000
#           71  0.1000000
#           72  0.8500000
#           73 -0.1700000
#           74  0.8500000
#           75  0.2300000
#           76   1.400000
#           77   1.380000
#           78   1.640000
#           79  0.9200000
#           80   1.130000
#           81  0.9000000
#           82   1.750000
#           83  0.6500000
#           84  -99.00000
#           85  -99.00000
#           86  -99.00000
#           87  -99.00000
#           88  -99.00000
#           89  -99.00000
#           90  2.0000000E-02
#           91  -99.00000
#           92 -0.5200000
#  ISOTOPES :156
#  NFILES   :19
#  SPHERICAL:T
#  Following atomic species included in molecular equilibrium:
#  H  He Li Be B  C  N  O  F  Ne
#  Na Mg Al Si P  S  Cl Ar K  Ca
#  Sc Ti V  Cr Mn Fe Co Ni Cu Zn
#  Ga Ge As Se Br Kr Rb Sr Y  Zr
#  Nb Mo Tc Ru Rh Pd Ag Cd In Sn
#  Sb Te I  Xe Cs Ba La Ce Pr Nd
#  Pm Sm Eu Gd Tb Dy Ho Er Tm Yb
#  Lu Hf Ta W  Re Os Ir Pt Au Hg
#  Tl Pb Bi Po At Rn Fr Ra Ac Th
#  Pa U
#  hydrovelo, computeIplus : F F
#  T  DATA/LISTE_molecules_all_v19.1.dat
#           19  line lists:
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-0.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-1.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-10.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-11.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-13.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-14.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-16.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-17.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-19.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-20.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-22.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-24.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-26.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-4.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-5.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-6.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-7.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-8.bsyn
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/linelist_for_fitting_trimm
#  ed/all/Nov-23-2024-20-00-36_0.9273353845421842/0/linelist-9.bsyn
#  T          30   300.0000              15   1.300000
#  dummy-output.dat
#
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434/model_opacity_00000000.opa
#  c
#  /media/advait/DATA/research/rcb-project/TSFitPy/lineranges/../temp_directory/te
#  mp_directory_Nov-23-2024-20-00-36__0.836539721460434//spectrum_00000000.spec
#  ab. changed: elt            1   7.500000
#  ab. changed: elt            2   11.50000
#  ab. changed: elt            3   1.050000
#  ab. changed: elt            4   1.380000
#  ab. changed: elt            5   2.700000
#  ab. changed: elt            6   9.895000
#  ab. changed: elt            7   9.084000
#  ab. changed: elt            8   7.993000
#  ab. changed: elt            9   4.400000
#  ab. changed: elt           10   8.160000
#  ab. changed: elt           11   6.290000
#  ab. changed: elt           12   7.720000
#  ab. changed: elt           13   6.430000
#  ab. changed: elt           14   7.380000
#  ab. changed: elt           15   5.410000
#  ab. changed: elt           16   7.010000
#  ab. changed: elt           17   5.250000
#  ab. changed: elt           18   6.400000
#  ab. changed: elt           19   5.140000
#  ab. changed: elt           20   5.860000
#  ab. changed: elt           21   3.070000
#  ab. changed: elt           22   4.940000
#  ab. changed: elt           23   3.890000
#  ab. changed: elt           24   5.740000
#  ab. changed: elt           25   5.520000
#  ab. changed: elt           26   7.050000
#  ab. changed: elt           27   4.950000
#  ab. changed: elt           28   6.240000
#  ab. changed: elt           29   4.190000
#  ab. changed: elt           30   4.560000
#  ab. changed: elt           31   3.040000
#  ab. changed: elt           32   3.650000
#  ab. changed: elt           33   2.290000
#  ab. changed: elt           34   3.330000
#  ab. changed: elt           35   2.560000
#  ab. changed: elt           36   3.250000
#  ab. changed: elt           37   2.520000
#  ab. changed: elt           38   2.870000
#  ab. changed: elt           39   2.210000
#  ab. changed: elt           40   2.580000
#  ab. changed: elt           41   1.460000
#  ab. changed: elt           42   1.880000
#  ab. changed: elt           44   1.750000
#  ab. changed: elt           45  0.9100000
#  ab. changed: elt           46   1.570000
#  ab. changed: elt           47  0.9400000
#  ab. changed: elt           48   1.770000
#  ab. changed: elt           49  0.8000000
#  ab. changed: elt           50   2.040000
#  ab. changed: elt           51   1.000000
#  ab. changed: elt           52   2.190000
#  ab. changed: elt           53   1.510000
#  ab. changed: elt           54   2.240000
#  ab. changed: elt           55   1.070000
#  ab. changed: elt           56   2.180000
#  ab. changed: elt           57   1.100000
#  ab. changed: elt           58   1.580000
#  ab. changed: elt           59  0.7200000
#  ab. changed: elt           60   1.420000
#  ab. changed: elt           62  0.9600000
#  ab. changed: elt           63  0.5200000
#  ab. changed: elt           64   1.070000
#  ab. changed: elt           65  0.3000000
#  ab. changed: elt           66   1.100000
#  ab. changed: elt           67  0.4800000
#  ab. changed: elt           68  0.9200000
#  ab. changed: elt           69  0.1000000
#  ab. changed: elt           70  0.8400000
# ...
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#          759  considered for element          608           1
#            0  lines rejected because of negative c6
#   starting scan of linelist
#  0608.012018
#  getlele C O
#  after getlele:          608 C O
#  Mass used for lines of          608 C O                  is    29.99916
# species: 0608.012018       C O                  iel:      608 ion:  1 isotopes:  12 18
#  nlines          618
#  ../CO/linelist/CO_all_Goorvitch.linelist
#
#
#
#          618  considered for element          608           1
#            0  lines rejected because of negative c6
#   starting scan of linelist
#  0608.013016
#  getlele C O
#  after getlele:          608 C O
#  Mass used for lines of          608 C O                  is    28.99827
# species: 0608.013016       C O                  iel:      608 ion:  1 isotopes:  13 16
#  nlines          660
#  ../CO/linelist/CO_all_Goorvitch.linelist
#
#
#
#          660  considered for element          608           1
#            0  lines rejected because of negative c6
#   starting scan of linelist
#  0608.013017
#  getlele C O
#  after getlele:          608 C O
#  Mass used for lines of          608 C O                  is    30.00249
# species: 0608.013017       C O                  iel:      608 ion:  1 isotopes:  13 17
#  nlines          508
#  ../CO/linelist/CO_all_Goorvitch.linelist
#
#
#
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#  Bsyn. WARNING!, ntot=0 for species: C O
#  atom=           8  isotope=          17
#  isotopfrac =  0.0000000E+00
#          508  considered for element          608           1
#            0  lines rejected because of negative c6
#   starting scan of linelist
#  0608.013018
#  getlele C O
#  after getlele:          608 C O
#  Mass used for lines of          608 C O                  is    31.00252
# species: 0608.013018       C O                  iel:      608 ion:  1 isotopes:  13 18
#  nlines          373
#  ../CO/linelist/CO_all_Goorvitch.linelist
#
#
#
#          373  considered for element          608           1
#            0  lines rejected because of negative c6
#       126 LINES WERE REJECTED, ONLY LINES BETWEEN 22495.000 AND 25005.000 A CONSIDERED
#   CENTRAL WAVELENGTH= 23750.000 A
#  now solve
#        57149  lines in the interval
#  FLUX SPECTRUM BETWEEN 22497.000 A AND  25003.000 A WITH STEP 0.100 A
# TS completed

# %%
plt.figure(figsize=(10, 4))
l, r = 23755,  23810
l, r = l*1e-4, r*1e-4
mask = (wavecorr > l) & (wavecorr < r) 
plt.xlim(l,r)
plt.ylim(0.6, 1.1)
plt.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
plt.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
# plt.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
plt.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
plt.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
plt.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

# for i in range(n):
    # i = 2
fig, (axs, ax2) = plt.subplots(2, 1, figsize=(15, 8))
plt.subplots_adjust(wspace=0, hspace=0)

# wav_range = [2.29, 2.30]
i = 1
buffer = 0.0005
wav_range = (wavmin + i/n*wavspan - buffer, wavmin + (i+1)/n*wavspan + buffer)

mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])
axs.set_xlim(wav_range)
ax2.set_xlim(wav_range)
axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
f = 0.1
fluxcorr2 = (fluxcorr - f)/(1-f)
# ax2.plot(wavecorr[mask], fluxcorr2[mask], "r.-", lw = 1, alpha=0.75)
# axs.plot(wavecorr[mask], fluxcorr2[mask], "r.-", lw = 1, alpha=0.75)

axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
axs.set_ylim(0.4, 1.15)
ax2.set_ylim(0.4, 1.15)
axs.legend(fontsize=5, loc = 'upper right')
axs.set_xticklabels([])
prev_wav = 0
prev_name = ''
for idx, row in lines.iterrows():
    near = False
    same = False

    if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
        linewav = row['wav']
        # find nearest syntwave index to linewav
        idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
        thresh = 0.95
        wav_gap_thresh = 1e-4
        if syntflux_atoms[idx] < thresh:
            near = abs(prev_wav - linewav) < wav_gap_thresh
            # print(abs(prev_wav - linewav))
            # print(near)
            same = prev_name == row['name']
            if (not near) :
                axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                prev_wav, prev_name = row['wav'], row['name']
            else:
                print("too near")
ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
# offset = -5e-4
ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
# 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
ax2.legend(fontsize=5, loc = 'upper right')

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

# for i in range(n):
    # i = 2
fig, (axs, ax2) = plt.subplots(2, 1, figsize=(15, 8))
plt.subplots_adjust(wspace=0, hspace=0)

# wav_range = [2.29, 2.30]
i = 8
buffer = 0.0005
wav_range = (wavmin + i/n*wavspan - buffer, wavmin + (i+1)/n*wavspan + buffer)

mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])
axs.set_xlim(wav_range)
ax2.set_xlim(wav_range)
axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
f = 0.1
fluxcorr2 = (fluxcorr - f)/(1-f)
# ax2.plot(wavecorr[mask], fluxcorr2[mask], "r.-", lw = 1, alpha=0.75)
# axs.plot(wavecorr[mask], fluxcorr2[mask], "r.-", lw = 1, alpha=0.75)

axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
axs.set_ylim(0.6, 1.15)
ax2.set_ylim(0.6, 1.15)
axs.legend(fontsize=5, loc = 'upper right')
axs.set_xticklabels([])
prev_wav = 0
prev_name = ''
for idx, row in lines.iterrows():
    near = False
    same = False

    if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
        linewav = row['wav']
        # find nearest syntwave index to linewav
        idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
        thresh = 0.95
        wav_gap_thresh = 1e-4
        if syntflux_atoms[idx] < thresh:
            near = abs(prev_wav - linewav) < wav_gap_thresh
            # print(abs(prev_wav - linewav))
            # print(near)
            same = prev_name == row['name']
            if (not near) :
                axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                prev_wav, prev_name = row['wav'], row['name']
            else:
                print("too near")
ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
# offset = -5e-4
ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
# 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
ax2.legend(fontsize=5, loc = 'upper right')
# Out:
# too near

# %%
# create a directory for the star name in this folder if it doesnt exist
if not os.path.exists(f"./{star}"):
    os.makedirs(f"./{star}")

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

for i in range(n):
    # i = 2
    fig, (axs, ax2) = plt.subplots(2, 1, figsize=(15, 8))
    plt.subplots_adjust(wspace=0, hspace=0)
    buffer = 0.0005
    wav_range = (wavmin + i/n*wavspan - buffer, wavmin + (i+1)/n*wavspan + buffer)
    mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])
    axs.set_xlim(wav_range)
    ax2.set_xlim(wav_range)
    axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    # axs.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    # axs.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    # axs.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
    # axs.plot(wavelength*1e-4, syntflux_C2_high, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$+ 0.7")
    # axs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    axs.set_ylim(0.6, 1.15)
    ax2.set_ylim(0.6, 1.15)
    axs.legend(fontsize=5, loc = 'upper right')
    axs.set_xticklabels([])
    # axs.grid(which='both', linestyle='--', alpha = 0.5)

    

    # find the lines in the range
    prev_wav = 0
    prev_name = ''
    for idx, row in lines.iterrows():
        near = False
        same = False

        if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
            linewav = row['wav']
            # find nearest syntwave index to linewav
            idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
            thresh = 0.95
            wav_gap_thresh = 1e-4
            if syntflux_atoms[idx] < thresh:
                near = abs(prev_wav - linewav) < wav_gap_thresh
                same = prev_name == row['name']
                if (not near) :
                    axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    prev_wav, prev_name = row['wav'], row['name']
                else:
                    print("too near")
    ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
    # 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    ax2.legend(fontsize=5, loc = 'upper right')

    

    # save the plot
    plt.savefig(f'./{star}/atom_{i}.png', dpi=300)
    # break
    plt.close()
    # axs.close()
    # axs[i].axhline(1.0, color = 'black', lw = 0.5)
# Out:
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near

# %%
# create a directory for the star name in this folder if it doesnt exist
if not os.path.exists(f"./{star}/masks"):
    os.makedirs(f"./{star}/masks")

# %%
lmask_path = "/media/advait/DATA/research/rcb-project/TSFitPy/input_files/linemask_files/O/o16+o18_hdc_weak.txt"
lmask = np.loadtxt(lmask_path, unpack=True, comments=";")
mid, left, right = lmask[0], lmask[1], lmask[2]

# %%
n = 20

mask = wavecorr < 2.5
fluxcorr = fluxcorr[mask]
wavecorr = wavecorr[mask]
wavmin = np.min(wavecorr)
wavspan = np.max(wavecorr)-np.min(wavecorr)

for i in range(n):
    # i = 4
    fig, (axs, ax2) = plt.subplots(2, 1, figsize=(15, 8))
    plt.subplots_adjust(wspace=0, hspace=0)
    buffer = 0.0005
    wav_range = (wavmin + i/n*wavspan - buffer, wavmin + (i+1)/n*wavspan + buffer)
    mask = (wavecorr > wav_range[0]) & (wavecorr < wav_range[1])
    axs.set_xlim(wav_range)
    ax2.set_xlim(wav_range)
    axs.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    # axs.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    # axs.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    # axs.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    axs.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
    # axs.plot(wavelength*1e-4, syntflux_C2_high, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$+ 0.7")
    # axs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    axs.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    axs.set_ylim(0.65, 1.15)
    ax2.set_ylim(0.65, 1.15)
    axs.legend(fontsize=5, loc = 'upper right')
    axs.set_xticklabels([])
    # axs.grid(which='both', linestyle='--', alpha = 0.5)

    for line in mid:
        axs.axvline(line*1e-4, color = 'xkcd:blue', lw = 2)
        if line*1e-4 > wav_range[0] and line*1e-4 < wav_range[1]:
            axs.text(line*1e-4+0.00005, 1.02, str(line), rotation = 90, fontsize = 10, fontname = 'serif')
        # axs.text(line*1e-4, 1.05, str(line), rotation = 90, fontsize = 10, fontname = 'serif')
        ax2.axvline(line*1e-4, color = 'xkcd:blue', lw = 2)
    for line in left:
        axs.axvline(line*1e-4, color = 'xkcd:red', lw = 2)
        ax2.axvline(line*1e-4, color = 'xkcd:red', lw = 2)
    for line in right:
        axs.axvline(line*1e-4, color = 'xkcd:red', lw = 2)
        ax2.axvline(line*1e-4, color = 'xkcd:red', lw = 2)

    

    # find the lines in the range
    prev_wav = 0
    prev_name = ''
    for idx, row in lines.iterrows():
        near = False
        same = False

        if row['wav'] > wav_range[0] and row['wav'] < wav_range[1]:
            linewav = row['wav']
            # find nearest syntwave index to linewav
            idx = np.argmin(np.abs(wavelength*1e-4 - linewav))
            thresh = 0.95
            wav_gap_thresh = 1e-4
            if syntflux_atoms[idx] < thresh:
                near = abs(prev_wav - linewav) < wav_gap_thresh
                same = prev_name == row['name']
                if (not near) :
                    axs.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    axs.text(row['wav']+5e-5, 1.05, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    ax2.axvline(row['wav'], color = 'xkcd:gray', linestyle='--', lw=1)
                    # ax2.text(row['wav']+5e-5, 1.15, row['name'], rotation = 90, fontsize = 10, fontname = 'serif')
                    prev_wav, prev_name = row['wav'], row['name']
                else:
                    print("too near")
    ax2.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
    ax2.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
    ax2.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
    ax2.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
    ax2.plot(wavelength*1e-4, syntflux_C2, lw = 2.5, c = 'xkcd:purple', alpha = 0.76, label = r"C$_2$")
    # 2xs.plot(syntwave_CH*1e-4, syntflux_CH, lw = 2.5, c = 'xkcd:pink', alpha = 0.76, label = "CH")
    ax2.plot(wavelength*1e-4, syntflux_atoms, lw = 2.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
    ax2.legend(fontsize=5, loc = 'upper right')

    

    # save the plot
    plt.savefig(f'./{star}/masks/CO_{i}.png', dpi=300)
    # break
    plt.close()
    # axs.close()
    # axs[i].axhline(1.0, color = 'black', lw = 0.5)
# Out:
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near
# too near

# %%
plt.figure(figsize=(7, 8))
l, r = 24247, 24249
l, r = l*1e-4, r*1e-4
mask = (wavecorr > l) & (wavecorr < r) 
plt.xlim(l,r)

plt.plot(wavecorr[mask], fluxcorr[mask], "k.-", lw = 1, alpha=0.75)
plt.plot(wavelength*1e-4, syntflux_all, lw = 2.5, c = 'xkcd:azure', alpha = 0.9, label = r"full")
plt.plot(wavelength*1e-4, syntflux_atoms, lw = 1.5, c = 'xkcd:orange', alpha = 0.76, label = "Atoms")
plt.plot(wavelength*1e-4, syntflux_CO16, lw = 2.5, c = 'xkcd:blue', alpha = 0.76, label = r"$^{12}$C$^{16}$O")
plt.plot(wavelength*1e-4, syntflux_CO18, lw = 2.5, c = 'xkcd:red', alpha = 0.76, label = r"$^{12}$C$^{18}$O")
plt.plot(wavelength*1e-4, syntflux_CN, lw = 2.5, c = 'xkcd:green', alpha = 0.76, label = "CN")
l, r = l*1e4, r*1e4
c = 0.5*(l+r)
print(f"{c:.2f}  {l:.2f}  {r:.2f}")
# Out:
# 24248.00  24247.00  24249.00
