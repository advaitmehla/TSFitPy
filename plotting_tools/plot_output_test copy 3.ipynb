# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *

# %%
# CHANGE NEXT LINE
output_folder_location: str = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/Sep-11-2024-01-53-36_0.632429639715436_LTE_O_1D" # CHANGE
# output_folder_location: str = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/Aug-27-2024-16-16-16_0.2522569805601429_LTE_N_1D" # CHANGE
# loads all data from config file and output, config is copied into output folder with name "configuration.txt" from now on
config_dict = load_output_data(output_folder_location)
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_results_pd_df = config_dict["output_file_df"]   # Pandas dataframe for your own use
print("Column names are:")
print(output_results_pd_df.columns.values)             # Column names if you want to plot them
output_results_pd_df
# Out:
# Column names are:
# ['specname' 'wave_center' 'wave_start' 'wave_end'
#  'Doppler_Shift_add_to_RV' 'Fe_H' 'O_Fe' 'Microturb' 'Macroturb'
#  'rotation' 'chi_squared' 'ew' 'flag_error' 'flag_warning']
#         specname  wave_center  wave_start  wave_end  Doppler_Shift_add_to_RV  \
# 0   HD137613.txt     22940.75    22939.00   22942.5                  -0.8099
# 1   HD137613.txt     22947.40    22946.00   22948.8                  -0.7445
# 2   HD137613.txt     22966.00    22964.60   22967.4                  -0.6142
# 3   HD137613.txt     22971.30    22969.50   22973.1                  -1.5755
# 4   HD137613.txt     22978.50    22976.70   22980.3                  -0.5304
# 5   HD137613.txt     23006.20    23004.50   23007.9                  -1.1416
# 6   HD137613.txt     23015.25    23013.90   23016.6                  -1.0774
# 7   HD137613.txt     23083.90    23082.00   23085.8                  -0.0610
# 8   HD137613.txt     23118.90    23117.00   23120.8                  -1.0870
# ...

# %%
output_results_pd_df = config_dict["output_file_df"]   # Pandas dataframe for your own use
print("Column names are:")
print(output_results_pd_df.columns.values)             # Column names if you want to plot them
output_results_pd_df
# Out:
# Column names are:
# ['specname' 'wave_center' 'wave_start' 'wave_end'
#  'Doppler_Shift_add_to_RV' 'Fe_H' 'O_Fe' 'Microturb' 'Macroturb'
#  'rotation' 'chi_squared' 'ew' 'flag_error' 'flag_warning']
#         specname  wave_center  wave_start  wave_end  Doppler_Shift_add_to_RV  \
# 0   HD137613.txt     22940.75    22939.00   22942.5                  -0.8099
# 1   HD137613.txt     22947.40    22946.00   22948.8                  -0.7445
# 2   HD137613.txt     22966.00    22964.60   22967.4                  -0.6142
# 3   HD137613.txt     22971.30    22969.50   22973.1                  -1.5755
# 4   HD137613.txt     22978.50    22976.70   22980.3                  -0.5304
# 5   HD137613.txt     23006.20    23004.50   23007.9                  -1.1416
# 6   HD137613.txt     23015.25    23013.90   23016.6                  -1.0774
# 7   HD137613.txt     23083.90    23082.00   23085.8                  -0.0610
# 8   HD137613.txt     23118.90    23117.00   23120.8                  -1.0870
# ...

# %%
# can plot your own results using column names from the data frame
# can also take any extra arguments just like plt.scatter, example with color='black' is shown below
# can also add e.g. xlim=(-5, 5) or ylim=(-1, 1) for x and y limits
# CHANGE COLUMN NAMES IF NEEDED
element = "O_Fe"
plot_scatter_df_results(output_results_pd_df, element, "chi_squared", color='black')
# works in similar way, but plots the density map with the desired cmap
# s=10 stands for point size
plot_density_df_results(output_results_pd_df, element, "chi_squared", s=10, cmap="plasma_r", alpha=0.5)
# also histogram if needed as well
plot_histogram_df_results(output_results_pd_df, element, color='grey', bins=20, alpha=0.5, histtype='bar', ec='black')

# %%
config_dict
# Out:
# {'filenames_output_folder': ['/media/advait/DATA/research/rcb-project/TSFitPy/output_files/Sep-11-2024-01-53-36_0.632429639715436_LTE_O_1D/result_spectrum_HD137613.txt_convolved.spec'],
#  'linemask_location': '/media/advait/DATA/research/rcb-project/TSFitPy/output_files/Sep-11-2024-01-53-36_0.632429639715436_LTE_O_1D/linemask.txt',
#  'observed_spectra_location': '/media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/.././input_files/observed_spectra/',
#  'specname_fitlist': array(['HD137613.txt'], dtype=object),
#  'rv_fitlist': array([0.]),
#  'output_folder_location': '/media/advait/DATA/research/rcb-project/TSFitPy/output_files/Sep-11-2024-01-53-36_0.632429639715436_LTE_O_1D',
#  'output_file_df':         specname  wave_center  wave_start  wave_end  Doppler_Shift_add_to_RV  \
#  0   HD137613.txt     22940.75    22939.00   22942.5                  -0.8099
#  1   HD137613.txt     22947.40    22946.00   22948.8                  -0.7445
# ...

# %%
# CHANGE NEXT LINE
star_name_to_plot: str = "HD137613.txt" # CHANGEq
# plots all fitted lines for the requested star
wavelength, flux, wavelength_observed_rv, flux_observed = plot_one_star(config_dict, star_name_to_plot, plot_title=True)

# %%
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 20])
output_trimmed = output_trimmed.reset_index(drop=True)
plot_scatter_df_results(output_trimmed, element, "chi_squared", color='black')
# works in similar way, but plots the density map with the desired cmap
# s=10 stands for point size
plot_density_df_results(output_trimmed, element, "chi_squared", s=10, cmap="plasma_r", alpha=0.5)
# also histogram if needed as well
plot_histogram_df_results(output_trimmed, element, color='grey', bins=20, alpha=0.5, histtype='bar', ec='black')

# %%
output_trimmed
# Out:
#         specname  wave_center  wave_start  wave_end  Doppler_Shift_add_to_RV  \
# 0   HD137613.txt     22940.75    22939.00   22942.5                  -0.8099
# 1   HD137613.txt     22947.40    22946.00   22948.8                  -0.7445
# 2   HD137613.txt     22966.00    22964.60   22967.4                  -0.6142
# 3   HD137613.txt     22971.30    22969.50   22973.1                  -1.5755
# 4   HD137613.txt     22978.50    22976.70   22980.3                  -0.5304
# 5   HD137613.txt     23006.20    23004.50   23007.9                  -1.1416
# 6   HD137613.txt     23015.25    23013.90   23016.6                  -1.0774
# 7   HD137613.txt     23083.90    23082.00   23085.8                  -0.0610
# 8   HD137613.txt     23118.90    23117.00   23120.8                  -1.0870
# 9   HD137613.txt     23170.70    23169.70   23171.7                  -1.0058
# 10  HD137613.txt     23261.30    23259.40   23263.2                  -1.6600
# ...

# %%
np.average(output_trimmed[element])+8.77
# Out:
# 8.4165

# %%
np.std(output_trimmed[element])
# Out:
# 0.05453348614485517

# %%
output_trimmed.sort_values(by='wave_center')
# Out:
#         specname  wave_center  wave_start  wave_end  Doppler_Shift_add_to_RV  \
# 0   HD137613.txt     22940.75    22939.00   22942.5                  -0.8099
# 1   HD137613.txt     22947.40    22946.00   22948.8                  -0.7445
# 2   HD137613.txt     22966.00    22964.60   22967.4                  -0.6142
# 3   HD137613.txt     22971.30    22969.50   22973.1                  -1.5755
# 4   HD137613.txt     22978.50    22976.70   22980.3                  -0.5304
# 5   HD137613.txt     23006.20    23004.50   23007.9                  -1.1416
# 6   HD137613.txt     23015.25    23013.90   23016.6                  -1.0774
# 7   HD137613.txt     23083.90    23082.00   23085.8                  -0.0610
# 8   HD137613.txt     23118.90    23117.00   23120.8                  -1.0870
# 9   HD137613.txt     23170.70    23169.70   23171.7                  -1.0058
# 10  HD137613.txt     23261.30    23259.40   23263.2                  -1.6600
# ...

# %%
import scienceplots
plt.style.use(['science', 'notebook'])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(output_trimmed['wave_center']*1e-4, output_trimmed[element], c=output_trimmed['chi_squared'], cmap = 'plasma', s=35)
plt.colorbar()
plt.xlabel('Wavelength (microns)')
plt.ylabel(f'{element}')
# get axes limits
xmin, xmax = plt.xlim()
ymin, ymax = plt.ylim()
print(xmin, xmax, ymin, ymax)
# Out:
# 2.2884510000000002 2.412179 -0.47863999999999995 -0.26656

# %%
# CHANGE NEXT LINE
output_folder_location: str = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/Sep-07-2024-21-25-36_0.9680025404647491_LTE_O_1D" # CHANGE
# output_folder_location: str = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/Aug-27-2024-16-16-16_0.2522569805601429_LTE_N_1D" # CHANGE
# loads all data from config file and output, config is copied into output folder with name "configuration.txt" from now on
config_dict = load_output_data(output_folder_location)
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_results_pd_df = config_dict["output_file_df"] 
output_trimmed2 = (output_results_pd_df[output_results_pd_df["chi_squared"] < 20])
output_trimmed2 = output_trimmed2.reset_index(drop=True)

# %%
plt.figure(figsize=(10, 6))
# plt.scatter(output_trimmed['wave_center']*1e-4, output_trimmed[element], c=output_trimmed['chi_squared'], cmap = 'plasma', s=35, label='CN blended')
plt.scatter(output_trimmed2['wave_center']*1e-4, output_trimmed2[element], c=output_trimmed2['chi_squared'], cmap = 'plasma', s=35, marker='x', label='Unblended')
plt.colorbar()
plt.xlabel('Wavelength (microns)')
plt.ylabel(f'{element}')
# plt.legend()
# Out:
# Text(0, 0.5, 'O_Fe')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(output_trimmed['wave_center']*1e-4, output_trimmed[element], c=output_trimmed['chi_squared'], cmap = 'plasma', s=35, label='CN blended')
plt.scatter(output_trimmed2['wave_center']*1e-4, output_trimmed2[element], c=output_trimmed2['chi_squared'], cmap = 'plasma', s=35, marker='x', label='Unblended')
plt.colorbar()
plt.xlabel('Wavelength (microns)')
plt.ylabel(f'{element}')
plt.legend()

# %%
np.average(np.concatenate((output_trimmed[element], output_trimmed2[element])))+8.77
# Out:
# 8.382867567567567

# %%
plt.hist(output_trimmed2[element], bins=5, histtype='step', label='Unblended', lw = 3, color='blue')
plt.hist(output_trimmed[element], bins=5, histtype='step', label='CN blended', lw = 3, color='xkcd:green')
plt.axvline(np.average(output_trimmed2[element]), color='blue', linestyle='--', lw = 5)
plt.axvline(np.average(output_trimmed[element]), color='xkcd:green', linestyle='--', lw = 5)
plt.legend()

# %%
np.average(output_trimmed2[element]) + 8.77, np.std(output_trimmed2[element])
# Out:
# (8.351005263157894, 0.10060337167983886)

# %%
np.average(output_trimmed[element]) + 8.77, np.std(output_trimmed[element])
# Out:
# (8.4165, 0.05453348614485517)
