# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *
import scienceplots
plt.style.use(['science', 'notebook'])

# %%
multwavs = [22587.95,22593.85,22613.8,22634,22659.4,22680.5,22691.75,22703,22713.25,22773.25,22783.3,22789.35,22915.25,23028.35,23067.25,23655.35,
            22920.00, 23292.60, 22995.00, 22732.25,24283.60,24683.35		]

# %%
# outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wise222/Oct-13-2024-22-42-15_0.9770073685963133_LTE_O_1D"
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wisej1942/Nov-03-2024-16-28-21_0.41314863537500746_LTE_O_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed_vmic = output_results_pd_df[np.logical_and(output_results_pd_df["chi_squared"] < 25 , output_results_pd_df["Microturb"] > 4)]
# output_trimmed_vmic = (output_results_pd_df[)

output_trimmed_vmic = output_trimmed_vmic.reset_index(drop=True)
output_trimmed_vmic = output_trimmed_vmic[~output_trimmed_vmic["wave_center"].isin(multwavs)]
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed_vmic
# Out:
#                specname  wave_center  wave_start  wave_end  \
# 0   WISEJ1942_clean.txt     22978.00     22976.0   22980.0
# 1   WISEJ1942_clean.txt     23304.50     23302.0   23307.0
# 2   WISEJ1942_clean.txt     23437.95     23436.7   23439.2
# 3   WISEJ1942_clean.txt     23669.50     23668.0   23671.0
# 4   WISEJ1942_clean.txt     24269.00     24267.0   24271.0
# 6   WISEJ1942_clean.txt     24288.50     24287.0   24290.0
# 7   WISEJ1942_clean.txt     24420.95     24419.4   24422.5
# 9   WISEJ1942_clean.txt     22978.00     22976.0   22980.0
# 10  WISEJ1942_clean.txt     23304.50     23302.0   23307.0
# 11  WISEJ1942_clean.txt     23322.00     23320.0   23324.0
# 12  WISEJ1942_clean.txt     23362.10     23360.7   23363.5
# 13  WISEJ1942_clean.txt     23373.00     23371.5   23374.5
# 14  WISEJ1942_clean.txt     23437.95     23436.7   23439.2
# 15  WISEJ1942_clean.txt     23669.50     23668.0   23671.0
# 16  WISEJ1942_clean.txt     24269.00     24267.0   24271.0
# 18  WISEJ1942_clean.txt     24288.50     24287.0   24290.0
# 19  WISEJ1942_clean.txt     24420.95     24419.4   24422.5
# 21  WISEJ1942_clean.txt     22978.00     22976.0   22980.0
# 22  WISEJ1942_clean.txt     23304.50     23302.0   23307.0
# 23  WISEJ1942_clean.txt     23322.00     23320.0   23324.0
# 24  WISEJ1942_clean.txt     23362.10     23360.7   23363.5
# 25  WISEJ1942_clean.txt     23373.00     23371.5   23374.5
# 26  WISEJ1942_clean.txt     23437.95     23436.7   23439.2
# 27  WISEJ1942_clean.txt     23669.50     23668.0   23671.0
# 28  WISEJ1942_clean.txt     24269.00     24267.0   24271.0
# 30  WISEJ1942_clean.txt     24288.50     24287.0   24290.0
# 31  WISEJ1942_clean.txt     24420.95     24419.4   24422.5
# 33  WISEJ1942_clean.txt     22978.00     22976.0   22980.0
# 34  WISEJ1942_clean.txt     23295.50     23293.0   23298.0
# 35  WISEJ1942_clean.txt     23304.50     23302.0   23307.0
# 36  WISEJ1942_clean.txt     23322.00     23320.0   23324.0
# 37  WISEJ1942_clean.txt     23362.10     23360.7   23363.5
# 38  WISEJ1942_clean.txt     23373.00     23371.5   23374.5
# 39  WISEJ1942_clean.txt     23421.10     23419.5   23422.7
# 40  WISEJ1942_clean.txt     23434.00     23432.0   23436.0
# 41  WISEJ1942_clean.txt     23437.95     23436.7   23439.2
# 42  WISEJ1942_clean.txt     23669.50     23668.0   23671.0
# 43  WISEJ1942_clean.txt     23759.00     23757.5   23760.5
# 44  WISEJ1942_clean.txt     24269.00     24267.0   24271.0
# 46  WISEJ1942_clean.txt     24288.50     24287.0   24290.0
# 47  WISEJ1942_clean.txt     24420.95     24419.4   24422.5
# 48  WISEJ1942_clean.txt     22978.00     22976.0   22980.0
# 49  WISEJ1942_clean.txt     23295.50     23293.0   23298.0
# 50  WISEJ1942_clean.txt     23304.50     23302.0   23307.0
# 51  WISEJ1942_clean.txt     23322.00     23320.0   23324.0
# 52  WISEJ1942_clean.txt     23362.10     23360.7   23363.5
# 53  WISEJ1942_clean.txt     23373.00     23371.5   23374.5
# 54  WISEJ1942_clean.txt     23421.10     23419.5   23422.7
# 55  WISEJ1942_clean.txt     23434.00     23432.0   23436.0
# 56  WISEJ1942_clean.txt     23437.95     23436.7   23439.2
# 57  WISEJ1942_clean.txt     23669.50     23668.0   23671.0
# 58  WISEJ1942_clean.txt     23759.00     23757.5   23760.5
# 59  WISEJ1942_clean.txt     24269.00     24267.0   24271.0
# 61  WISEJ1942_clean.txt     24288.50     24287.0   24290.0
# 62  WISEJ1942_clean.txt     24420.95     24419.4   24422.5
#
#     Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 0                   -0.4659   0.0 -0.9426        5.0        4.0       0.0
# 1                   -0.0010   0.0 -1.1274        5.0        4.0       0.0
# 2                   -1.4740   0.0 -1.1634        5.0        4.0       0.0
# 3                   -1.0769   0.0 -0.9366        5.0        4.0       0.0
# 4                   -1.2498   0.0 -1.3061        5.0        4.0       0.0
# 6                   -2.5000   0.0 -1.2403        5.0        4.0       0.0
# 7                   -1.7975   0.0 -1.3534        5.0        4.0       0.0
# 9                   -0.6502   0.0 -1.0195        6.0        4.0       0.0
# 10                  -0.4509   0.0 -1.2141        6.0        4.0       0.0
# 11                  -2.1047   0.0 -1.2297        6.0        4.0       0.0
# 12                  -1.8754   0.0 -1.1913        6.0        4.0       0.0
# 13                  -2.1223   0.0 -1.2261        6.0        4.0       0.0
# 14                  -1.4754   0.0 -1.2034        6.0        4.0       0.0
# 15                  -1.0895   0.0 -1.1326        6.0        4.0       0.0
# 16                  -1.0727   0.0 -1.3238        6.0        4.0       0.0
# 18                  -2.5000   0.0 -1.2891        6.0        4.0       0.0
# 19                  -1.5562   0.0 -1.4061        6.0        4.0       0.0
# 21                  -0.8774   0.0 -1.0921        7.0        4.0       0.0
# 22                  -0.8963   0.0 -1.2868        7.0        4.0       0.0
# 23                  -2.3373   0.0 -1.3061        7.0        4.0       0.0
# 24                  -1.5318   0.0 -1.2882        7.0        4.0       0.0
# 25                  -1.2699   0.0 -1.2786        7.0        4.0       0.0
# 26                  -1.4793   0.0 -1.2301        7.0        4.0       0.0
# 27                  -1.0712   0.0 -1.2969        7.0        4.0       0.0
# 28                  -0.9125   0.0 -1.3395        7.0        4.0       0.0
# 30                  -2.5000   0.0 -1.3301        7.0        4.0       0.0
# 31                  -1.3890   0.0 -1.4481        7.0        4.0       0.0
# 33                  -1.1105   0.0 -1.1575        8.0        4.0       0.0
# 34                  -1.7166   0.0 -1.0867        8.0        4.0       0.0
# 35                  -1.3268   0.0 -1.3502        8.0        4.0       0.0
# 36                  -2.5000   0.0 -1.3750        8.0        4.0       0.0
# 37                  -1.3183   0.0 -1.3717        8.0        4.0       0.0
# 38                  -0.9890   0.0 -1.3375        8.0        4.0       0.0
# 39                  -2.3746   0.0 -1.2639        8.0        4.0       0.0
# 40                  -1.5153   0.0 -1.2106        8.0        4.0       0.0
# 41                  -1.4918   0.0 -1.2476        8.0        4.0       0.0
# 42                  -1.0273   0.0 -1.4299        8.0        4.0       0.0
# 43                  -2.0188   0.0 -1.4268        8.0        4.0       0.0
# 44                  -0.8030   0.0 -1.3547        8.0        4.0       0.0
# 46                  -2.5000   0.0 -1.3663        8.0        4.0       0.0
# 47                  -1.2957   0.0 -1.4829        8.0        4.0       0.0
# 48                  -1.3188   0.0 -1.2169        9.0        4.0       0.0
# 49                  -1.7573   0.0 -1.1660        9.0        4.0       0.0
# 50                  -1.7054   0.0 -1.4059        9.0        4.0       0.0
# 51                  -2.5000   0.0 -1.4358        9.0        4.0       0.0
# 52                  -1.1932   0.0 -1.4376        9.0        4.0       0.0
# 53                  -0.0462   0.0 -1.3648        9.0        4.0       0.0
# 54                  -2.1773   0.0 -1.3314        9.0        4.0       0.0
# 55                  -1.6355   0.0 -1.2831        9.0        4.0       0.0
# 56                  -1.5218   0.0 -1.2609        9.0        4.0       0.0
# 57                  -0.9797   0.0 -1.5320        9.0        4.0       0.0
# 58                  -2.0792   0.0 -1.4724        9.0        4.0       0.0
# 59                  -0.5608   0.0 -1.3697        9.0        4.0       0.0
# 61                  -2.5000   0.0 -1.3979        9.0        4.0       0.0
# 62                  -1.2603   0.0 -1.5123        9.0        4.0       0.0
#
#     chi_squared         ew  flag_error  flag_warning
# 0     22.534991   966.7357           0             0
# 1     23.969772  1041.2274           0             0
# 2      1.256050   294.8296           0             0
# 3     20.946931   742.9364           0             0
# 4      3.473297   687.6510           0             0
# 6      7.340265   471.2903           0      10000000
# 7     11.227886   528.4441           0             0
# 9     10.377731   995.5404           0             0
# 10    11.644661  1069.4034           0             0
# 11    21.008145   893.8179           0             0
# 12    16.759075   830.8807           0             0
# 13    14.733070   854.5503           0             0
# 14     0.992855   303.5911           0             0
# 15     7.769754   757.6328           0             0
# 16     3.232111   697.6468           0             0
# 18     4.466801   484.8477           0      10000000
# 19     5.704403   544.7143           0             0
# 21     6.039698  1016.0550           0             0
# 22     6.954805  1090.4504           0             0
# 23    10.089982   918.1199           0             0
# 24     6.034461   840.6045           0             0
# 25     7.516679   873.0232           0             0
# 26     2.258828   309.9497           0             0
# 27     3.300316   760.4053           0             0
# 28     3.793235   708.3055           0             0
# 30     4.560569   492.9653           0      10000000
# 31     2.149190   558.4460           0             0
# 33     7.599688  1030.7525           0             0
# 34    12.084469  1399.8663           0             0
# 35     7.648891  1106.6661           0             0
# 36     5.732187   938.0015           0      10000000
# 37     4.233405   843.8315           0             0
# 38     4.278766   880.7449           0             0
# 39    13.329724   821.0129           0          1000
# 40    12.133646   864.1912           0             0
# 41     4.699757   314.5002           0             0
# 42     6.039007   755.7559           0             0
# 43    18.348916   711.1623           0             0
# 44     5.486000   719.7574           0             0
# 46     7.345899   496.3589           0      10000000
# 47     0.965957   569.0197           0             0
# 48    14.207858  1039.9767           0             0
# 49     8.328142  1409.9866           0             0
# 50    13.220049  1119.8522           0             0
# 51     7.373634   954.2534           0      10000000
# 52     8.521063   844.3645           0             0
# 53     4.246037   897.6341           0          1000
# 54     2.812632   841.1754           0             0
# 55     6.233403   890.2358           0             0
# 56     7.910969   316.7491           0             0
# 57    13.747159   748.4626           0             0
# 58    15.696259   722.7174           0             0
# 59     7.934912   731.4125           0             0
# 61    12.120401   496.2190           0      10000000
# 62     2.047298   575.9790           0             0

# %%
vmics = np.unique(output_trimmed_vmic["Microturb"].values)
cs = ['r', 'g', 'b', 'c', 'm', 'y', 'r', 'g', 'b', 'c', 'm', 'y']
markers = ['o', 's', 'D', '^', 'v', 'p','^', 'v', 'p','^', 'v', 'p']
for i in range(len(vmics)):
    vmic = vmics[i]
    output_trimmed3 = output_trimmed_vmic[output_trimmed_vmic["Microturb"] == vmic]
    ews = np.array(output_trimmed3["ew"])
    nfes = np.array(output_trimmed3["O_Fe"])
    mean_nfe = np.mean(nfes)
    std_nfe = np.std(nfes)
    choose_idxs = np.where(np.abs(nfes - mean_nfe) < 3*std_nfe)
    choose_idxs = choose_idxs[0]
    choose_idxs2 = np.where(ews[choose_idxs] <12000)
    choose_idxs2 = choose_idxs2[0]
    choose_idxs = choose_idxs[choose_idxs2]
    ews = ews[choose_idxs]
    nfes = nfes[choose_idxs]
    corr = np.corrcoef(ews,nfes)[0,1]
    corr = corr.round(2)
    plt.scatter(ews,nfes, c=cs[i], marker = markers[i], label = f"vmic = {vmics[i]}, corr = {corr}")
    m,c = np.polyfit(ews,nfes,1)
    x = np.linspace(100, 700, 100)
    y = m*x + c
    print(vmics[i], m, len(nfes))
    plt.plot(x,y, c = cs[i])
    plt.legend(fontsize = 8)
    plt.ylabel("[N/Fe]")
    plt.xlabel("EW")
# Out:
# 5.0 0.00031199528297765294 7
# 6.0 0.0002067482193786641 10
# 7.0 0.00012834089931731865 10
# 8.0 0.00021288328037152998 14
# 9.0 0.00015753323529600554 14

# %%
output_trimmed3
# Out:
#                specname  wave_center  wave_start  wave_end  \
# 48  WISEJ1942_clean.txt     22978.00     22976.0   22980.0
# 49  WISEJ1942_clean.txt     23295.50     23293.0   23298.0
# 50  WISEJ1942_clean.txt     23304.50     23302.0   23307.0
# 51  WISEJ1942_clean.txt     23322.00     23320.0   23324.0
# 52  WISEJ1942_clean.txt     23362.10     23360.7   23363.5
# 53  WISEJ1942_clean.txt     23373.00     23371.5   23374.5
# 54  WISEJ1942_clean.txt     23421.10     23419.5   23422.7
# 55  WISEJ1942_clean.txt     23434.00     23432.0   23436.0
# 56  WISEJ1942_clean.txt     23437.95     23436.7   23439.2
# 57  WISEJ1942_clean.txt     23669.50     23668.0   23671.0
# 58  WISEJ1942_clean.txt     23759.00     23757.5   23760.5
# 59  WISEJ1942_clean.txt     24269.00     24267.0   24271.0
# 61  WISEJ1942_clean.txt     24288.50     24287.0   24290.0
# 62  WISEJ1942_clean.txt     24420.95     24419.4   24422.5
#
#     Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 48                  -1.3188   0.0 -1.2169        9.0        4.0       0.0
# 49                  -1.7573   0.0 -1.1660        9.0        4.0       0.0
# 50                  -1.7054   0.0 -1.4059        9.0        4.0       0.0
# 51                  -2.5000   0.0 -1.4358        9.0        4.0       0.0
# 52                  -1.1932   0.0 -1.4376        9.0        4.0       0.0
# 53                  -0.0462   0.0 -1.3648        9.0        4.0       0.0
# 54                  -2.1773   0.0 -1.3314        9.0        4.0       0.0
# 55                  -1.6355   0.0 -1.2831        9.0        4.0       0.0
# 56                  -1.5218   0.0 -1.2609        9.0        4.0       0.0
# 57                  -0.9797   0.0 -1.5320        9.0        4.0       0.0
# 58                  -2.0792   0.0 -1.4724        9.0        4.0       0.0
# 59                  -0.5608   0.0 -1.3697        9.0        4.0       0.0
# 61                  -2.5000   0.0 -1.3979        9.0        4.0       0.0
# 62                  -1.2603   0.0 -1.5123        9.0        4.0       0.0
#
#     chi_squared         ew  flag_error  flag_warning
# 48    14.207858  1039.9767           0             0
# 49     8.328142  1409.9866           0             0
# 50    13.220049  1119.8522           0             0
# 51     7.373634   954.2534           0      10000000
# 52     8.521063   844.3645           0             0
# 53     4.246037   897.6341           0          1000
# 54     2.812632   841.1754           0             0
# 55     6.233403   890.2358           0             0
# 56     7.910969   316.7491           0             0
# 57    13.747159   748.4626           0             0
# 58    15.696259   722.7174           0             0
# 59     7.934912   731.4125           0             0
# 61    12.120401   496.2190           0      10000000
# 62     2.047298   575.9790           0             0

# %%
output_trimmed3
# Out:
#                specname  wave_center  wave_start  wave_end  \
# 48  WISEJ1942_clean.txt     22978.00     22976.0   22980.0
# 49  WISEJ1942_clean.txt     23295.50     23293.0   23298.0
# 50  WISEJ1942_clean.txt     23304.50     23302.0   23307.0
# 51  WISEJ1942_clean.txt     23322.00     23320.0   23324.0
# 52  WISEJ1942_clean.txt     23362.10     23360.7   23363.5
# 53  WISEJ1942_clean.txt     23373.00     23371.5   23374.5
# 54  WISEJ1942_clean.txt     23421.10     23419.5   23422.7
# 55  WISEJ1942_clean.txt     23434.00     23432.0   23436.0
# 56  WISEJ1942_clean.txt     23437.95     23436.7   23439.2
# 57  WISEJ1942_clean.txt     23669.50     23668.0   23671.0
# 58  WISEJ1942_clean.txt     23759.00     23757.5   23760.5
# 59  WISEJ1942_clean.txt     24269.00     24267.0   24271.0
# 61  WISEJ1942_clean.txt     24288.50     24287.0   24290.0
# 62  WISEJ1942_clean.txt     24420.95     24419.4   24422.5
#
#     Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 48                  -1.3188   0.0 -1.2169        9.0        4.0       0.0
# 49                  -1.7573   0.0 -1.1660        9.0        4.0       0.0
# 50                  -1.7054   0.0 -1.4059        9.0        4.0       0.0
# 51                  -2.5000   0.0 -1.4358        9.0        4.0       0.0
# 52                  -1.1932   0.0 -1.4376        9.0        4.0       0.0
# 53                  -0.0462   0.0 -1.3648        9.0        4.0       0.0
# 54                  -2.1773   0.0 -1.3314        9.0        4.0       0.0
# 55                  -1.6355   0.0 -1.2831        9.0        4.0       0.0
# 56                  -1.5218   0.0 -1.2609        9.0        4.0       0.0
# 57                  -0.9797   0.0 -1.5320        9.0        4.0       0.0
# 58                  -2.0792   0.0 -1.4724        9.0        4.0       0.0
# 59                  -0.5608   0.0 -1.3697        9.0        4.0       0.0
# 61                  -2.5000   0.0 -1.3979        9.0        4.0       0.0
# 62                  -1.2603   0.0 -1.5123        9.0        4.0       0.0
#
#     chi_squared         ew  flag_error  flag_warning
# 48    14.207858  1039.9767           0             0
# 49     8.328142  1409.9866           0             0
# 50    13.220049  1119.8522           0             0
# 51     7.373634   954.2534           0      10000000
# 52     8.521063   844.3645           0             0
# 53     4.246037   897.6341           0          1000
# 54     2.812632   841.1754           0             0
# 55     6.233403   890.2358           0             0
# 56     7.910969   316.7491           0             0
# 57    13.747159   748.4626           0             0
# 58    15.696259   722.7174           0             0
# 59     7.934912   731.4125           0             0
# 61    12.120401   496.2190           0      10000000
# 62     2.047298   575.9790           0             0

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wisej1942/Nov-03-2024-21-09-35_0.9647508491418836_LTE_C_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 25])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#               specname  wave_center  wave_start  wave_end  \
# 0  WISEJ1942_clean.txt     22743.35     22742.0   22744.7
# 1  WISEJ1942_clean.txt     22868.25     22867.0   22869.5
# 2  WISEJ1942_clean.txt     23067.25     23065.0   23069.5
# 3  WISEJ1942_clean.txt     23336.60     23333.5   23339.7
#
#    Doppler_Shift_add_to_RV  Fe_H    C_Fe  Microturb  Macroturb  rotation  \
# 0                  -3.5000   0.0 -0.0367        7.0        6.0       0.0
# 1                   0.2543   0.0 -0.1264        7.0        6.0       0.0
# 2                  -1.3869   0.0 -0.0889        7.0        6.0       0.0
# 3                  -2.7821   0.0 -0.1859        7.0        6.0       0.0
#
#    chi_squared        ew  flag_error  flag_warning
# 0    11.031083  320.7287           0      10000000
# 1    21.663758  199.6619           0             0
# 2     3.628471  403.0652           0             0
# 3     4.626606  398.6362           0             0

# %%
(np.mean(output_trimmed["C_Fe"])+8.56).round(2), np.std(output_trimmed["C_Fe"]).round(2)
# Out:
# (np.float64(8.45), np.float64(0.05))

# %%
np.mean(output_trimmed["N_Fe"])+7.98
# Out:
# np.float64(7.567075000000001)

# %%
plot_one_star(config_dict, "WISEJ1942_clean.txt");

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wisej1942/Nov-03-2024-21-11-44_0.61201918223768_LTE_N_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 20])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#                specname  wave_center  wave_start  wave_end  \
# 0   WISEJ1942_clean.txt     22580.25    22578.50   22582.0
# 1   WISEJ1942_clean.txt     22632.75    22631.00   22634.5
# 2   WISEJ1942_clean.txt     22659.60    22657.90   22661.3
# 4   WISEJ1942_clean.txt     22680.50    22678.50   22682.5
# 5   WISEJ1942_clean.txt     22718.90    22717.50   22720.3
# 6   WISEJ1942_clean.txt     22729.50    22727.00   22732.0
# 7   WISEJ1942_clean.txt     22754.00    22752.00   22756.0
# 9   WISEJ1942_clean.txt     22817.75    22816.50   22819.0
# 10  WISEJ1942_clean.txt     22828.00    22826.00   22830.0
# 12  WISEJ1942_clean.txt     22895.50    22894.00   22897.0
# 13  WISEJ1942_clean.txt     22915.50    22913.50   22917.5
# 14  WISEJ1942_clean.txt     22924.50    22923.00   22926.0
# 15  WISEJ1942_clean.txt     22995.00    22994.00   22996.0
# 16  WISEJ1942_clean.txt     23067.25    23065.00   23069.5
# 17  WISEJ1942_clean.txt     23077.50    23074.50   23080.5
# 18  WISEJ1942_clean.txt     23101.85    23100.79   23102.9
# 19  WISEJ1942_clean.txt     23111.75    23110.50   23113.0
# 20  WISEJ1942_clean.txt     23202.75    23201.50   23204.0
# 21  WISEJ1942_clean.txt     23301.00    23300.00   23302.0
# 24  WISEJ1942_clean.txt     24019.20    24017.90   24020.5
# 25  WISEJ1942_clean.txt     24054.65    24053.50   24055.8
#
#     Doppler_Shift_add_to_RV  Fe_H    N_Fe  Microturb  Macroturb  rotation  \
# 0                   -1.2693   0.0 -1.0779        7.0        6.0       0.0
# 1                   -0.2742   0.0 -1.1140        7.0        6.0       0.0
# 2                   -0.0596   0.0 -1.0493        7.0        6.0       0.0
# 4                   -3.4853   0.0 -0.9775        7.0        6.0       0.0
# 5                   -2.7053   0.0 -1.1448        7.0        6.0       0.0
# 6                   -3.5000   0.0 -1.1847        7.0        6.0       0.0
# 7                   -3.5000   0.0 -0.7726        7.0        6.0       0.0
# 9                   -2.3109   0.0 -1.2744        7.0        6.0       0.0
# 10                  -3.5000   0.0 -1.0865        7.0        6.0       0.0
# 12                  -2.3135   0.0 -0.9454        7.0        6.0       0.0
# 13                   0.9035   0.0 -0.9665        7.0        6.0       0.0
# 14                  -3.5000   0.0 -1.1485        7.0        6.0       0.0
# 15                  -1.9183   0.0 -0.9101        7.0        6.0       0.0
# 16                  -1.3869   0.0 -0.9696        7.0        6.0       0.0
# 17                  -0.5600   0.0 -1.2238        7.0        6.0       0.0
# 18                   2.0509   0.0 -1.1213        7.0        6.0       0.0
# 19                  -1.5487   0.0 -0.9551        7.0        6.0       0.0
# 20                  -3.5000   0.0 -1.2533        7.0        6.0       0.0
# 21                  -3.0765   0.0 -1.4034        7.0        6.0       0.0
# 24                   0.2067   0.0 -0.8606        7.0        6.0       0.0
# 25                  -3.5000   0.0 -1.0582        7.0        6.0       0.0
#
#     chi_squared        ew  flag_error  flag_warning
# 0      2.839037  377.5984           0             0
# 1      3.405634  406.9992           0             0
# 2      4.011737  393.9941           0             0
# 4      4.830177  326.6608           0             0
# 5      1.925404  153.6152           0             0
# 6     14.355515  392.7619           0      10000000
# 7     16.086500  410.4161           0      10000000
# 9      4.209791  259.6420           0             0
# 10     9.529031  349.8086           0      10000000
# 12     5.726837  260.1900           0             0
# 13     5.779020  413.0549           0             0
# 14     1.675479  137.0222           0      10000000
# 15     5.478303   90.3998           0             0
# 16     3.698480  400.1414           0             0
# 17     7.151900  358.5115           0             0
# 18     8.749554   74.1155           0             0
# 19    14.541874  330.3091           0             0
# 20     4.252417  129.4041           0      10000000
# 21     5.651099   96.2204           0             0
# 24     1.444320  197.5835           0             0
# 25     5.287336  159.4286           0      10000000

# %%
(np.mean(output_trimmed["N_Fe"])+7.98).round(2), np.std(output_trimmed["N_Fe"]).round(2)
# Out:
# (np.float64(6.91), np.float64(0.15))

# %%
fitlist = pd.read_csv('/media/advait/DATA/research/rcb-project/TSFitPy/input_files/wisej1942/vmac', sep='  ')
# Out:
# /tmp/ipykernel_1051725/1206121688.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   fitlist = pd.read_csv('/media/advait/DATA/research/rcb-project/TSFitPy/input_files/wisej1942/vmac', sep='  ')

# %%
fitlist
# Out:
#   #name_of_spectrum_to_fit   rv    teff  logg  [Fe/H]  Input_vmicroturb  A(H)  \
# 0      WISEJ1942_clean.txt  0.0  4500.0   1.0     0.0               7.0   7.5
#
#    A(He)  A(C)  A(O)  A(Na)  A(S)  A(Fe)  A(N)  A(Ca)  A(Si)  A(Mg)  A(Co)  \
# 0   11.5  8.45   7.5   5.29  6.16    6.5  6.97   5.37   6.59   6.55   3.95
#
#    A(Ti)  oisorat
# 0   3.94     60.0

# %%
rats = np.arange(80, 200,5)
rats = np.repeat(rats, 10)
rats
# Out:
# array([ 80,  80,  80,  80,  80,  80,  80,  80,  80,  80,  85,  85,  85,
#         85,  85,  85,  85,  85,  85,  85,  90,  90,  90,  90,  90,  90,
#         90,  90,  90,  90,  95,  95,  95,  95,  95,  95,  95,  95,  95,
#         95, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 105, 105,
#        105, 105, 105, 105, 105, 105, 105, 105, 110, 110, 110, 110, 110,
#        110, 110, 110, 110, 110, 115, 115, 115, 115, 115, 115, 115, 115,
#        115, 115, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 125,
#        125, 125, 125, 125, 125, 125, 125, 125, 125, 130, 130, 130, 130,
#        130, 130, 130, 130, 130, 130, 135, 135, 135, 135, 135, 135, 135,
#        135, 135, 135, 140, 140, 140, 140, 140, 140, 140, 140, 140, 140,
#        145, 145, 145, 145, 145, 145, 145, 145, 145, 145, 150, 150, 150,
#        150, 150, 150, 150, 150, 150, 150, 155, 155, 155, 155, 155, 155,
#        155, 155, 155, 155, 160, 160, 160, 160, 160, 160, 160, 160, 160,
#        160, 165, 165, 165, 165, 165, 165, 165, 165, 165, 165, 170, 170,
#        170, 170, 170, 170, 170, 170, 170, 170, 175, 175, 175, 175, 175,
#        175, 175, 175, 175, 175, 180, 180, 180, 180, 180, 180, 180, 180,
#        180, 180, 185, 185, 185, 185, 185, 185, 185, 185, 185, 185, 190,
#        190, 190, 190, 190, 190, 190, 190, 190, 190, 195, 195, 195, 195,
#        195, 195, 195, 195, 195, 195])

# %%
len(rats)
# Out:
# 240

# %%
# Extract the last row
last_row = fitlist.iloc[-1]

# Create a new DataFrame by repeating the last row n times
new_rows = pd.DataFrame([last_row] * (len(rats) - len(fitlist)), columns=fitlist.columns)

# Append the new rows to the original DataFrame
fitlist2 = pd.concat([fitlist, new_rows], ignore_index=True)

fitlist2['oisorat'] = rats
# fitlist2

# %%
fitlist2.to_csv('/media/advait/DATA/research/rcb-project/TSFitPy/input_files/wisej1942/comb', sep=' ', index=False)

# %%
allpath = '/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wisej1942/Nov-03-2024-10-57-52_0.34375190929143506_LTE_O_1D/output'
# allpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/hd137613/Oct-17-2024-23-13-22_0.35833114159931434_LTE_O_1D/output"
df1 = pd.read_csv(allpath, sep='\t')
allpath = '/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wisej1942/Nov-03-2024-11-35-14_0.3641906682942011_LTE_O_1D/output'
df2 = pd.read_csv(allpath, sep='\t')

allpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wisej1942/Nov-03-2024-13-23-31_0.41070702154497307_LTE_O_1D/output"
df3 = pd.read_csv(allpath, sep='\t')

allpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wisej1942/Nov-03-2024-22-25-12_0.09688269001907202_LTE_O_1D/output"
df4 = pd.read_csv(allpath, sep='\t')

# %%
df_fine = pd.concat([df1,df2, df3, df4])
# df_fine = df1
df_fine.sort_values(by='oisorat', inplace=True)
rats = np.unique(df3['oisorat'])
rats2 = np.unique(df4['oisorat'])

# %%
df_fine
# Out:
#                 specname      O_Fe  Doppler_Shift_add_to_RV  chi_squared  \
# 8    WISEJ1942_clean.txt -1.322662                -0.784204     8.745080
# 9    WISEJ1942_clean.txt -1.305726                -0.954342     8.707321
# 2    WISEJ1942_clean.txt -1.346009                -0.765118     8.803126
# 0    WISEJ1942_clean.txt -1.336717                -0.971407     8.720867
# 4    WISEJ1942_clean.txt -1.338808                -0.948813     8.735711
# ..                   ...       ...                      ...          ...
# 233  WISEJ1942_clean.txt -1.294929                -0.940099     8.351111
# 239  WISEJ1942_clean.txt -1.302300                -0.944350     8.362366
# 238  WISEJ1942_clean.txt -1.311963                -0.783728     8.425656
# 234  WISEJ1942_clean.txt -1.329663                -0.769827     8.501992
# 235  WISEJ1942_clean.txt -1.300117                -0.780653     8.398618
#
#      vmac  red_chi_squared  oisorat
# 8     6.0        14.090051     30.0
# 9     6.0        13.543175     30.0
# 2     6.0        14.684153     30.0
# 0     6.0        14.129923     30.0
# 4     6.0        14.225981     30.0
# ..    ...              ...      ...
# 233   6.0        12.755878    195.0
# 239   6.0        12.902026    195.0
# 238   6.0        13.352127    195.0
# 234   6.0        13.851348    195.0
# 235   6.0        13.090512    195.0
#
# [624 rows x 7 columns]

# %%
# rats = np.unique(df3['oisorat'])
chis, dchis, oabunds, doabunds = [], [], [], []
rvs = []
rats = np.union1d(rats, rats2)
for rat in rats:
    subdf = df_fine[df_fine['oisorat'] == rat]
    meanchi = np.mean(subdf['red_chi_squared'])
    stdchi = np.std(subdf['red_chi_squared'])
    meanoabund = np.mean(subdf['O_Fe'])
    stdoabund = np.std(subdf['O_Fe'])
    rv = np.mean(subdf['Doppler_Shift_add_to_RV'])
    rvs.append(rv)
    chis.append(meanchi)
    dchis.append(stdchi)
    oabunds.append(meanoabund)
    doabunds.append(stdoabund)

# %%
# import numpy as np
# import pandas as pd
from astropy.stats import sigma_clip


# df_fine = df1
# df_fine.sort_values(by='oisorat', inplace=True)
# rats = np.unique(df_fine['oisorat'])

chis, dchis, oabunds, doabunds = [], [], [], []
rvs = []
for rat in rats:
    subdf = df_fine[df_fine['oisorat'] == rat]
    
    # Sigma clipping for red_chi_squared
    clipped_chi = sigma_clip(subdf['red_chi_squared'], sigma=3, maxiters=5)
    meanchi = np.mean(clipped_chi)
    stdchi = np.std(clipped_chi)
    
    meanoabund = np.mean(subdf['O_Fe'])
    stdoabund = np.std(subdf['O_Fe'])
    rv = np.mean(subdf['Doppler_Shift_add_to_RV'])
    
    rvs.append(rv)
    chis.append(meanchi)
    dchis.append(stdchi)
    oabunds.append(meanoabund)
    doabunds.append(stdoabund)

print("RVs:", rvs)
print("Mean Chi:", chis)
print("Std Chi:", dchis)
print("O Abundances:", oabunds)
print("Std O Abundances:", doabunds)
# Out:
# RVs: [np.float64(-0.9415739985002488), np.float64(-0.953443148094883), np.float64(-0.9095947259258478), np.float64(-0.926893020608323), np.float64(-0.902971685163189), np.float64(-0.8467023303660561), np.float64(-0.8625953955484833), np.float64(-0.8888405435809068), np.float64(-0.8845313155195954), np.float64(-0.8807513784319141), np.float64(-0.8848226175882569), np.float64(-0.8681793294622796), np.float64(-0.8576033961526539), np.float64(-0.8403449867429824), np.float64(-0.8567219164561379), np.float64(-0.8382907282551072), np.float64(-0.8423250518867228), np.float64(-0.8287441244643551), np.float64(-0.8192900652252227), np.float64(-0.8405900845802448), np.float64(-0.8276527587599855), np.float64(-0.8499300857858785), np.float64(-0.8178312424656216), np.float64(-0.8552943378698495), np.float64(-0.8832588610918984), np.float64(-0.8264578588426043), np.float64(-0.8285817211055393), np.float64(-0.8536090908360521), np.float64(-0.8343116363947747), np.float64(-0.8457729872878446), np.float64(-0.900840505433908), np.float64(-0.9100948655731471), np.float64(-0.8625507587969926), np.float64(-0.8239849011837463)]
# Mean Chi: [np.float64(14.040258193079293), np.float64(13.56446372639059), np.float64(13.307157272592118), np.float64(13.2627096749043), np.float64(13.16363087885414), np.float64(13.26087868326612), np.float64(13.063425578730328), np.float64(12.898177255478924), np.float64(12.832490900735733), np.float64(12.830397384044344), np.float64(12.987476217086943), np.float64(12.894828507672495), np.float64(13.011272186157628), np.float64(13.023661180219136), np.float64(13.119907502534176), np.float64(13.2056811765647), np.float64(13.144989724472394), np.float64(13.205258158730386), np.float64(13.151690566223948), np.float64(13.101340583583497), np.float64(13.117409168726843), np.float64(13.06537727385334), np.float64(13.232294541529072), np.float64(13.240634433464226), np.float64(13.00820617441122), np.float64(13.311852401529146), np.float64(13.373103531757517), np.float64(13.207592293964305), np.float64(13.331225914870203), np.float64(13.174982315916719), np.float64(13.1245904862038), np.float64(13.206032473767632), np.float64(13.40931654213193), np.float64(13.344152611941913)]
# Std Chi: [np.float64(0.3188391106715204), np.float64(0.3354007422617891), np.float64(0.44479983181174126), np.float64(0.40531860418763765), np.float64(0.5024931660831173), np.float64(0.4063265071620915), np.float64(0.3446491865183534), np.float64(0.335903230638895), np.float64(0.49068713669384323), np.float64(0.26427752609593275), np.float64(0.47589375802135186), np.float64(0.4670125442798944), np.float64(0.44432363404802344), np.float64(0.40291254109061625), np.float64(0.5659366937478505), np.float64(0.41955204726014445), np.float64(0.46837579106369354), np.float64(0.43024612127499356), np.float64(0.42489804374587126), np.float64(0.5609869243299498), np.float64(0.519929643559669), np.float64(0.43796283183931467), np.float64(0.32298133681072405), np.float64(0.42411863261909727), np.float64(0.300450917741066), np.float64(0.5252554606117312), np.float64(0.49708502283825895), np.float64(0.3889826428626932), np.float64(0.41797547353813364), np.float64(0.3860641673854254), np.float64(0.3896407839854373), np.float64(0.2081697330587441), np.float64(0.5080670205671707), np.float64(0.4143153635108354)]
# O Abundances: [np.float64(-1.3280472912727717), np.float64(-1.3218688715749685), np.float64(-1.3171939331212703), np.float64(-1.3213412492340528), np.float64(-1.3176494820515194), np.float64(-1.3223459964269069), np.float64(-1.316584690686404), np.float64(-1.3116290339811465), np.float64(-1.3079631414907804), np.float64(-1.311836000116274), np.float64(-1.3140335057437895), np.float64(-1.3084244367545537), np.float64(-1.3124793864081334), np.float64(-1.3116526529940178), np.float64(-1.3149232948891374), np.float64(-1.3174090778384047), np.float64(-1.3145329049532382), np.float64(-1.3155054633087522), np.float64(-1.3122363521768303), np.float64(-1.3097176447311862), np.float64(-1.3097022155983071), np.float64(-1.3085553949360527), np.float64(-1.3125634883389665), np.float64(-1.314705921752956), np.float64(-1.3073769851372588), np.float64(-1.3147031822502566), np.float64(-1.3171027800517654), np.float64(-1.3113662578200687), np.float64(-1.314815349642708), np.float64(-1.3089743083249963), np.float64(-1.3088515374511949), np.float64(-1.313671689279814), np.float64(-1.3173399581564718), np.float64(-1.3128080328084213)]
# Std O Abundances: [np.float64(0.011880785857825961), np.float64(0.012212173776833549), np.float64(0.015806938834019492), np.float64(0.013177970697656912), np.float64(0.015826445356584038), np.float64(0.013795078670811084), np.float64(0.011692952659464679), np.float64(0.012138092894016407), np.float64(0.016023879442983276), np.float64(0.014237655853292302), np.float64(0.015447991059788838), np.float64(0.016330862177915958), np.float64(0.015204299134119177), np.float64(0.013882051989300084), np.float64(0.017876924734051825), np.float64(0.01286801543368213), np.float64(0.014680714687847193), np.float64(0.013380078368301088), np.float64(0.015400847255768433), np.float64(0.01802519508742609), np.float64(0.01696354153426295), np.float64(0.01435056967604425), np.float64(0.012179875504199696), np.float64(0.012889438240002018), np.float64(0.008356594362347513), np.float64(0.017390490644378077), np.float64(0.015665674249732375), np.float64(0.01343966033151981), np.float64(0.01122228686491817), np.float64(0.01261032453553263), np.float64(0.012442609998266057), np.float64(0.007024072843171927), np.float64(0.015232017506561508), np.float64(0.01321137041798003)]

# %%
plt.plot(rats, chis, 'ko-')
plt.errorbar(rats, chis, yerr=dchis, fmt='ko', capsize=3)
# plt.axhline(np.min(chis), ls='--', color='r')
# plt.axhline(np.min(chis)+1.0, ls='--', color='r')
# plt.axvline(3.4)
plt.grid(which='both')

# fit a 3rd degree polynomial weighted by the errors
p = np.polyfit(rats, chis, 5, w=1/np.array(dchis)**2)
x = np.linspace(20,220,1000)
y = np.polyval(p, x)
plt.plot(x, y, 'r')
plt.axvline(x[np.where(y == np.min(y))], color='r')
xfit = x[np.where(y == np.min(y))]
plt.axhline(np.min(y), color='r')
# find nearest x value to min + 1 y value
ybound = np.min(y) + 1.0
diff = np.abs(y-ybound)
idx = np.where(diff == np.min(diff))
# find the index of next minimum
idx2 = np.where(diff == np.partition(diff, 1)[1])
xbounds = (x[idx]-xfit).round(2), (x[idx2]-xfit).round(2)
plt.axvline(x[idx], color='r')
plt.axvline(x[idx2], color='r')
plt.axhline(ybound, color='r')
print(xfit[0].round(2), xbounds[0][0], xbounds[1][0])
plt.ylabel(r'$\chi^2$')
plt.xlabel("16O/18O ratio")
# find x values nearest to ybounds
# Out:
# 71.65 144.34 -40.44
# Text(0.5, 0, '16O/18O ratio')

# %%
plt.plot(rats, chis, 'ko-')
plt.errorbar(rats, chis, yerr=dchis, fmt='ko', capsize=3)
# plt.axhline(np.min(chis), ls='--', color='r')
# plt.axhline(np.min(chis)+1.0, ls='--', color='r')
# plt.axvline(3.4)
plt.grid(which='both')

# fit a 3rd degree polynomial weighted by the errors
p = np.polyfit(rats, chis, 5, w=1/np.array(dchis)**2)
x = np.linspace(5.5,14,1000)
y = np.polyval(p, x)
plt.plot(x, y, 'r')
plt.axvline(x[np.where(y == np.min(y))], color='r')
xfit = x[np.where(y == np.min(y))]
plt.axhline(np.min(y), color='r')
# find nearest x value to min + 1 y value
ybound = np.min(y) + 1.0
diff = np.abs(y-ybound)
idx = np.where(diff == np.min(diff))
# find the index of next minimum
idx2 = np.where(diff == np.partition(diff, 1)[1])
xbounds = (x[idx]-xfit).round(2), (x[idx2]-xfit).round(2)
plt.axvline(x[idx], color='r')
plt.axvline(x[idx2], color='r')
plt.axhline(ybound, color='r')
print(xfit[0].round(2), xbounds[0][0], xbounds[1][0])
plt.ylabel(r'$\chi^2$')
plt.xlabel("16O/18O ratio")
# find x values nearest to ybounds
# Out:
#  ** On entry to DLASCL parameter number  4 had an illegal value
#  ** On entry to DLASCL parameter number  4 had an illegal value
# /tmp/ipykernel_1051725/3694607107.py:9: RuntimeWarning: divide by zero encountered in divide
#   p = np.polyfit(rats, chis, 5, w=1/np.array(dchis)**2)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[27], line 9
#       6 plt.grid(which='both')
#       8 # fit a 3rd degree polynomial weighted by the errors
# ----> 9 p = np.polyfit(rats, chis, 5, w=1/np.array(dchis)**2)
#      10 x = np.linspace(5.5,14,1000)
#      11 y = np.polyval(p, x)
#
# File ~/miniconda3/envs/astro/lib/python3.12/site-packages/numpy/lib/_polynomial_impl.py:666, in polyfit(x, y, deg, rcond, full, w, cov)
#     664 scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     665 lhs /= scale
# --> 666 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     667 c = (c.T/scale).T  # broadcast scale coefficients
#     669 # warn on rank reduction, which indicates an ill conditioned matrix
#
# File ~/miniconda3/envs/astro/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2565, in lstsq(a, b, rcond)
#    2561     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
#    2563 with errstate(call=_raise_linalgerror_lstsq, invalid='call',
#    2564               over='ignore', divide='ignore', under='ignore'):
# -> 2565     x, resids, rank, s = _umath_linalg.lstsq(a, b, rcond,
#    2566                                              signature=signature)
#    2567 if m == 0:
#    2568     x[...] = 0
#
# File ~/miniconda3/envs/astro/lib/python3.12/site-packages/numpy/linalg/_linalg.py:116, in _raise_linalgerror_lstsq(err, flag)
#     115 def _raise_linalgerror_lstsq(err, flag):
# --> 116     raise LinAlgError("SVD did not converge in Linear Least Squares")
#
# LinAlgError: SVD did not converge in Linear Least Squares

# %%
plt.plot(rats, np.array(oabunds)+8.77, 'ko-')
plt.errorbar(rats, np.array(oabunds)+8.77, yerr=doabunds, fmt='ko', capsize=3)
plt.axhline(8.38)
# plt.axhline(8.81, color='r')
plt.axhline(8.38-0.11, color='r')
# plt.axhline(8.81+0.1, color='r')
# plt.axvline(0.52)

# %%
/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-18/Oct-31-2024-21-17-14_0.6220364455096137_LTE_O_1D

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-18/Nov-01-2024-11-02-49_0.027895648108579807_LTE_O_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 20])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
(np.mean(output_trimmed["O_Fe"])+solar_abundances['O']).round(2), np.std(output_trimmed["O_Fe"]).round(2)
# Out:
# (np.float64(8.4), np.float64(0.11))

# %%
np.mean(output_trimmed["O_Fe"])
# Out:
# np.float64(-0.39451)

# %%
-0.39451-0.11
# Out:
# -0.50451

# %%
-0.39451+0.11
# Out:
# -0.28451000000000004
