# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *
import scienceplots
plt.style.use(['science', 'notebook'])
import glob

# %%
import glob
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-4/"
# find the newest folder in the directory
newest_folder = max(glob.glob(outpath + "/*"), key=os.path.getctime)
config_dict = load_output_data("/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-4/Dec-03-2024-02-33-09_0.9943320097811229_LTE_C_1D")
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 20])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#            specname  wave_center  wave_start  wave_end  \
# 0   ASAS-RCB-21.txt     22647.50     22646.0   22649.0
# 1   ASAS-RCB-21.txt     22663.75     22662.5   22665.0
# 2   ASAS-RCB-21.txt     22722.50     22721.0   22724.0
# 3   ASAS-RCB-21.txt     22736.50     22735.0   22738.0
# 5   ASAS-RCB-21.txt     22799.00     22797.0   22801.0
# 6   ASAS-RCB-21.txt     22842.00     22840.0   22844.0
# 7   ASAS-RCB-21.txt     22862.50     22861.0   22864.0
# 8   ASAS-RCB-21.txt     22869.70     22868.0   22871.4
# 9   ASAS-RCB-21.txt     23055.50     23054.0   23057.0
# 10  ASAS-RCB-21.txt     23126.50     23125.5   23127.5
# 11  ASAS-RCB-21.txt     23168.00     23167.0   23169.0
# 12  ASAS-RCB-21.txt     23357.00     23356.0   23358.0
# 13  ASAS-RCB-21.txt     23381.75     23380.5   23383.0
# 14  ASAS-RCB-21.txt     23392.00     23390.0   23394.0
#
#     Doppler_Shift_add_to_RV  Fe_H    C_Fe  Microturb  Macroturb  rotation  \
# 0                   -0.0656   0.0  0.1953        9.0        7.8       0.0
# 1                   -0.0640   0.0  0.1096        9.0        7.8       0.0
# 2                    0.0223   0.0  0.2161        9.0        7.8       0.0
# 3                   -1.2962   0.0  0.2010        9.0        7.8       0.0
# 5                   -0.9215   0.0  0.2325        9.0        7.8       0.0
# 6                   -2.3911   0.0  0.2207        9.0        7.8       0.0
# 7                    1.9492   0.0  0.2342        9.0        7.8       0.0
# 8                   -0.7813   0.0  0.2540        9.0        7.8       0.0
# 9                    2.5000   0.0  0.1865        9.0        7.8       0.0
# 10                   0.0104   0.0  0.1146        9.0        7.8       0.0
# 11                   0.0286   0.0  0.2202        9.0        7.8       0.0
# 12                   0.0515   0.0  0.0734        9.0        7.8       0.0
# 13                  -0.9218   0.0  0.2026        9.0        7.8       0.0
# 14                   2.0847   0.0  0.1372        9.0        7.8       0.0
#
#     chi_squared        ew  flag_error  flag_warning
# 0      3.308443  202.9002           0             0
# 1     10.828356  371.7777           0             0
# 2      3.211683  257.4994           0             0
# 3      3.796908  487.6276           0             0
# 5      6.748395  605.8482           0             0
# 6      4.465148  388.4542           0             0
# 7     11.628917  498.3346           0             0
# 8      5.974828  693.1609           0             0
# 9      6.486985  496.5872           0      10000000
# 10     8.144055  214.8201           0             0
# 11     7.318896  253.8977           0             0
# 12     1.907074   54.3197           0             0
# 13     5.547335  215.1909           0         10000
# 14     5.434596  440.5075           0             0

# %%
np.mean(output_trimmed['C_Fe'])+solar_abundances['C']
# Out:
# np.float64(8.745564285714286)

# %%
np.std(output_trimmed['C_Fe'])
# Out:
# np.float64(0.052758880188793905)

# %%
plt.scatter(output_trimmed['wave_center'], output_trimmed['C_Fe'], c = output_trimmed['chi_squared'], cmap = 'inferno')
plt.grid(which='both')
plt.colorbar()
# plt.axvline(2.322e4)

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-4/"
# find the newest folder in the directory
newest_folder = max(glob.glob(outpath + "/*"), key=os.path.getctime)
config_dict = load_output_data("/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-4/Nov-29-2024-20-39-37_0.458006269803542_LTE_N_1D")
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] <20])
# output_trimmed = output_trimmed[output_trimmed["N_Fe"] + solar_abundances['N'] > 7.5]
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
(7.98+np.mean(output_trimmed['N_Fe'])).round(3), np.std(output_trimmed['N_Fe']).round(3)
# Out:
# (np.float64(7.666), np.float64(0.078))

# %%
plt.scatter(output_trimmed['wave_center'], output_trimmed['N_Fe']+7.98, c = output_trimmed['chi_squared'], cmap = 'inferno')
plt.grid(which='both')
plt.colorbar()
# plt.axvline(2.322e4)

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-4/"
# find the newest folder in the directory
newest_folder = max(glob.glob(outpath + "/*"), key=os.path.getctime)
config_dict = load_output_data(newest_folder)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] <40])
# output_trimmed = output_trimmed[output_trimmed["O_Fe"] + solar_abundances['O'] < 8.05]
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
solar_abundances['O'] - 0.693
# Out:
# 8.077

# %%
output_trimmed
# Out:
#            specname  wave_center  wave_start  wave_end  \
# 0   ASAS-RCB-21.txt     23304.50    23302.00   23307.0
# 1   ASAS-RCB-21.txt     23313.00    23310.00   23316.0
# 2   ASAS-RCB-21.txt     23362.10    23360.70   23363.5
# 3   ASAS-RCB-21.txt     23373.00    23371.50   23374.5
# 4   ASAS-RCB-21.txt     23496.00    23484.00   23508.0
# 5   ASAS-RCB-21.txt     23642.60    23640.70   23644.5
# 6   ASAS-RCB-21.txt     23818.90    23815.79   23822.0
# 7   ASAS-RCB-21.txt     23900.00    23897.00   23903.0
# 8   ASAS-RCB-21.txt     23989.50    23988.00   23991.0
# 9   ASAS-RCB-21.txt     24097.50    24089.00   24106.0
# 10  ASAS-RCB-21.txt     24128.00    24123.50   24132.5
# 11  ASAS-RCB-21.txt     24287.40    24284.79   24290.0
# 12  ASAS-RCB-21.txt     24303.00    24301.50   24304.5
# 13  ASAS-RCB-21.txt     24330.20    24328.40   24332.0
# 14  ASAS-RCB-21.txt     24365.15    24364.00   24366.3
#
#     Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 0                    0.7819   0.0 -1.2931        7.0        7.8       0.0
# 1                   -0.4257   0.0 -1.0931        7.0        7.8       0.0
# 2                   -0.3230   0.0 -1.2562        7.0        7.8       0.0
# 3                   -0.2027   0.0 -1.1325        7.0        7.8       0.0
# 4                    0.8659   0.0 -1.0193        7.0        7.8       0.0
# 5                    0.0342   0.0 -1.0283        7.0        7.8       0.0
# 6                    1.5167   0.0 -1.2743        7.0        7.8       0.0
# 7                   -0.3823   0.0 -1.1208        7.0        7.8       0.0
# 8                    0.3162   0.0 -1.2544        7.0        7.8       0.0
# 9                   -0.3929   0.0 -1.2269        7.0        7.8       0.0
# 10                  -1.9417   0.0 -1.2723        7.0        7.8       0.0
# 11                   0.1663   0.0 -1.2485        7.0        7.8       0.0
# 12                   0.0357   0.0 -1.2760        7.0        7.8       0.0
# 13                  -0.4885   0.0 -1.2825        7.0        7.8       0.0
# 14                  -0.8416   0.0 -1.1176        7.0        7.8       0.0
#
#     chi_squared         ew  flag_error  flag_warning
# 0      6.854855  1131.4417           0             0
# 1      5.574309  1550.4061           0             0
# 2     10.427935   825.1951           0             0
# 3      4.833345   966.6250           0             0
# 4      9.396851  5858.1253           0             0
# 5      6.835410   799.6683           0             0
# 6      9.647455  1373.3099           0             0
# 7      5.244722  1440.2867           0             0
# 8      7.772861   468.5017           0             0
# 9     10.638739  3723.9779           0             0
# 10    17.635855  2521.9480           0             0
# 11    10.595387   900.0276           0             0
# 12     5.055469   586.6006           0             0
# 13     4.579322   968.2034           0             0
# 14     2.453512   631.3461           0             0

# %%
# for i in range(len(output_trimmed)):
#     print(f"{output_trimmed['wave_center'].iloc[i]}  {output_trimmed['wave_start'].iloc[i]}  {output_trimmed['wave_end'].iloc[i]}")

# %%
np.mean(output_trimmed['O_Fe']).round(3)
# Out:
# np.float64(-1.193)

# %%
(solar_abundances['O']+np.mean(output_trimmed['O_Fe'])).round(3), np.std(output_trimmed['O_Fe']).round(3)
# Out:
# (np.float64(7.577), np.float64(0.094))

# %%
plt.scatter(output_trimmed['wave_center'], output_trimmed['O_Fe']+solar_abundances['O'], c = output_trimmed['chi_squared'], cmap = 'inferno')
plt.grid(which='both')
plt.colorbar()
# plt.axvline(2.322e4)
