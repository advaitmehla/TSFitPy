# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *
import scienceplots
plt.style.use(['science', 'notebook'])

# %%
# outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wise222/Oct-13-2024-22-42-15_0.9770073685963133_LTE_O_1D"
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wise222/Oct-14-2024-12-23-39_0.15940232938950527_LTE_O_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 50])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_results_pd_df
# Out:
#               specname  wave_center  wave_start  wave_end  \
# 0    WISE222_clean.txt     22947.40     22946.0   22948.8
# 1    WISE222_clean.txt     22956.00     22954.0   22958.0
# 2    WISE222_clean.txt     22971.30     22969.5   22973.1
# 3    WISE222_clean.txt     22978.50     22976.7   22980.3
# 4    WISE222_clean.txt     22998.00     22996.5   23002.0
# ..                 ...          ...         ...       ...
# 110  WISE222_clean.txt     23759.00     23757.5   23760.5
# 111  WISE222_clean.txt     24303.00     24301.5   24304.5
# 112  WISE222_clean.txt     24605.25     24604.0   24606.5
# 113  WISE222_clean.txt     24640.75     24637.0   24644.5
# 114  WISE222_clean.txt     24683.35     24682.0   24684.7
#
#      Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 0                     0.6937   0.0 -0.8720        4.0        1.0       0.0
# 1                     2.5000   0.0 -0.9128        4.0        1.0       0.0
# 2                     0.3719   0.0 -0.8746        4.0        1.0       0.0
# 3                     0.6466   0.0 -1.0240        4.0        1.0       0.0
# 4                     1.6999   0.0 -0.6881        4.0        1.0       0.0
# ..                       ...   ...     ...        ...        ...       ...
# 110                  -1.7242   0.0 -1.2361        8.0        1.0       0.0
# 111                  -0.4823   0.0 -1.0871        8.0        1.0       0.0
# 112                   2.1509   0.0 -1.8113        8.0        1.0       0.0
# 113                  -0.4963   0.0 -1.4209        8.0        1.0       0.0
# 114                   0.2867   0.0 -1.8430        8.0        1.0       0.0
#
#      chi_squared         ew  flag_error  flag_warning
# 0      37.427133   872.8370           0             0
# 1      36.235675   978.7727           0      10000000
# 2      37.463853   947.0596           0             0
# 3      26.736957   845.0737           0             0
# 4      56.607487   743.9069           0             0
# ..           ...        ...         ...           ...
# 110    33.841462   681.7361           0             0
# 111     6.311982   591.1923           0             0
# 112    61.693902   490.2528           0             0
# 113     5.499576  1558.5944           0             0
# 114    38.230377   485.7284           0          1000
#
# [115 rows x 14 columns]

# %%
output_trimmed
# Out:
#               specname  wave_center  wave_start  wave_end  \
# 0    WISE222_clean.txt     22947.40     22946.0   22948.8
# 1    WISE222_clean.txt     22956.00     22954.0   22958.0
# 2    WISE222_clean.txt     22971.30     22969.5   22973.1
# 3    WISE222_clean.txt     22978.50     22976.7   22980.3
# 8    WISE222_clean.txt     23304.50     23302.0   23307.0
# ..                 ...          ...         ...       ...
# 109  WISE222_clean.txt     23642.60     23640.7   23644.5
# 110  WISE222_clean.txt     23759.00     23757.5   23760.5
# 111  WISE222_clean.txt     24303.00     24301.5   24304.5
# 113  WISE222_clean.txt     24640.75     24637.0   24644.5
# 114  WISE222_clean.txt     24683.35     24682.0   24684.7
#
#      Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 0                     0.6937   0.0 -0.8720        4.0        1.0       0.0
# 1                     2.5000   0.0 -0.9128        4.0        1.0       0.0
# 2                     0.3719   0.0 -0.8746        4.0        1.0       0.0
# 3                     0.6466   0.0 -1.0240        4.0        1.0       0.0
# 8                     2.4952   0.0 -0.9774        4.0        1.0       0.0
# ..                       ...   ...     ...        ...        ...       ...
# 109                   2.5000   0.0 -0.9514        8.0        1.0       0.0
# 110                  -1.7242   0.0 -1.2361        8.0        1.0       0.0
# 111                  -0.4823   0.0 -1.0871        8.0        1.0       0.0
# 113                  -0.4963   0.0 -1.4209        8.0        1.0       0.0
# 114                   0.2867   0.0 -1.8430        8.0        1.0       0.0
#
#      chi_squared         ew  flag_error  flag_warning
# 0      37.427133   872.8370           0             0
# 1      36.235675   978.7727           0      10000000
# 2      37.463853   947.0596           0             0
# 3      26.736957   845.0737           0             0
# 8      49.133920   981.8957           0             0
# ..           ...        ...         ...           ...
# 109    13.202485   762.7061           0      10000000
# 110    33.841462   681.7361           0             0
# 111     6.311982   591.1923           0             0
# 113     5.499576  1558.5944           0             0
# 114    38.230377   485.7284           0          1000
#
# [85 rows x 14 columns]

# %%
vmics = np.unique(output_trimmed["Microturb"].values)
cs = ['r', 'g', 'b', 'c', 'm', 'y']
markers = ['o', 's', 'D', '^', 'v', 'p']
for i in range(len(vmics)):
    vmic = vmics[i]
    output_trimmed3 = output_trimmed[output_trimmed["Microturb"] == vmic]
    ews = np.array(output_trimmed3["ew"])
    nfes = np.array(output_trimmed3["O_Fe"])
    mean_nfe = np.mean(nfes)
    std_nfe = np.std(nfes)
    choose_idxs = np.where(np.abs(nfes - mean_nfe) < 1*std_nfe)
    choose_idxs = choose_idxs[0]
    choose_idxs2 = np.where(ews[choose_idxs] <1200)
    choose_idxs2 = choose_idxs2[0]
    choose_idxs = choose_idxs[choose_idxs2]
    ews = ews[choose_idxs]
    nfes = nfes[choose_idxs]
    corr = np.corrcoef(ews,nfes)[0,1]
    corr = corr.round(2)
    plt.scatter(ews,nfes, c=cs[i], marker = markers[i], label = f"vmic = {vmics[i]}, corr = {corr}")
    m,c = np.polyfit(ews,nfes,1)
    x = np.linspace(400, 1500, 100)
    y = m*x + c
    print(vmics[i], m, len(nfes))
    plt.plot(x,y, c = cs[i])
    plt.legend(fontsize = 8)
    plt.ylabel("[N/Fe]")
    plt.xlabel("EW")
# Out:
# 4.0 -4.441787080905622e-05 6
# 5.0 -0.0002222434822384701 11
# 6.0 -0.00017663156177753038 13
# 7.0 0.0001050193686328009 13
# 8.0 0.0001462118065436347 16

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wise222/Oct-14-2024-14-23-35_0.507657243264725_LTE_N_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 25])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#             specname  wave_center  wave_start  wave_end  \
# 0  WISE222_clean.txt     22580.25     22578.5   22582.0
# 1  WISE222_clean.txt     22632.75     22631.0   22634.5
# 2  WISE222_clean.txt     22828.00     22826.0   22830.0
# 3  WISE222_clean.txt     22915.50     22913.5   22917.5
#
#    Doppler_Shift_add_to_RV  Fe_H    N_Fe  Microturb  Macroturb  rotation  \
# 0                   0.1655   0.0 -0.1232        7.0     4.9224       0.0
# 1                   0.8214   0.0 -0.0297        7.0     5.3671       0.0
# 2                   0.4807   0.0 -0.0224        7.0     6.1184       0.0
# 3                  -1.5463   0.0 -0.1357        7.0     6.9569       0.0
#
#    chi_squared        ew  flag_error  flag_warning
# 0     0.727199  820.0952           0             0
# 1     9.637451  959.0050        1000          1000
# 2    15.854170  878.4395        1000          1000
# 3     6.107040  771.6399           0             0

# %%
output_trimmed
# Out:
#             specname  wave_center  wave_start  wave_end  \
# 0  WISE222_clean.txt     22580.25     22578.5   22582.0
# 1  WISE222_clean.txt     22632.75     22631.0   22634.5
# 2  WISE222_clean.txt     22828.00     22826.0   22830.0
# 3  WISE222_clean.txt     22915.50     22913.5   22917.5
#
#    Doppler_Shift_add_to_RV  Fe_H    N_Fe  Microturb  Macroturb  rotation  \
# 0                   0.1650   0.0 -0.1237        7.0     4.9197       0.0
# 1                   0.6348   0.0 -0.1796        7.0     4.3539       0.0
# 2                   0.1996   0.0 -0.2116        7.0     2.8054       0.0
# 3                  -1.6505   0.0 -0.0077        7.0     9.8181       0.0
#
#    chi_squared        ew  flag_error  flag_warning
# 0     0.727174  819.7545           0             0
# 1     1.870679  843.7932           0             0
# 2     3.511880  731.0423           0          1000
# 3    10.862966  859.6404           0             0

# %%
np.mean(output_trimmed["Macroturb"]), np.std(output_trimmed["Macroturb"])
# Out:
# (np.float64(5.841200000000001), np.float64(0.7730767393991365))

# %%
np.mean(output_trimmed["Macroturb"]), np.std(output_trimmed["Macroturb"])
# Out:
# (np.float64(7.5984181818181815), np.float64(3.856012872200832))

# %%
np.mean(output_trimmed[output_trimmed["Macroturb"] < 5]["Macroturb"]), np.std(output_trimmed[output_trimmed["Macroturb"] < 5]["Macroturb"])
# Out:
# (np.float64(4.0263333333333335), np.float64(0.8936968402216839))

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wise222/Oct-14-2024-15-30-44_0.852449912428387_LTE_CN_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 12])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#             specname  wave_center  wave_start  wave_end  \
# 0  WISE222_clean.txt     22743.35     22742.0   22744.7
# 2  WISE222_clean.txt     22804.50     22802.0   22807.0
# 3  WISE222_clean.txt     22879.25     22877.0   22881.5
#
#    Doppler_Shift_add_to_RV  Fe_H    C_Fe    N_Fe  Microturb  Macroturb  \
# 0                  -0.3712   0.0  0.1643  0.1247        7.0        4.0
# 2                  -1.5208   0.0  0.1629  0.1517        7.0        4.0
# 3                   0.7253   0.0  0.1449  0.1686        7.0        4.0
#
#    rotation  chi_squared        ew  flag_error  flag_warning
# 0       0.0     5.478024  447.4218           0             0
# 2       0.0     3.739713  748.7374           0             0
# 3       0.0     4.902073  822.1731           0             0

# %%
np.mean(output_trimmed["C_Fe"])
# Out:
# np.float64(0.15736666666666665)

# %%
np.mean(output_trimmed["C_Fe"])+8.56
# Out:
# np.float64(8.717366666666667)

# %%
np.mean(output_trimmed["N_Fe"])+7.98
# Out:
# np.float64(8.128333333333334)

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/wise222/Oct-14-2024-16-52-53_0.9121924404140458_LTE_C_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 12])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#             specname  wave_center  wave_start  wave_end  \
# 0  WISE222_clean.txt     22743.35     22742.0   22744.7
# 1  WISE222_clean.txt     22799.60     22798.0   22801.2
# 2  WISE222_clean.txt     22804.50     22802.0   22807.0
# 3  WISE222_clean.txt     22879.25     22877.0   22881.5
#
#    Doppler_Shift_add_to_RV  Fe_H    C_Fe  Microturb  Macroturb  rotation  \
# 0                  -0.4502   0.0  0.2720        7.0        4.0       0.0
# 1                  -0.6942   0.0  0.3956        7.0        4.0       0.0
# 2                  -1.4627   0.0  0.2890        7.0        4.0       0.0
# 3                   0.7291   0.0  0.2899        7.0        4.0       0.0
#
#    chi_squared        ew  flag_error  flag_warning
# 0     5.573205  445.8523           0             0
# 1     7.447995  604.5220           0             0
# 2     3.687908  750.2217           0             0
# 3     4.175026  831.5563           0             0

# %%
np.mean(output_trimmed["C_Fe"])+8.56
# Out:
# np.float64(8.871625)
