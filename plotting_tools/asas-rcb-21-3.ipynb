# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *
import scienceplots
plt.style.use(['science', 'notebook'])

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-2/"
# find the newest folder in the directory
newest_folder = max(glob.glob(outpath + "/*"), key=os.path.getctime)
config_dict = load_output_data(newest_folder)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] <200])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
remove = [22740.0	,23144.0,22832.5	,22770.0,
			22905.5	,23328.0,22608.00,22575.25,22655.50,22934.50,23348.5	]
output_trimmed = output_trimmed[~output_trimmed["wave_center"].isin(remove)]

# %%
# output_trimmed = output_trimmed[output_trimmed["wave_center"] != 23348.5			]
output_trimmed
# Out:
#           specname  wave_center  wave_start  wave_end  \
# 1  ASAS-RCB-21.txt      23379.0     23377.0   23381.0
#
#    Doppler_Shift_add_to_RV  Fe_H   Na_Fe  Microturb  Macroturb  rotation  \
# 1                  -0.7326   0.0 -1.1782        7.0        7.8       0.0
#
#    chi_squared        ew  flag_error  flag_warning
# 1      2.47711  624.3773           0             0

# %%
X = "Na"
np.mean(output_trimmed[f"{X}_Fe"]).round(2)
# Out:
# np.float64(-1.18)

# %%
(solar_abundances[X] + np.mean(output_trimmed[f"{X}_Fe"])).round(2)
# Out:
# np.float64(5.11)

# %%
np.mean(output_trimmed[f"Fe_H"]).round(2)
# Out:
# np.float64(-0.92)

# %%
(solar_abundances["Fe"] + np.mean(output_trimmed[f"Fe_H"])).round(2)
# Out:
# np.float64(6.58)

# %%
multwavs = [22587.95,22593.85,22613.8,22634,22659.4,22680.5,22691.75,22703,22713.25,22773.25,22783.3,22789.35,22915.25,23028.35,23067.25,23655.35,
            22920.00, 23292.60]

outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-2/Oct-24-2024-13-55-40_0.28258010476482254_LTE_O_1D"

# %%
config_dict = load_output_data(outpath)
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_results_pd_df = config_dict["output_file_df"]

# %%
output_results_pd_df
# Out:
#            specname  wave_center  wave_start  wave_end  \
# 0   ASAS-RCB-21.txt     23023.50     23022.3   23024.7
# 1   ASAS-RCB-21.txt     23072.00     23071.0   23073.0
# 2   ASAS-RCB-21.txt     23118.20     23117.3   23119.1
# 3   ASAS-RCB-21.txt     23274.60     23273.6   23275.6
# 4   ASAS-RCB-21.txt     23295.50     23293.0   23298.0
# ..              ...          ...         ...       ...
# 67  ASAS-RCB-21.txt     23759.00     23757.5   23760.5
# 68  ASAS-RCB-21.txt     24063.50     24062.6   24064.4
# 69  ASAS-RCB-21.txt     24283.60     24282.6   24284.6
# 70  ASAS-RCB-21.txt     24605.25     24604.0   24606.5
# 71  ASAS-RCB-21.txt     24683.35     24682.0   24684.7
#
#     Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 0               999999.0000   0.0  1.2244        7.0        5.0       0.0
# 1                   -0.7799   0.0  0.2873        7.0        5.0       0.0
# 2               999999.0000   0.0  1.2191        7.0        5.0       0.0
# 3                    0.7613   0.0 -0.1368        7.0        5.0       0.0
# 4                   -1.3260   0.0  0.0874        7.0        5.0       0.0
# ..                      ...   ...     ...        ...        ...       ...
# 67                  -0.6231   0.0 -0.0475        5.0        5.0       0.0
# 68                   2.5000   0.0 -0.0686        5.0        5.0       0.0
# 69                   0.8371   0.0 -0.3290        5.0        5.0       0.0
# 70                   0.2167   0.0  0.0133        5.0        5.0       0.0
# 71                  -0.0668   0.0 -0.1263        5.0        5.0       0.0
#
#       chi_squared            ew  flag_error  flag_warning
# 0   999999.990000  9.999990e+08    10000000             0
# 1       15.440323  7.777781e+02           0             0
# 2   999999.990000  9.999990e+08    10000000             0
# 3       15.833801  6.932620e+02           0             0
# 4       58.959228  1.335915e+03           0             0
# ..            ...           ...         ...           ...
# 67      30.938918  6.058032e+02           0             0
# 68      71.764026  5.002907e+02           0      10000000
# 69      17.651591  4.059684e+02           0             0
# 70      43.859343  6.418817e+02           0             0
# 71      31.063238  6.192522e+02           0             0
#
# [72 rows x 14 columns]

# %%
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 30])
output_trimmed = output_trimmed.reset_index(drop=True)
output_trimmed_vmic = output_trimmed[~output_trimmed["wave_center"].isin(multwavs)]

# %%
output_trimmed_vmic
# Out:
#            specname  wave_center  wave_start  wave_end  \
# 0   ASAS-RCB-21.txt    23072.000    23071.00   23073.0
# 1   ASAS-RCB-21.txt    23274.600    23273.60   23275.6
# 2   ASAS-RCB-21.txt    23304.500    23302.00   23307.0
# 3   ASAS-RCB-21.txt    23341.250    23339.50   23343.0
# 4   ASAS-RCB-21.txt    23362.100    23360.70   23363.5
# 5   ASAS-RCB-21.txt    23373.000    23371.50   23374.5
# 6   ASAS-RCB-21.txt    23759.000    23757.50   23760.5
# 7   ASAS-RCB-21.txt    24063.500    24062.60   24064.4
# 8   ASAS-RCB-21.txt    24283.600    24282.60   24284.6
# 9   ASAS-RCB-21.txt    24605.250    24604.00   24606.5
# 10  ASAS-RCB-21.txt    24683.350    24682.00   24684.7
# 11  ASAS-RCB-21.txt    23072.000    23071.00   23073.0
# 12  ASAS-RCB-21.txt    23274.600    23273.60   23275.6
# 13  ASAS-RCB-21.txt    23304.500    23302.00   23307.0
# 14  ASAS-RCB-21.txt    23322.000    23320.00   23324.0
# 15  ASAS-RCB-21.txt    23341.250    23339.50   23343.0
# 16  ASAS-RCB-21.txt    23362.100    23360.70   23363.5
# 17  ASAS-RCB-21.txt    23373.000    23371.50   23374.5
# 18  ASAS-RCB-21.txt    23421.100    23419.50   23422.7
# 19  ASAS-RCB-21.txt    23476.045    23474.79   23477.3
# 20  ASAS-RCB-21.txt    23759.000    23757.50   23760.5
# 21  ASAS-RCB-21.txt    24063.500    24062.60   24064.4
# 22  ASAS-RCB-21.txt    24283.600    24282.60   24284.6
# 23  ASAS-RCB-21.txt    24605.250    24604.00   24606.5
# 24  ASAS-RCB-21.txt    24683.350    24682.00   24684.7
# 25  ASAS-RCB-21.txt    23274.600    23273.60   23275.6
# 26  ASAS-RCB-21.txt    23304.500    23302.00   23307.0
# 27  ASAS-RCB-21.txt    23362.100    23360.70   23363.5
# 28  ASAS-RCB-21.txt    23373.000    23371.50   23374.5
# 29  ASAS-RCB-21.txt    23759.000    23757.50   23760.5
# 30  ASAS-RCB-21.txt    24283.600    24282.60   24284.6
# 31  ASAS-RCB-21.txt    24605.250    24604.00   24606.5
# 32  ASAS-RCB-21.txt    24683.350    24682.00   24684.7
# 33  ASAS-RCB-21.txt    23304.500    23302.00   23307.0
# 34  ASAS-RCB-21.txt    23373.000    23371.50   23374.5
# 35  ASAS-RCB-21.txt    24283.600    24282.60   24284.6
#
#     Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 0                   -0.7799   0.0  0.2873        7.0        5.0       0.0
# 1                    0.7613   0.0 -0.1368        7.0        5.0       0.0
# 2                    0.7832   0.0 -0.1558        7.0        5.0       0.0
# 3                    0.3609   0.0 -0.0761        7.0        5.0       0.0
# 4                   -0.6880   0.0 -0.1566        7.0        5.0       0.0
# 5                   -1.0434   0.0 -0.0052        7.0        5.0       0.0
# 6                   -0.6826   0.0 -0.1614        7.0        5.0       0.0
# 7                    2.5000   0.0 -0.1767        7.0        5.0       0.0
# 8                    0.8370   0.0 -0.3701        7.0        5.0       0.0
# 9                   -0.0439   0.0 -0.1342        7.0        5.0       0.0
# 10                  -0.0668   0.0 -0.2182        7.0        5.0       0.0
# 11                  -0.8315   0.0  0.2080        8.0        5.0       0.0
# 12                   0.3110   0.0 -0.1915        8.0        5.0       0.0
# 13                   0.1634   0.0 -0.1947        8.0        5.0       0.0
# 14                   0.9731   0.0 -0.0977        8.0        5.0       0.0
# 15                   0.3608   0.0 -0.0811        8.0        5.0       0.0
# 16                  -0.6612   0.0 -0.2039        8.0        5.0       0.0
# 17                  -0.7532   0.0 -0.0488        8.0        5.0       0.0
# 18                  -0.0496   0.0 -0.0929        8.0        5.0       0.0
# 19                  -0.8697   0.0  0.0355        8.0        5.0       0.0
# 20                  -0.9060   0.0 -0.1860        8.0        5.0       0.0
# 21                   2.5000   0.0 -0.1954        8.0        5.0       0.0
# 22                   0.7803   0.0 -0.3755        8.0        5.0       0.0
# 23                   0.1961   0.0 -0.1731        8.0        5.0       0.0
# 24                  -0.0668   0.0 -0.2351        8.0        5.0       0.0
# 25                   0.2511   0.0 -0.0513        6.0        5.0       0.0
# 26                   1.1528   0.0 -0.1123        6.0        5.0       0.0
# 27                  -0.7465   0.0 -0.0877        6.0        5.0       0.0
# 28                  -1.8713   0.0  0.0455        6.0        5.0       0.0
# 29                  -0.6826   0.0 -0.1233        6.0        5.0       0.0
# 30                   0.8370   0.0 -0.3569        6.0        5.0       0.0
# 31                   0.2173   0.0 -0.1237        6.0        5.0       0.0
# 32                  -0.0668   0.0 -0.1855        6.0        5.0       0.0
# 33                   1.6072   0.0 -0.0552        5.0        5.0       0.0
# 34                  -2.2876   0.0  0.1182        5.0        5.0       0.0
# 35                   0.8371   0.0 -0.3290        5.0        5.0       0.0
#
#     chi_squared         ew  flag_error  flag_warning
# 0     15.440323   777.7781           0             0
# 1     15.833801   693.2620           0             0
# 2     13.751591  1030.1285           0             0
# 3     27.494805   798.1074           0             0
# 4      9.342851   829.8474           0             0
# 5     17.079327   954.7522           0             0
# 6     10.934494   644.6443           0             0
# 7     26.377345   507.4261           0      10000000
# 8      2.254640   417.4233           0             0
# 9     10.419452   664.1641           0             0
# 10     8.772756   640.4464           0             0
# 11     7.108915   773.8775           0             0
# 12    11.103097   682.6149           0             0
# 13     8.694178  1039.0442           0             0
# 14    27.018623   957.1417           0             0
# 15    17.764092   858.0282           0          1000
# 16     3.648174   837.9385           0             0
# 17    10.541686   958.5248           0             0
# 18    13.942490   793.5444           0             0
# 19    19.605082   777.6618           0             0
# 20     5.941615   661.1525           0             0
# 21    18.119727   510.0203           0      10000000
# 22     1.361015   420.4425           0             0
# 23     5.737306   667.7832           0             0
# 24     4.756954   649.8861           0             0
# 25    23.858692   701.6504           0             0
# 26    19.761771  1016.1024           0             0
# 27    20.446183   821.6513           0             0
# 28    20.849445   946.0189           0             0
# 29    19.128938   624.2539           0             0
# 30     7.127156   412.3267           0             0
# 31    20.952411   631.3556           0             0
# 32    17.410284   630.1248           0             0
# 33    27.305624   998.8291           0             0
# 34    25.728538   938.1873           0             0
# 35    17.651591   405.9684           0             0

# %%
vmics = np.unique(output_trimmed_vmic["Microturb"].values)
cs = ['r', 'g', 'b', 'c', 'm', 'y']
markers = ['o', 's', 'D', '^', 'v', 'p']
for i in range(len(vmics)):
    vmic = vmics[i]
    output_vmic = output_trimmed_vmic[output_trimmed_vmic["Microturb"] == vmic]
    ews = np.array(output_vmic["ew"])
    nfes = np.array(output_vmic["O_Fe"])
    mean_nfe = np.mean(nfes)
    std_nfe = np.std(nfes)
    choose_idxs = np.where(np.abs(nfes - mean_nfe) < 5*std_nfe)
    choose_idxs = choose_idxs[0]
    choose_idxs2 = np.where(nfes[choose_idxs] > -10.0)
    choose_idxs2 = choose_idxs2[0]
    choose_idxs = choose_idxs[choose_idxs2]
    ews = ews[choose_idxs]
    nfes = nfes[choose_idxs]
    corr = np.corrcoef(ews,nfes)[0,1]
    corr = corr.round(2)
    plt.scatter(ews,nfes, c=cs[i], marker = markers[i], label = f"vmic = {vmics[i]}, corr = {corr}")
    m,c = np.polyfit(ews,nfes,1)
    x = np.linspace(500, 1600, 100)
    y = m*x + c
    print(vmics[i], m, len(nfes))
    plt.plot(x,y, c = cs[i])
    plt.legend(fontsize = 8)
    plt.ylabel("[N/Fe]")
    plt.xlabel("EW")
# Out:
# 5.0 0.0006106001781517664 3
# 6.0 0.00045045841690877594 8
# 7.0 0.0004262472820358806 11
# 8.0 0.000355753278816573 14

# %%
np.min(output_trimmed2['N_Fe'])
# Out:
# np.float64(0.9777)

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-2/Oct-16-2024-00-22-14_0.1910654443745513_LTE_N_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 50])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_results_pd_df
# Out:
#           specname  wave_center  wave_start  wave_end  \
# 0  ASAS-RCB-21.txt     22580.25     22578.5   22582.0
# 1  ASAS-RCB-21.txt     22632.75     22631.0   22634.5
# 2  ASAS-RCB-21.txt     22828.00     22826.0   22830.0
# 3  ASAS-RCB-21.txt     22915.50     22913.5   22917.5
#
#    Doppler_Shift_add_to_RV  Fe_H    N_Fe  Microturb  Macroturb  rotation  \
# 0                  -1.0971   0.0 -0.2537        7.0     0.0000       0.0
# 1                   0.9330   0.0  1.2008        7.0     5.0697       0.0
# 2                  -2.5000   0.0 -1.0000        7.0     3.7877       0.0
# 3                  -0.8544   0.0  1.2443        7.0     5.6956       0.0
#
#    chi_squared        ew  flag_error  flag_warning
# 0   252.498259    9.8995       10000      10011000
# 1     2.638169  764.3171           0             0
# 2   169.532586  174.5669       10000      10011000
# 3     9.477321  701.3213           0             0

# %%
output_trimmed
# Out:
#           specname  wave_center  wave_start  wave_end  \
# 1  ASAS-RCB-21.txt     22632.75     22631.0   22634.5
# 3  ASAS-RCB-21.txt     22915.50     22913.5   22917.5
#
#    Doppler_Shift_add_to_RV  Fe_H    N_Fe  Microturb  Macroturb  rotation  \
# 1                   0.9330   0.0  1.2008        7.0     5.0697       0.0
# 3                  -0.8544   0.0  1.2443        7.0     5.6956       0.0
#
#    chi_squared        ew  flag_error  flag_warning
# 1     2.638169  764.3171           0             0
# 3     9.477321  701.3213           0             0

# %%
np.mean(output_trimmed['Macroturb'])
# Out:
# np.float64(5.38265)

# %%
np.mean(output_trimmed["Macroturb"]), np.std(output_trimmed["Macroturb"])
# Out:
# (np.float64(8.0), np.float64(0.0))

# %%
import glob
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-2/"
# find the newest folder in the directory
newest_folder = max(glob.glob(outpath + "/*"), key=os.path.getctime)
config_dict = load_output_data(newest_folder)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 20])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#            specname  wave_center  wave_start  wave_end  \
# 0   ASAS-RCB-21.txt     22647.50     22646.0   22649.0
# 1   ASAS-RCB-21.txt     22663.75     22662.5   22665.0
# 2   ASAS-RCB-21.txt     22722.50     22721.0   22724.0
# 3   ASAS-RCB-21.txt     22736.50     22735.0   22738.0
# 4   ASAS-RCB-21.txt     22788.50     22787.0   22790.0
# 5   ASAS-RCB-21.txt     22799.00     22797.0   22801.0
# 6   ASAS-RCB-21.txt     22842.00     22840.0   22844.0
# 7   ASAS-RCB-21.txt     22862.50     22861.0   22864.0
# 8   ASAS-RCB-21.txt     22869.70     22868.0   22871.4
# 9   ASAS-RCB-21.txt     23055.50     23054.0   23057.0
# 10  ASAS-RCB-21.txt     23126.50     23125.5   23127.5
# 11  ASAS-RCB-21.txt     23168.00     23167.0   23169.0
# 12  ASAS-RCB-21.txt     23357.00     23356.0   23358.0
# 13  ASAS-RCB-21.txt     23381.75     23380.5   23383.0
# 14  ASAS-RCB-21.txt     23392.00     23390.0   23394.0
#
#     Doppler_Shift_add_to_RV  Fe_H    C_Fe  Microturb  Macroturb  rotation  \
# 0                    0.0963   0.0  0.3036        7.0        5.4       0.0
# 1                    0.1726   0.0  0.2656        7.0        5.4       0.0
# 2                    0.2377   0.0  0.3200        7.0        5.4       0.0
# 3                   -1.9938   0.0  0.3244        7.0        5.4       0.0
# 4                   -0.4116   0.0  0.2306        7.0        5.4       0.0
# 5                   -0.9433   0.0  0.3499        7.0        5.4       0.0
# 6                   -1.8596   0.0  0.3325        7.0        5.4       0.0
# 7                    1.3466   0.0  0.3653        7.0        5.4       0.0
# 8                   -0.6248   0.0  0.3927        7.0        5.4       0.0
# 9                    2.5000   0.0  0.3180        7.0        5.4       0.0
# 10                  -0.2420   0.0  0.2319        7.0        5.4       0.0
# 11                   0.5266   0.0  0.3311        7.0        5.4       0.0
# 12                   0.8869   0.0  0.1694        7.0        5.4       0.0
# 13                  -1.7836   0.0  0.3184        7.0        5.4       0.0
# 14                   2.2311   0.0  0.2519        7.0        5.4       0.0
#
#     chi_squared        ew  flag_error  flag_warning
# 0      1.583657  194.2891           0             0
# 1      2.070203  368.0000           0             0
# 2      1.667101  241.1892           0             0
# 3      2.541642  484.1904           0             0
# 4      9.783293  471.5235           0             0
# 5      4.801637  590.3095           0             0
# 6      3.227266  374.3430           0             0
# 7      5.664996  488.2703           0             0
# 8      5.201908  668.0747           0          1000
# 9      6.481628  486.9459           0      10000000
# 10     3.218425  210.2661           0             0
# 11     5.529285  244.2566           0             0
# 12     1.301021   55.1507           0             0
# 13     2.137772  182.1432           0             0
# 14     6.950195  411.2527           0             0

# %%
np.mean(output_trimmed['C_Fe'])+solar_abundances['C']
# Out:
# np.float64(8.860353333333334)

# %%
np.std(output_trimmed['C_Fe'])
# Out:
# np.float64(0.05718225676631598)

# %%
# wavelength, flux, wavelength_observed_rv, flux_observed = plot_one_star(config_dict, 'ASAS-RCB-21', plot_title=True)

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-2/"
# find the newest folder in the directory
newest_folder = max(glob.glob(outpath + "/*"), key=os.path.getctime)
config_dict = load_output_data(newest_folder)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] <20])
output_trimmed = output_trimmed[output_trimmed["N_Fe"] + solar_abundances['N'] > 7.5]
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
(7.98+np.mean(output_trimmed['N_Fe'])).round(3), np.std(output_trimmed['N_Fe']).round(3)
# Out:
# (np.float64(7.736), np.float64(0.086))

# %%
plt.scatter(output_trimmed['wave_center'], output_trimmed['N_Fe']+7.98, c = output_trimmed['chi_squared'], cmap = 'inferno')
plt.grid(which='both')
plt.colorbar()
# plt.axvline(2.322e4)

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21-2/"
# find the newest folder in the directory
newest_folder = max(glob.glob(outpath + "/*"), key=os.path.getctime)
config_dict = load_output_data(newest_folder)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] <20])
output_trimmed = output_trimmed[output_trimmed["O_Fe"] + solar_abundances['O'] > 7.5]
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#            specname  wave_center  wave_start  wave_end  \
# 0   ASAS-RCB-21.txt    23255.500    23253.50   23257.5
# 2   ASAS-RCB-21.txt    23274.000    23272.00   23276.0
# 4   ASAS-RCB-21.txt    23304.000    23302.00   23306.0
# 5   ASAS-RCB-21.txt    23313.500    23311.00   23316.0
# 6   ASAS-RCB-21.txt    23362.100    23360.70   23363.5
# 7   ASAS-RCB-21.txt    23373.000    23371.50   23374.5
# 9   ASAS-RCB-21.txt    23421.000    23419.79   23422.2
# 10  ASAS-RCB-21.txt    23447.750    23446.50   23449.0
# 11  ASAS-RCB-21.txt    23476.045    23474.79   23477.3
# 12  ASAS-RCB-21.txt    23718.150    23717.00   23719.3
# 14  ASAS-RCB-21.txt    23759.000    23757.50   23760.5
# 15  ASAS-RCB-21.txt    23794.950    23793.60   23796.3
# 16  ASAS-RCB-21.txt    23799.000    23797.00   23801.0
# 17  ASAS-RCB-21.txt    23803.500    23802.00   23805.0
# 18  ASAS-RCB-21.txt    23808.500    23807.00   23810.0
# 19  ASAS-RCB-21.txt    23878.500    23877.00   23880.0
# 21  ASAS-RCB-21.txt    24003.000    24001.00   24005.0
# 22  ASAS-RCB-21.txt    24016.250    24015.00   24017.5
# 23  ASAS-RCB-21.txt    24022.600    24020.60   24024.6
# 24  ASAS-RCB-21.txt    24035.250    24033.50   24037.0
# 25  ASAS-RCB-21.txt    24044.750    24043.50   24046.0
# 26  ASAS-RCB-21.txt    24059.500    24058.00   24061.0
# 27  ASAS-RCB-21.txt    24065.550    24064.10   24067.0
# 28  ASAS-RCB-21.txt    24099.750    24098.50   24101.0
# 33  ASAS-RCB-21.txt    24285.750    24284.50   24287.0
# 35  ASAS-RCB-21.txt    24310.350    24305.70   24315.0
# 36  ASAS-RCB-21.txt    24330.200    24328.40   24332.0
# 37  ASAS-RCB-21.txt    24357.250    24355.50   24359.0
# 38  ASAS-RCB-21.txt    24365.150    24364.00   24366.3
# 39  ASAS-RCB-21.txt    24393.850    24392.00   24395.7
# 41  ASAS-RCB-21.txt    24589.750    24585.50   24594.0
# 42  ASAS-RCB-21.txt    24605.250    24604.00   24606.5
# 44  ASAS-RCB-21.txt    24721.000    24719.00   24723.0
# 45  ASAS-RCB-21.txt    24837.200    24836.00   24838.4
#
#     Doppler_Shift_add_to_RV  Fe_H    O_Fe  Microturb  Macroturb  rotation  \
# 0                    1.8587   0.0 -1.1203        7.0        7.8       0.0
# 2                    1.8433   0.0 -1.1611        7.0        7.8       0.0
# 4                    0.9147   0.0 -1.0764        7.0        7.8       0.0
# 5                   -0.8353   0.0 -0.8323        7.0        7.8       0.0
# 6                   -0.3572   0.0 -1.0293        7.0        7.8       0.0
# 7                   -0.2027   0.0 -0.9067        7.0        7.8       0.0
# 9                    0.0661   0.0 -0.9648        7.0        7.8       0.0
# 10                  -2.5000   0.0 -0.7626        7.0        7.8       0.0
# 11                  -1.0442   0.0 -0.8993        7.0        7.8       0.0
# 12                   0.0825   0.0 -1.1390        7.0        7.8       0.0
# 14                  -0.6826   0.0 -1.1107        7.0        7.8       0.0
# 15                  -0.9601   0.0 -1.1271        7.0        7.8       0.0
# 16                  -0.1427   0.0 -0.9976        7.0        7.8       0.0
# 17                  -1.3374   0.0 -0.8512        7.0        7.8       0.0
# 18                  -1.2783   0.0 -1.2433        7.0        7.8       0.0
# 19                   2.5000   0.0 -1.1817        7.0        7.8       0.0
# 21                  -2.1170   0.0 -0.8194        7.0        7.8       0.0
# 22                   0.5352   0.0 -0.9541        7.0        7.8       0.0
# 23                   1.6406   0.0 -1.1513        7.0        7.8       0.0
# 24                  -2.5000   0.0 -1.0473        7.0        7.8       0.0
# 25                   0.8328   0.0 -1.0420        7.0        7.8       0.0
# 26                  -2.0745   0.0 -0.6663        7.0        7.8       0.0
# 27                  -0.6356   0.0 -0.7847        7.0        7.8       0.0
# 28                   0.5386   0.0 -1.2036        7.0        7.8       0.0
# 33                   0.0795   0.0 -1.0837        7.0        7.8       0.0
# 35                   1.3486   0.0 -1.2277        7.0        7.8       0.0
# 36                  -0.4979   0.0 -1.0737        7.0        7.8       0.0
# 37                  -2.0295   0.0 -0.8993        7.0        7.8       0.0
# 38                  -0.8416   0.0 -0.8584        7.0        7.8       0.0
# 39                   2.5000   0.0 -1.1697        7.0        7.8       0.0
# 41                   0.0184   0.0 -1.1502        7.0        7.8       0.0
# 42                  -0.0439   0.0 -1.1129        7.0        7.8       0.0
# 44                  -2.5000   0.0 -0.6637        7.0        7.8       0.0
# 45                   0.6243   0.0 -0.7976        7.0        7.8       0.0
#
#     chi_squared         ew  flag_error  flag_warning
# 0      3.126632  1120.8211           0             0
# 2     10.933120  1084.4950           0             0
# 4      8.059688  1035.0547           0             0
# 5      4.573895  1431.1973           0             0
# 6     11.913165   825.7301           0             0
# 7      5.554046   966.7956           0             0
# 9     11.223305   712.8403           0             0
# 10    11.749223   861.6208           0      10000000
# 11    11.835430   789.6248           0             0
# 12     6.071412   662.9625           0             0
# 14     7.078350   702.2864           0             0
# 15     5.226948   512.4384           0             0
# 16     7.293333   615.5961           0             0
# 17     7.044998   980.4832           0             0
# 18     3.266697   618.5205           0             0
# 19    12.976336   681.5683           0      10000000
# 21     5.408170  1267.3741           0             0
# 22     8.051996   419.5189           0             0
# 23    10.297237  1187.7151           0             0
# 24    13.962497  1120.3800           0      10000000
# 25     4.153848   430.6492           0          1000
# 26    10.851950   586.0258           0          1000
# 27     6.148058   977.6125        1000          1000
# 28     7.729674   347.3734           0             0
# 33     9.083517   365.7108           0             0
# 35     8.816982  1755.7809           0             0
# 36     6.014396   971.0920           0             0
# 37     8.054452   789.6628           0          1000
# 38     3.215969   643.8937           0             0
# 39    11.392626   466.2835           0      10000000
# 41    11.099451  2168.9575           0             0
# 42     7.999356   676.4303           0             0
# 44     6.055437   861.2003           0      10000000
# 45     2.164087   533.0147           0             0

# %%
# for i in range(len(output_trimmed)):
#     print(f"{output_trimmed['wave_center'].iloc[i]}  {output_trimmed['wave_start'].iloc[i]}  {output_trimmed['wave_end'].iloc[i]}")

# %%
np.mean(output_trimmed['O_Fe']).round(3)
# Out:
# np.float64(-1.003)

# %%
(solar_abundances['O']+np.mean(output_trimmed['O_Fe'])).round(3), np.std(output_trimmed['O_Fe']).round(3)
# Out:
# (np.float64(7.767), np.float64(0.162))

# %%
plt.scatter(output_trimmed['wave_center'], output_trimmed['O_Fe']+solar_abundances['O'], c = output_trimmed['chi_squared'], cmap = 'inferno')
plt.grid(which='both')
plt.colorbar()
# plt.axvline(2.322e4)
