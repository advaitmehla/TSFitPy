# %%
from __future__ import annotations
try:
    from scripts_for_plotting import *
except ModuleNotFoundError:
    import sys
    sys.path.append('../')
    from scripts_for_plotting import *
import scienceplots
plt.style.use(['science', 'notebook'])

# %%
outpath = "/media/advait/DATA/research/rcb-project/TSFitPy/output_files/asas-rcb-21/Sep-26-2024-02-32-25_0.2853033523713069_LTE_O_1D"
config_dict = load_output_data(outpath)
output_results_pd_df = config_dict["output_file_df"]
output_trimmed = (output_results_pd_df[output_results_pd_df["chi_squared"] < 20])
# Out:
# /media/advait/DATA/research/rcb-project/TSFitPy/plotting_tools/scripts_for_plotting.py:109: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   output_file_df = output_file_df.apply(pd.to_numeric, errors='ignore')

# %%
output_trimmed
# Out:
#            specname  wave_center  wave_start  wave_end  \
# 0   ASAS-RCB-21.txt    22937.750    22936.50   22939.0
# 1   ASAS-RCB-21.txt    22940.750    22939.00   22942.5
# 2   ASAS-RCB-21.txt    22947.400    22946.00   22948.8
# 3   ASAS-RCB-21.txt    22966.000    22964.60   22967.4
# 4   ASAS-RCB-21.txt    22971.300    22969.50   22973.1
# 5   ASAS-RCB-21.txt    22978.500    22976.70   22980.3
# 7   ASAS-RCB-21.txt    23015.250    23013.90   23016.6
# 8   ASAS-RCB-21.txt    23072.500    23070.50   23074.5
# 9   ASAS-RCB-21.txt    23083.900    23082.00   23085.8
# 10  ASAS-RCB-21.txt    23118.900    23117.00   23120.8
# 11  ASAS-RCB-21.txt    23170.700    23169.70   23171.7
# 13  ASAS-RCB-21.txt    23255.500    23253.50   23257.5
# 14  ASAS-RCB-21.txt    23261.300    23259.40   23263.2
# 15  ASAS-RCB-21.txt    23267.400    23265.50   23269.3
# 16  ASAS-RCB-21.txt    23274.000    23272.00   23276.0
# 18  ASAS-RCB-21.txt    23362.100    23360.70   23363.5
# ...

# %%
plt.scatter(output_trimmed['wave_center'], output_trimmed['O_Fe'])
plt.axvline(2.322e4)

# %%
output_trimmed2 = output_trimmed[output_trimmed['wave_center'] > 2.322e4]
np.mean(output_trimmed2['O_Fe']).round(3)+8.77, np.std(output_trimmed2['O_Fe']).round(3)
# Out:
# (np.float64(8.798), np.float64(0.139))

# %%
output_trimmed2 = output_trimmed[output_trimmed['wave_center'] > 2.322e4]
np.mean(output_trimmed2['O_Fe']).round(3)+8.77, np.std(output_trimmed2['O_Fe']).round(3)
# Out:
# (np.float64(8.798), np.float64(0.139))

# %%
np.mean(output_trimmed2['Macroturb']).round(3), np.std(output_trimmed2['Macroturb']).round(3)
# Out:
# (np.float64(8.0), np.float64(0.0))

# %%
wavelength, flux, wavelength_observed_rv, flux_observed = plot_one_star(config_dict, 'ASAS-RCB-21', plot_title=True)
